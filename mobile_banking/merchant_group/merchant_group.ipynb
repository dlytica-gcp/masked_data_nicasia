# %%
import pandas as pd

# %%
df=  pd.read_excel("merchant_group.xlsx")
df.head()
# Out:
#                          _airbyte_ab_id     _airbyte_emitted_at  id  \
# 0  4f1626ef-285a-4abe-a690-30de20eb5be4 2024-08-06 07:20:29.848   1
# 1  97e0b688-702e-4336-92d4-9f341363fc8a 2024-08-06 07:20:29.848   2
# 2  926b42fc-ffb1-4ad4-85db-6dde216b3b40 2024-08-06 07:20:29.848   3
# 3  ecd8566c-50a1-40c8-92d0-1a0881f494e6 2024-08-06 07:20:29.848   4
# 4  c58bf908-3c03-4e93-be6b-b214f319daa9 2024-08-06 07:20:29.848   5
#
#            code                             icon active     group_name  \
# 0          MPAY  merchant-group/bill-payment.png      Y    Credit Card
# 1         TOPUP               other-payments.png      Y          Topup
# 2            RC                         card.png      Y  Recharge Card
# 3           WAL                 wallet-topup.png      Y    Load Wallet
# 4  DATA_PACKAGE                    data-pack.png      Y   Data Package
#
#    offer_text  sort_order                           description unicode_name  \
# 0         NaN           0  Bill Payment to registered merchants          NaN
# 1         NaN           4                         Topup payment          NaN
# 2         NaN           5    Recharge various recharge vouchers          NaN
# 3         NaN           2                           Load Wallet          NaN
# 4         NaN           6                          Data Package          NaN
#
#    display_position  unicode_description  _airbyte_additional_properties  \
# 0  mainmenu,payment                  NaN                             NaN
# 1           payment                  NaN                             NaN
# 2           payment                  NaN                             NaN
# 3           payment                  NaN                             NaN
# 4           payment                  NaN                             NaN
#
#                                     source_file_path              updated_at
# 0  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:25.979
# 1  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:25.979
# 2  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:25.979
# 3  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:25.979
# 4  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:25.979

# %%
df = df.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)
print(df.shape)
df.head()
# Out:
# (7, 12)
#    id          code                             icon active     group_name  \
# 0   1          MPAY  merchant-group/bill-payment.png      Y    Credit Card
# 1   2         TOPUP               other-payments.png      Y          Topup
# 2   3            RC                         card.png      Y  Recharge Card
# 3   4           WAL                 wallet-topup.png      Y    Load Wallet
# 4   5  DATA_PACKAGE                    data-pack.png      Y   Data Package
#
#    offer_text  sort_order                           description unicode_name  \
# 0         NaN           0  Bill Payment to registered merchants          NaN
# 1         NaN           4                         Topup payment          NaN
# 2         NaN           5    Recharge various recharge vouchers          NaN
# 3         NaN           2                           Load Wallet          NaN
# 4         NaN           6                          Data Package          NaN
#
#    display_position  unicode_description              updated_at
# 0  mainmenu,payment                  NaN 2024-08-07 07:05:25.979
# 1           payment                  NaN 2024-08-07 07:05:25.979
# 2           payment                  NaN 2024-08-07 07:05:25.979
# 3           payment                  NaN 2024-08-07 07:05:25.979
# 4           payment                  NaN 2024-08-07 07:05:25.979

# %%
df.to_csv("merchant_group_masked.csv", index=False)
