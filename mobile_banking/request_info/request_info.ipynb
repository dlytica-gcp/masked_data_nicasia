# %%
import pandas as pd

# %%
df= pd.read_excel("request_info.xlsx")

# %%
df.head()
# Out:
#                          _airbyte_ab_id     _airbyte_emitted_at  id channel  \
# 0  a787dcd8-9ca5-478b-9def-66fddd50f075 2024-08-06 07:20:29.848  94  MOBILE
# 1  4df6a406-2c82-4e22-8105-b7cbc11c0564 2024-08-06 07:20:29.848  95     WEB
# 2  c9f61501-2d57-42b6-84b6-b7bbc3c88668 2024-08-06 07:20:29.848  96  MOBILE
# 3  8750200a-4f9e-48cf-9fd2-548b7ab68a2c 2024-08-06 07:20:29.848  97  MOBILE
# 4  71b79142-115a-4ee4-94d7-db8562efdd2e 2024-08-06 07:20:29.848  98  MOBILE
#
#   is_used  module_id                       booking_id  feature_id  \
# 0       Y        NaN  9J9e=d7zRE7N0kNUNay5JWtYs3EFw==         5.0
# 1       Y        NaN  3qlZcFLwCeuWsx/90ItvTCVGo4f8w==        27.0
# 2       Y        NaN  OY2NiImGgK+ISkYDrOCPNYn/CKv9w==         5.0
# 3       N        NaN  3Mc6mGGpYMQdB+KGdyvMfuXUdp6rw==         4.0
# 4       N        NaN  nXkohxXCwZhfGbi5y++GwQecHe3jQ==         4.0
#
#    merchant_id request_type  \
# 0          NaN       NORMAL
# 1          NaN       NORMAL
# 2          NaN       NORMAL
# 3          1.0       NORMAL
# 4          7.0       NORMAL
#
#                                       requested_date  customer_login_id  \
# 0  Row(member0=Timestamp('2022-03-21 05:57:02'), ...                143
# 1  Row(member0=Timestamp('2022-03-24 03:36:03'), ...                154
# 2  Row(member0=Timestamp('2022-03-24 03:56:00'), ...                157
# 3  Row(member0=Timestamp('2022-03-25 00:59:04'), ...                158
# 4  Row(member0=Timestamp('2022-03-25 01:08:01'), ...                158
#
#   txn_initiate_type  accessible_channel_id  _airbyte_additional_properties  \
# 0               NaN                    2.0                             NaN
# 1               NaN                    2.0                             NaN
# 2               NaN                    2.0                             NaN
# 3               NaN                    2.0                             NaN
# 4               NaN                    2.0                             NaN
#
#                                     source_file_path              updated_at
# 0  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:28.893
# 1  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:28.893
# 2  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:28.893
# 3  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:28.893
# 4  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:28.893

# %%
df = df.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)
df.head()
# Out:
#    id channel is_used  module_id                       booking_id  feature_id  \
# 0  94  MOBILE       Y        NaN  9J9e=d7zRE7N0kNUNay5JWtYs3EFw==         5.0
# 1  95     WEB       Y        NaN  3qlZcFLwCeuWsx/90ItvTCVGo4f8w==        27.0
# 2  96  MOBILE       Y        NaN  OY2NiImGgK+ISkYDrOCPNYn/CKv9w==         5.0
# 3  97  MOBILE       N        NaN  3Mc6mGGpYMQdB+KGdyvMfuXUdp6rw==         4.0
# 4  98  MOBILE       N        NaN  nXkohxXCwZhfGbi5y++GwQecHe3jQ==         4.0
#
#    merchant_id request_type  \
# 0          NaN       NORMAL
# 1          NaN       NORMAL
# 2          NaN       NORMAL
# 3          1.0       NORMAL
# 4          7.0       NORMAL
#
#                                       requested_date  customer_login_id  \
# 0  Row(member0=Timestamp('2022-03-21 05:57:02'), ...                143
# 1  Row(member0=Timestamp('2022-03-24 03:36:03'), ...                154
# 2  Row(member0=Timestamp('2022-03-24 03:56:00'), ...                157
# 3  Row(member0=Timestamp('2022-03-25 00:59:04'), ...                158
# 4  Row(member0=Timestamp('2022-03-25 01:08:01'), ...                158
#
#   txn_initiate_type  accessible_channel_id              updated_at
# 0               NaN                    2.0 2024-08-07 07:05:28.893
# 1               NaN                    2.0 2024-08-07 07:05:28.893
# 2               NaN                    2.0 2024-08-07 07:05:28.893
# 3               NaN                    2.0 2024-08-07 07:05:28.893
# 4               NaN                    2.0 2024-08-07 07:05:28.893

# %%
df.to_csv("request_info_masked.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.to_csv("request_info_masked.csv", index=False)
#
# NameError: name 'df' is not defined
