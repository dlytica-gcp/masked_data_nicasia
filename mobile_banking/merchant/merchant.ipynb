# %%
import pandas as pd

# %%
df=  pd.read_excel("merchant.xlsx")
df.head()
# Out:
#                          _airbyte_ab_id     _airbyte_emitted_at  id  \
# 0  b9af1738-a102-4442-9f75-fe8757d71b63 2024-08-06 07:20:29.848   2
# 1  2beb3769-67ce-4711-b72b-d19e810697d9 2024-08-06 07:20:29.848   3
# 2  7568ff19-3dee-45b0-a05d-09232d0ca9b3 2024-08-06 07:20:29.848   4
# 3  de61545c-da20-4358-8782-2777e997f1da 2024-08-06 07:20:29.848   5
# 4  2a5594cf-14e4-4951-8be9-4d45b7bb3d90 2024-08-06 07:20:29.848   6
#
#                  icon active mnemonic has_limit  created_by  offer_text  \
# 0             ntc.png      Y    NTPOS         Y           1         NaN
# 1           ncell.png      Y    NCELL         Y           1         NaN
# 2      esewa-icon.png      Y    ESEWA         Y           1         NaN
# 3  fonepay-direct.png      Y    FPIBT         N           1         NaN
# 4  fonepay-direct.png      Y     FPMP         N           1         NaN
#
#    service_id  ...  payable_limit_type account_branch_code  \
# 0          10  ...                   F                   0
# 1           8  ...                   R                   0
# 2          26  ...                   R                   1
# 3           4  ...                   R                   1
# 4           5  ...                   R                   0
#
#    redirect_to_fonepay        merchant_description allow_counter_payment  \
# 0                    N           NT Postpaid Topup                     N
# 1                    N                 Ncell Topup                     N
# 2                    N                  eSewa Load                     N
# 3                    N  Fonepay InterBank Transfer                     N
# 4                    N    Fonepay Merchant Payment                     N
#
#   merchant_category_code_id  unicode_merchant_description  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
#
#   _airbyte_additional_properties  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
#                                     source_file_path              updated_at
# 0  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:25.427
# 1  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:25.427
# 2  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:25.427
# 3  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:25.427
# 4  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:25.427
#
# [5 rows x 38 columns]

# %%
df = df.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)
print(df.shape)
df.head()
# Out:
# (50, 34)
#    id                icon active mnemonic has_limit  created_by  offer_text  \
# 0   2             ntc.png      Y    NTPOS         Y           1         NaN
# 1   3           ncell.png      Y    NCELL         Y           1         NaN
# 2   4      esewa-icon.png      Y    ESEWA         Y           1         NaN
# 3   5  fonepay-direct.png      Y    FPIBT         N           1         NaN
# 4   6  fonepay-direct.png      Y     FPMP         N           1         NaN
#
#    service_id  sort_order                                        instruction  \
# 0          10           3  Please enter your NT Postpaid mobile number an...
# 1           8           4  Please enter your NCELL Mobile Number and sele...
# 2          26           1  Please enter your Esewa Id, select amount and ...
# 3           4           2                                                NaN
# 4           5           3                                                NaN
#
#    ...  merchant_group_id                                 last_modified_date  \
# 0  ...                2.0  Row(member0=Timestamp('2019-02-01 08:32:11'), ...
# 1  ...                2.0  Row(member0=Timestamp('2019-02-01 08:31:59'), ...
# 2  ...                4.0  Row(member0=Timestamp('2018-11-11 13:21:38'), ...
# 3  ...                1.0                                                NaN
# 4  ...                1.0                                                NaN
#
#   payable_limit_type account_branch_code  redirect_to_fonepay  \
# 0                  F                   0                    N
# 1                  R                   0                    N
# 2                  R                   1                    N
# 3                  R                   1                    N
# 4                  R                   0                    N
#
#          merchant_description allow_counter_payment  \
# 0           NT Postpaid Topup                     N
# 1                 Ncell Topup                     N
# 2                  eSewa Load                     N
# 3  Fonepay InterBank Transfer                     N
# 4    Fonepay Merchant Payment                     N
#
#    merchant_category_code_id unicode_merchant_description  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# 3                        NaN                          NaN
# 4                        NaN                          NaN
#
#                updated_at
# 0 2024-08-07 07:05:25.427
# 1 2024-08-07 07:05:25.427
# 2 2024-08-07 07:05:25.427
# 3 2024-08-07 07:05:25.427
# 4 2024-08-07 07:05:25.427
#
# [5 rows x 34 columns]

# %%
df.to_csv("merchant_masked.csv", index=False)
