# %%
import pandas as pd

# %%
df = pd.read_excel('customer.xlsx')
df.head()
# Out:
#                          _airbyte_ab_id     _airbyte_emitted_at  id mode  \
# 0  6a217085-3135-4346-8451-937db55103eb 2024-08-06 07:20:29.848  22    A
# 1  fcb56071-cccc-44a4-b042-9fa40fe29aef 2024-08-06 07:20:29.848  23    A
# 2  0d57bfe3-6119-4c7d-a9bb-a1dbaab3a856 2024-08-06 07:20:29.848  24    A
# 3  78353f8c-7f6d-487c-84f2-e108a6c11dd8 2024-08-06 07:20:29.848  25    A
# 4  53ddb137-76db-4f05-ae8c-a80347505198 2024-08-06 07:20:29.848  26    A
#
#   active     cbs_id gender                 address approved  language  ...  \
# 0      D  019898447      M  JUREPI GALLI-14 HN:239        D       NaN  ...
# 1      D  R00745672      M             DANFE MARGA        D       NaN  ...
# 2      D  R00858406      M                  IMADOL        D       NaN  ...
# 3      D  R00108041      M             BATISPUTALI        D       NaN  ...
# 4      D  R00842883      M                 CHYASAL        D       NaN  ...
#
#   last_modified_date                              deleted_approved_date  \
# ...

# %%
df.shape
# Out:
# (1280, 54)

# %%
df = df.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)
df.head()
# Out:
#    id mode active     cbs_id gender                 address approved  \
# 0  22    A      D  019898447      M  JUREPI GALLI-14 HN:239        D
# 1  23    A      D  R00745672      M             DANFE MARGA        D
# 2  24    A      D  R00858406      M                  IMADOL        D
# 3  25    A      D  R00108041      M             BATISPUTALI        D
# 4  26    A      D  R00842883      M                 CHYASAL        D
#
#    language qr_login ac_holder  ...  delete_approved_by edit_approved_date  \
# 0       NaN        N         Y  ...                 4.0                NaN
# 1       NaN        N         Y  ...                 5.0                NaN
# 2       NaN        N         Y  ...                 4.0                NaN
# 3       NaN        N         Y  ...                 4.0                NaN
# 4       NaN        N         Y  ...                 4.0                NaN
#
#    last_modified_date                              deleted_approved_date  \
# ...

# %%
cif_masked = pd.read_csv("../../crmuser/account/cif_masked.csv")
cif_masked.head()
# Out:
#           cif_id     orgkey          cust_first_name cust_middle_name  \
# 0  DLNIND4568821  R01562055                    Duman          Narayan
# 1  DLNIND7235296  R01911512                  Prajina             Devi
# 2  DLNIND1406504  R02944296                Humacanta            Bipin
# 3  DLNLEG6218579  C00038863  KHOTANG FOODS PVT. LTD.              NaN
# 4  DLNIND1255130  R01651971                   Adarsh           Bhakta
#
#   cust_last_name  preferredphone            preferredname  \
# 0        Neupane    9.779830e+12    Duman Narayan Neupane
# 1       Maharjan    9.779890e+12    Prajina Devi Maharjan
# 2          Thapa    9.779860e+12    Humacanta Bipin Thapa
# 3            NaN    9.779860e+12  KHOTANG FOODS PVT. LTD.
# 4           Lama    9.779810e+12       Adarsh Bhakta Lama
#
#                 preferredemail                        email gender  \
# 0           duman492@gmail.com           duman492@gmail.com      M
# ...

# %%
df_org = df[df['cbs_id'].isin(cif_masked['orgkey'])]
df_org.head()
# Out:
#      id mode active     cbs_id gender address approved  language qr_login  \
# 62   84    A      D  R01786441      M     NaN        D       NaN        N
# 63   85    A      D  R01786442      M     NaN        D       NaN        N
# 64   86    A      D  R01786443      M     NaN        D       NaN        N
# 74   96    A      D  R01847463      M     NaN        D       NaN        N
# 80  102    A      D  R01901391      M     NaN        D       NaN        N
#
#    ac_holder  ...  delete_approved_by edit_approved_date  last_modified_date  \
# 62         Y  ...                 NaN                NaN                 NaN
# 63         Y  ...                 NaN                NaN                 NaN
# 64         Y  ...                 NaN                NaN                 NaN
# 74         Y  ...                 4.0                NaN                 NaN
# 80         Y  ...                 1.0                NaN                 NaN
#
# ...

# %%
df[df["cbs_id"] == "R01847463" ].head()
# Out:
#     id mode active     cbs_id gender address approved  language qr_login  \
# 74  96    A      D  R01847463      M     NaN        D       NaN        N
#
#    ac_holder  ...  delete_approved_by edit_approved_date  last_modified_date  \
# 74         Y  ...                 4.0                NaN                 NaN
#
#                                 deleted_approved_date  has_security_question  \
# 74  Row(member0=Timestamp('2022-03-04 02:54:18'), ...                      Y
#
#    last_modified_remarks  latest_changed_mobile  notification_language  \
# 74                   NaN                    NaN                     en
#
#        latest_activity_remarks              updated_at
# 74  Customer Deletion Approved 2024-08-07 07:05:19.896
#
# [1 rows x 50 columns]

# %%
result_df = df.merge(df_org, how='inner', on='cbs_id', suffixes=('_p', '_a'))
result_df.head()
# Out:
#    id_p mode_p active_p     cbs_id gender_p address_p approved_p  language_p  \
# 0    84      A        D  R01786441        M       NaN          D         NaN
# 1    85      A        D  R01786442        M       NaN          D         NaN
# 2    86      A        D  R01786443        M       NaN          D         NaN
# 3    96      A        D  R01847463        M       NaN          D         NaN
# 4   102      A        D  R01901391        M       NaN          D         NaN
#
#   qr_login_p ac_holder_p  ...  delete_approved_by_a edit_approved_date_a  \
# 0          N           Y  ...                   NaN                  NaN
# 1          N           Y  ...                   NaN                  NaN
# 2          N           Y  ...                   NaN                  NaN
# 3          N           Y  ...                   4.0                  NaN
# 4          N           Y  ...                   1.0                  NaN
#
# ...

# %%
result_df.shape
# Out:
# (15, 99)
