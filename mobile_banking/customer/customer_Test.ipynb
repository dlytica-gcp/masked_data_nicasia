# %%
import pandas as pd

# %%
df = pd.read_excel('customer.xlsx') 
df.head()
# Out:
#                          _airbyte_ab_id     _airbyte_emitted_at  id mode  \
# 0  6a217085-3135-4346-8451-937db55103eb 2024-08-06 07:20:29.848  22    A
# 1  fcb56071-cccc-44a4-b042-9fa40fe29aef 2024-08-06 07:20:29.848  23    A
# 2  0d57bfe3-6119-4c7d-a9bb-a1dbaab3a856 2024-08-06 07:20:29.848  24    A
# 3  78353f8c-7f6d-487c-84f2-e108a6c11dd8 2024-08-06 07:20:29.848  25    A
# 4  53ddb137-76db-4f05-ae8c-a80347505198 2024-08-06 07:20:29.848  26    A
#
#   active     cbs_id gender                 address approved  language  ...  \
# 0      D  019898447      M  JUREPI GALLI-14 HN:239        D       NaN  ...
# 1      D  R00745672      M             DANFE MARGA        D       NaN  ...
# 2      D  R00858406      M                  IMADOL        D       NaN  ...
# 3      D  R00108041      M             BATISPUTALI        D       NaN  ...
# 4      D  R00842883      M                 CHYASAL        D       NaN  ...
#
#   last_modified_date                              deleted_approved_date  \
# ...

# %%
df = df.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)
df.head()
# Out:
#    id mode active     cbs_id gender                 address approved  \
# 0  22    A      D  019898447      M  JUREPI GALLI-14 HN:239        D
# 1  23    A      D  R00745672      M             DANFE MARGA        D
# 2  24    A      D  R00858406      M                  IMADOL        D
# 3  25    A      D  R00108041      M             BATISPUTALI        D
# 4  26    A      D  R00842883      M                 CHYASAL        D
#
#    language qr_login ac_holder  ...  delete_approved_by edit_approved_date  \
# 0       NaN        N         Y  ...                 4.0                NaN
# 1       NaN        N         Y  ...                 5.0                NaN
# 2       NaN        N         Y  ...                 4.0                NaN
# 3       NaN        N         Y  ...                 4.0                NaN
# 4       NaN        N         Y  ...                 4.0                NaN
#
#    last_modified_date                              deleted_approved_date  \
# ...

# %%
df["cbs_id"].value_counts()
# Out:
# cbs_id
# 019898447    5
# R30102709    5
# R01958668    3
# R00381058    3
# R00852531    3
#             ..
# R01865799    1
# R01903611    1
# 019855901    1
# R01483611    1
# R50258393    1
# Name: count, Length: 1233, dtype: int64

# %%
df.drop_duplicates(subset=['cbs_id'], inplace=True)
df["cbs_id"].value_counts()
# Out:
# cbs_id
# 019898447    1
# R01418974    1
# R50258449    1
# R30102565    1
# R22141251    1
#             ..
# 019552829    1
# 019561139    1
# 019543293    1
# 019546239    1
# R50258393    1
# Name: count, Length: 1233, dtype: int64

# %%
df=  df.sample(frac=1, random_state=42).reset_index(drop=True)[:125]
print(df.shape)
# Out:
# (125, 50)

# %%
acct = pd.read_csv("../../crmuser/account/account_masked3.csv")
acct["address_line1"].head()
# Out:
# 0     NAYATHIMI
# 1      LAXMIPUR
# 2       GARDUAL
# 3        KHANAR
# 4    TALCHIKHEL
# Name: address_line1, dtype: object

# %%
acct.head(30)
# Out:
#            orgkey                           cust_first_name cust_middle_name  \
# 0   DLNIND4568821                                     Duman          Narayan
# 1   DLNIND7235296                                   Prajina             Devi
# 2   DLNIND1406504                                 Humacanta            Bipin
# 3   DLNLEG6218579                   KHOTANG FOODS PVT. LTD.              NaN
# 4   DLNIND1255130                                    Adarsh           Bhakta
# 5   DLNLEG8980703          KALINCHOWK REAL ESTATE PVT. LTD.              NaN
# 6   DLNIND1498614                                     Keith           Bikram
# 7   DLNLEG9370940            HIMAL DAIRY PRODUCTS PVT. LTD.              NaN
# 8   DLNLEG8767566                EVEREST FOOTWEAR PVT. LTD.              NaN
# 9   DLNIND9286944                                   Veshraj              NaN
# 10  DLNIND3186116                                    Posraj           Bhakta
# ...

# %%
print(len(acct))
# Out:
# 125

# %%
df["last_name"] = acct['cust_last_name'].values
df["first_name"] = acct['cust_first_name'].values
df["email_address"] = acct['email'].values
df["contact_no"] = acct['preferredphone'].values
df["mobile_number"] = acct['preferredphone'].values
df["cbs_id"] = acct['orgkey'].values
df["gender"] = acct['gender'].values
df["address"] = acct['address_line1'].values
df["middle_name"] = acct['cust_middle_name'].values

# %%
df[['mobile_number',"last_name",'contact_no','email_address','mobile_number','gender','first_name']].head(30)
# Out:
#     mobile_number last_name  contact_no  \
# 0      9833329213   Neupane  9833329213
# 1      9892306612  Maharjan  9892306612
# 2      9856817476     Thapa  9856817476
# 3      9862720425       NaN  9862720425
# 4      9810012680      Lama  9810012680
# 5      9837429964       NaN  9837429964
# 6      9850582125       Rai  9850582125
# 7      9899755984       NaN  9899755984
# 8      9863342315       NaN  9863342315
# 9      9861674997   Mainali  9861674997
# 10     9894972060     Dahal  9894972060
# 11     9892029057       NaN  9892029057
# 12     9822084112     Regmi  9822084112
# 13     9846479864       NaN  9846479864
# 14     9813378723      Rana  9813378723
# 15     9863483293       NaN  9863483293
# 16     9857074601  Adhikari  9857074601
# 17     9848709913       NaN  9848709913
# 18     9891240526   Neupane  9891240526
# 19     9884583727       NaN  9884583727
# 20     9898516491    Sharma  9898516491
# 21     9850585226       NaN  9850585226
# ...

# %%
df.to_csv("customer_masked_final.csv", index=False)
