# %%
import pandas as pd

# %%
df = pd.read_csv('customer_masked_final.csv')
df.head()
# Out:
#     id              mode active         cbs_id gender     address approved  \
# 0  809              BULK      Y  DLNIND4568821      M   NAYATHIMI        Y
# 1  638              BULK      Y  DLNIND7235296      F    LAXMIPUR        Y
# 2  604              BULK      Y  DLNIND1406504      M     GARDUAL        Y
# 3  154            MANUAL      Y  DLNLEG6218579    NaN      KHANAR        Y
# 4  225  WEB_REGISTRATION      Y  DLNIND1255130      M  TALCHIKHEL        Y
#
#    language qr_login ac_holder  ...  delete_approved_by edit_approved_date  \
# 0       NaN        N         Y  ...                 NaN                NaN
# 1       NaN        N         Y  ...                 NaN                NaN
# 2       NaN        N         Y  ...                 NaN                NaN
# 3       NaN        N         Y  ...                 NaN                NaN
# 4       NaN        N         Y  ...                 NaN                NaN
#
# ...

# %%
df_cus = df[df["cbs_id"].str.startswith("DLNIND")]
df_cus.head(50)
# Out:
#       id                 mode active         cbs_id gender  \
# 0    809                 BULK      Y  DLNIND4568821      M
# 1    638                 BULK      Y  DLNIND7235296      F
# 2    604                 BULK      Y  DLNIND1406504      M
# 4    225     WEB_REGISTRATION      Y  DLNIND1255130      M
# 6    365                 BULK      Y  DLNIND1498614      M
# 9   1112                 BULK      Y  DLNIND9286944      M
# 10  1229                 BULK      Y  DLNIND3186116      M
# 12   827                 BULK      Y  DLNIND2287753      F
# 14   471                 BULK      Y  DLNIND5601256      M
# 16   665                 BULK      Y  DLNIND2830344      F
# 18   388                 BULK      Y  DLNIND7537080      M
# 20   546                 BULK      Y  DLNIND6814583      F
# 22  1132                 BULK      Y  DLNIND2622447      M
# 23   177  MOBILE_REGISTRATION      Y  DLNIND4157875      M
# 24   147     WEB_REGISTRATION      Y  DLNIND8212211      F
# ...

# %%
df_cus.shape
# Out:
# (71, 50)

# %%
df_cus.to_csv('super_final_customer.csv', index=False)
