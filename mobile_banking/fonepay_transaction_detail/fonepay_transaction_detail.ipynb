# %%
import pandas as pd

# %%
df=  pd.read_excel("fonepay_transaction_detail.xlsx")

# %%
df.head()
# Out:
#                          _airbyte_ab_id     _airbyte_emitted_at  id  \
# 0  59d267c1-6ad3-40fc-99f6-645216231d27 2024-08-06 07:20:29.848   1
# 1  3c9feb78-ec3f-4612-b80b-e797d928fcf9 2024-08-06 07:20:29.848   2
# 2  ea076d84-3f3e-466a-ba8e-148290d0eb76 2024-08-06 07:20:29.848   3
# 3  d6421b60-6580-4abd-8712-9f5e05a32611 2024-08-06 07:20:29.848   4
# 4  e3be9245-a3dd-4f25-8442-e3e0c52c48dc 2024-08-06 07:20:29.848   5
#
#    mti_number  initiated_by   txn_trace_id  fonepay_charge  fonepay_status  \
# 0         NaN           NaN            NaN             NaN               7
# 1         NaN           NaN            NaN             NaN               7
# 2  12345678.0           NaN  GLBBNPKA:2875            10.0               1
# 3  12345678.0           NaN  GLBBNPKA:2962            10.0               1
# 4  12345678.0           NaN  GLBBNPKA:2963            10.0               1
#
#    initiated_date  request_info_id  ...  fonepay_service_code  \
# ...
