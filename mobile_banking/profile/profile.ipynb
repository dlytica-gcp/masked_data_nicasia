# %%
import pandas as pd

# %%
df = pd.read_excel("profile.xlsx")
df.head()
# Out:
#                          _airbyte_ab_id     _airbyte_emitted_at  id  \
# 0  21eec519-01e3-484d-b874-c643e78521e8 2024-08-06 07:20:29.848   1
# 1  e9ad0922-e33b-4326-ab9d-7a0712097571 2024-08-06 07:20:29.848   2
# 2  b500d744-a29b-4208-88d9-24ea3a804edd 2024-08-06 07:20:29.848   3
# 3  8205db95-d0f7-4afa-ba74-21f27c02892e 2024-08-06 07:20:29.848   4
# 4  6a2ed706-c7d0-41e0-b05f-d5aad765020c 2024-08-06 07:20:29.848   5
#
#                    code active  remarks  created_by  \
# 0               AllRole      Y  AllRole         NaN
# 1             All Staff      Y      NaN         1.0
# 2           kyc profile      Y      NaN         1.0
# 3  Non Kyc Lite Account      Y      NaN         1.0
# 4      Kyc Lite Account      Y      NaN         1.0
#
#                                         created_date  migration_id  \
# 0  Row(member0=Timestamp('2020-02-24 05:45:00'), ...           NaN
# 1  Row(member0=Timestamp('2021-11-01 20:08:40'), ...           NaN
# 2  Row(member0=Timestamp('2022-02-10 11:36:22'), ...           NaN
# 3  Row(member0=Timestamp('2022-02-28 09:50:54'), ...           NaN
# 4  Row(member0=Timestamp('2022-02-28 09:55:17'), ...           NaN
#
#            profile_name    profile_type  old_profile_id  last_modified_by  \
# 0               AllRole    ROLE_PROFILE             1.0               1.0
# 1             All Staff  MODULE_PROFILE             NaN               1.0
# 2           kyc profile  MODULE_PROFILE             NaN               NaN
# 3  Non Kyc Lite Account  MODULE_PROFILE             NaN               NaN
# 4      Kyc Lite Account  MODULE_PROFILE             NaN               NaN
#
#                                   last_modified_date   profile_description  \
# 0  Row(member0=Timestamp('2022-03-26 04:08:54'), ...               AllRole
# 1  Row(member0=Timestamp('2024-02-11 15:58:37'), ...             All Staff
# 2                                                NaN                   NaN
# 3                                                NaN  Non Kyc Lite Account
# 4                                                NaN     Kyc Lite Account
#
#    _airbyte_additional_properties  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#                                     source_file_path              updated_at
# 0  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:27.612
# 1  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:27.612
# 2  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:27.612
# 3  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:27.612
# 4  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:27.612

# %%
df = df.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)
print(df.shape)
df.head()
# Out:
# (52, 14)
#    id                  code active  remarks  created_by  \
# 0   1               AllRole      Y  AllRole         NaN
# 1   2             All Staff      Y      NaN         1.0
# 2   3           kyc profile      Y      NaN         1.0
# 3   4  Non Kyc Lite Account      Y      NaN         1.0
# 4   5      Kyc Lite Account      Y      NaN         1.0
#
#                                         created_date  migration_id  \
# 0  Row(member0=Timestamp('2020-02-24 05:45:00'), ...           NaN
# 1  Row(member0=Timestamp('2021-11-01 20:08:40'), ...           NaN
# 2  Row(member0=Timestamp('2022-02-10 11:36:22'), ...           NaN
# 3  Row(member0=Timestamp('2022-02-28 09:50:54'), ...           NaN
# 4  Row(member0=Timestamp('2022-02-28 09:55:17'), ...           NaN
#
#            profile_name    profile_type  old_profile_id  last_modified_by  \
# 0               AllRole    ROLE_PROFILE             1.0               1.0
# 1             All Staff  MODULE_PROFILE             NaN               1.0
# 2           kyc profile  MODULE_PROFILE             NaN               NaN
# 3  Non Kyc Lite Account  MODULE_PROFILE             NaN               NaN
# 4      Kyc Lite Account  MODULE_PROFILE             NaN               NaN
#
#                                   last_modified_date   profile_description  \
# 0  Row(member0=Timestamp('2022-03-26 04:08:54'), ...               AllRole
# 1  Row(member0=Timestamp('2024-02-11 15:58:37'), ...             All Staff
# 2                                                NaN                   NaN
# 3                                                NaN  Non Kyc Lite Account
# 4                                                NaN     Kyc Lite Account
#
#                updated_at
# 0 2024-08-07 07:05:27.612
# 1 2024-08-07 07:05:27.612
# 2 2024-08-07 07:05:27.612
# 3 2024-08-07 07:05:27.612
# 4 2024-08-07 07:05:27.612

# %%
df.to_csv("profile_masked.csv", index=False)
