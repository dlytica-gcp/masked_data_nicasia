# %%
import pandas as pd

# %%
df = pd.read_csv('bank_account_masked_final.csv')
df.head()
# Out:
#    id active  added_by  branch_id  \
# 0   1      Y       1.0          2
# 1   2      Y       1.0          2
# 2   3      Y       1.0          2
# 3   4      D       1.0          2
# 4   5      D       1.0          2
#
#                                           added_date is_primary  \
# 0  Row(member0=Timestamp('2022-03-20 06:07:12'), ...          Y
# 1  Row(member0=Timestamp('2022-03-20 06:15:00'), ...          Y
# 2  Row(member0=Timestamp('2022-03-20 22:32:36'), ...          Y
# 3  Row(member0=Timestamp('2022-03-20 22:48:10'), ...          Y
# 4  Row(member0=Timestamp('2022-03-20 22:48:10'), ...          Y
#
#                                           renew_date card_number  charge_code  \
# 0  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN            0
# 1  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN            0
# 2  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN            0
# ...

# %%
df_cus = df[df["account_owner_cbs_id"].str.startswith("DLNIND")]
df_cus.head(50)
# Out:
#       id active  added_by  branch_id  \
# 0      1      Y       1.0          2
# 1      2      Y       1.0          2
# 2      3      Y       1.0          2
# 5      6      D       1.0          2
# 7      8      Y       1.0          2
# 10    11      Y       1.0          2
# 11    12      D       1.0          2
# 15    17      Y       1.0          1
# 17    19      Y       1.0          2
# 18    20      Y       1.0          2
# 19    21      Y       1.0          4
# 20    22      Y       1.0          2
# 23    25      Y       1.0          2
# 25    27      Y       1.0          1
# 35    37      Y       9.0         24
# 36    38      Y       1.0         98
# 37    39      Y       1.0        333
# 38    40      Y       1.0        320
# 39    41      Y       1.0         49
# 40    42      Y       1.0        177
# 41    43      Y       1.0        300
# 60    62      Y       1.0        177
# 61    63      Y       1.0        173
# 62    64      Y       1.0         79
# ...

# %%
df_cus.to_csv('super_final_bank_account.csv', index=False)
