# %%
import pandas as pd

# %%
df = pd.read_excel('bank_account.xlsx')
df.head()
# Out:
#                          _airbyte_ab_id     _airbyte_emitted_at  id active  \
# 0  7098e1bc-718d-4ea3-bad1-7cff26834913 2024-08-06 07:20:29.848   1      Y
# 1  5f033c1d-c424-4144-9078-f5b912388e61 2024-08-06 07:20:29.848   2      Y
# 2  7f6799f3-647f-4e6f-9bd5-4c799470f7fb 2024-08-06 07:20:29.848   3      Y
# 3  bd374e3c-8095-4c29-90af-d72ec6fbb839 2024-08-06 07:20:29.848   4      D
# 4  5d4a8821-fd69-4f9a-8a9a-0d4d2dd4b8d4 2024-08-06 07:20:29.848   5      D
#
#    added_by  branch_id                                         added_date  \
# 0       1.0          2  Row(member0=Timestamp('2022-03-20 06:07:12'), ...
# 1       1.0          2  Row(member0=Timestamp('2022-03-20 06:15:00'), ...
# 2       1.0          2  Row(member0=Timestamp('2022-03-20 22:32:36'), ...
# 3       1.0          2  Row(member0=Timestamp('2022-03-20 22:48:10'), ...
# 4       1.0          2  Row(member0=Timestamp('2022-03-20 22:48:10'), ...
#
# ...

# %%
df = df.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)
df.head()
# Out:
#    id active  added_by  branch_id  \
# 0   1      Y       1.0          2
# 1   2      Y       1.0          2
# 2   3      Y       1.0          2
# 3   4      D       1.0          2
# 4   5      D       1.0          2
#
#                                           added_date is_primary  \
# 0  Row(member0=Timestamp('2022-03-20 06:07:12'), ...          Y
# 1  Row(member0=Timestamp('2022-03-20 06:15:00'), ...          Y
# 2  Row(member0=Timestamp('2022-03-20 22:32:36'), ...          Y
# 3  Row(member0=Timestamp('2022-03-20 22:48:10'), ...          Y
# 4  Row(member0=Timestamp('2022-03-20 22:48:10'), ...          Y
#
#                                           renew_date card_number  charge_code  \
# 0  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN            0
# 1  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN            0
# 2  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN            0
# ...

# %%
df.drop_duplicates(subset=['account_number'], inplace=True)
df.head()
# Out:
#    id active  added_by  branch_id  \
# 0   1      Y       1.0          2
# 1   2      Y       1.0          2
# 2   3      Y       1.0          2
# 3   4      D       1.0          2
# 4   5      D       1.0          2
#
#                                           added_date is_primary  \
# 0  Row(member0=Timestamp('2022-03-20 06:07:12'), ...          Y
# 1  Row(member0=Timestamp('2022-03-20 06:15:00'), ...          Y
# 2  Row(member0=Timestamp('2022-03-20 22:32:36'), ...          Y
# 3  Row(member0=Timestamp('2022-03-20 22:48:10'), ...          Y
# 4  Row(member0=Timestamp('2022-03-20 22:48:10'), ...          Y
#
#                                           renew_date card_number  charge_code  \
# 0  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN            0
# 1  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN            0
# 2  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN            0
# ...

# %%
for_acid = pd.read_csv("../../tbaadm/general_acct_mast_table/acid_foracid_masked.csv")
for_acid.head()
# Out:
#          acid      acid_t         cif_id           foracid  \
# 0   Q39620558  AC10370877  DLNIND1406504  2635752944296001
# 1  Y110180600  AC41672289  DLNIND4211643  3414659520992004
# 2   O93531058  AC73584145  DLNIND4211643  O987952099252401
# 3    32559774  AC12345718  DLNLEG9334212  3241157797524004
# 4   889280082  AC47235600  DLNLEG6576494  0884459092002067
#
#             foracid_t           pan      acct_num                   acct_name
# 0  FA9627239668220084  PAN668645879  272396682200       Humacanta Bipin Thapa
# 1  FA3302344775994664  PAN697945863   23447759946          Sriti Kumari Thapa
# 2  FA5553585851915269  PAN697945863  535858519152          Sriti Kumari Thapa
# 3  FA2582732553674743  PAN353089449  827325536747  PALPA HEALTHCARE PVT. LTD.
# 4  FA7171012596574289  PAN813377590  710125965742                         NaN

# %%
result = pd.merge(df, for_acid, left_on='account_number', right_on='foracid', how='left')

# %%
result.head(49)
# Out:
#     id active  added_by  branch_id  \
# 0    1      Y       1.0          2
# 1    2      Y       1.0          2
# 2    3      Y       1.0          2
# 3    4      D       1.0          2
# 4    5      D       1.0          2
# 5    6      D       1.0          2
# 6    7      Y       1.0          1
# 7    8      Y       1.0          2
# 8    9      Y       1.0          2
# 9   10      Y       1.0          1
# 10  11      Y       1.0          2
# 11  12      D       1.0          2
# 12  13      Y       1.0          2
# 13  14      Y       1.0          2
# 14  15      Y       1.0          2
# 15  17      Y       1.0          1
# 16  18      Y       1.0          2
# 17  19      Y       1.0          2
# 18  20      Y       1.0          2
# 19  21      Y       1.0          4
# 20  22      Y       1.0          2
# 21  23      Y       1.0         49
# 22  24      Y       1.0          1
# 23  25      Y       1.0          2
# 24  26      Y       1.0          2
# ...

# %%
print(result.shape)
# Out:
# (1172, 44)

# %%
df["account_number"] = result["account_number"]

# %%
df['account_number'].value_counts().reset_index().head(20)
# Out:
#       account_number  count
# 0   0535751911522001      1
# 1   01ST032966NPR001      1
# 2   0151952777524001      1
# 3   0151374471524001      1
# 4   0151877758524001      1
# 5   0151893452524001      1
# 6   0104257808524001      1
# 7   01ST044333NPR001      1
# 8   0151155247524002      1
# 9   0151411409524001      1
# 10  0151065663524002      1
# 11  0151397799524001      1
# 12  0014351396688009      1
# 13  0151329528524001      1
# 14  01ST073713NPR001      1
# 15  01ST052513NPR001      1
# 16  01ST034480NPR001      1
# 17  0151486334524001      1
# 18  0151400539524002      1
# 19  0151443332524002      1

# %%
df_test=  pd.read_csv('bank_account_masked.csv')
df_test["account_owner_cbs_id"].values.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 df_test=  pd.read_csv('bank_account_masked.csv')
# ----> 2 df_test["account_owner_cbs_id"].values.count()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'count'

# %%
df['account_owner_cbs_id'].value_counts().reset_index().head(20)
# Out:
#    account_owner_cbs_id  count
# 0             R30102709      7
# 1             R29927923      7
# 2             R00801157      3
# 3             R02127905      3
# 4             019665905      3
# 5             010000033      3
# 6             R01397120      2
# 7             010000094      2
# 8             R01031299      2
# 9             019533819      2
# 10            R01461288      2
# 11            R01001548      2
# 12            R00313493      2
# 13            R01916827      2
# 14            R01393648      2
# 15            R01396130      2
# 16            R01032966      1
# 17            R01329528      1
# 18            R08065663      1
# 19            R01397799      1
