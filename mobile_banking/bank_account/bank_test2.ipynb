# %%
import pandas as pd

# %%
df = pd.read_csv('bank_account_masked.csv')

# %%
df.head()
# Out:
#      id active  added_by  branch_id  \
# 0   320      Y       1.0          1
# 1  1197      N       1.0          1
# 2   908      Y       1.0          1
# 3    87      Y       1.0          1
# 4   937      Y       1.0          1
#
#                                           added_date is_primary  \
# 0  Row(member0=Timestamp('2022-12-14 10:09:32'), ...          Y
# 1  Row(member0=Timestamp('2023-04-03 11:38:09'), ...          N
# 2  Row(member0=Timestamp('2022-12-14 10:09:32'), ...          Y
# 3  Row(member0=Timestamp('2022-04-12 23:51:15'), ...          Y
# 4  Row(member0=Timestamp('2022-12-14 10:09:32'), ...          Y
#
#                                           renew_date card_number  charge_code  \
# 0  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN            0
# 1  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN            0
# 2  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN            0
# ...

# %%
df['account_number'].value_counts().reset_index().head(20)
# Out:
#         account_number  count
# 0   FA2585798066934693      9
# 1   FA5189714263282277      9
# 2   FA8416326642901529      9
# 3   FA4216350869660382      8
# 4   FA9785210407123574      8
# 5   FA1857528018019354      8
# 6   FA6647687348506680      8
# 7   FA9437626959149272      7
# 8   FA5980607832339199      7
# 9   FA9068020910573944      6
# 10  FA7242713779079212      6
# 11  FA7473415353044639      6
# 12  FA8421606189374923      6
# 13  FA2303230787590244      6
# 14  FA3843045759027013      6
# 15  FA1513019623323879      6
# 16  FA5349566606347525      6
# 17  FA2497356325397065      5
# 18  FA9592523941647640      5
# 19  FA8206904562199527      5
