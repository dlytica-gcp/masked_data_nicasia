# %%
import pandas as pd

# %%
df = pd.read_excel('bank_account.xlsx')
df.head()
# Out:
#                          _airbyte_ab_id     _airbyte_emitted_at  id active  \
# 0  7098e1bc-718d-4ea3-bad1-7cff26834913 2024-08-06 07:20:29.848   1      Y
# 1  5f033c1d-c424-4144-9078-f5b912388e61 2024-08-06 07:20:29.848   2      Y
# 2  7f6799f3-647f-4e6f-9bd5-4c799470f7fb 2024-08-06 07:20:29.848   3      Y
# 3  bd374e3c-8095-4c29-90af-d72ec6fbb839 2024-08-06 07:20:29.848   4      D
# 4  5d4a8821-fd69-4f9a-8a9a-0d4d2dd4b8d4 2024-08-06 07:20:29.848   5      D
#
#    added_by  branch_id                                         added_date  \
# 0       1.0          2  Row(member0=Timestamp('2022-03-20 06:07:12'), ...
# 1       1.0          2  Row(member0=Timestamp('2022-03-20 06:15:00'), ...
# 2       1.0          2  Row(member0=Timestamp('2022-03-20 22:32:36'), ...
# 3       1.0          2  Row(member0=Timestamp('2022-03-20 22:48:10'), ...
# 4       1.0          2  Row(member0=Timestamp('2022-03-20 22:48:10'), ...
#
#   is_primary                                         renew_date card_number  \
# 0          Y  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN
# 1          Y  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN
# 2          Y  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN
# 3          Y  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN
# 4          Y  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN
#
#    ...  charge_deduct_date  last_modified_date service_block_date  \
# 0  ...                 NaN                 NaN                NaN
# 1  ...                 NaN                 NaN                NaN
# 2  ...                 NaN                 NaN                NaN
# 3  ...                 NaN                 NaN                NaN
# 4  ...                 NaN                 NaN                NaN
#
#       account_holder_name  old_bank_account_id account_owner_cbs_id  \
# 0     RASHIM N DHAUBANJAR                  NaN            R01911522
# 1  HARI BAHADUR ALE MAGAR                  NaN            R27057898
# 2               RIMA K.C.                  NaN            R02552347
# 3      DAMODAR N BHANDARI                  NaN            R01916822
# 4      DAMODAR N BHANDARI                  NaN            R01916821
#
#    allow_foreign_currency_txn _airbyte_additional_properties  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
# 3                         NaN                            NaN
# 4                         NaN                            NaN
#
#                                     source_file_path              updated_at
# 0  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:19.210
# 1  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:19.210
# 2  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:19.210
# 3  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:19.210
# 4  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:19.210
#
# [5 rows x 40 columns]

# %%
df = df.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)
df.head()
# Out:
#    id active  added_by  branch_id  \
# 0   1      Y       1.0          2
# 1   2      Y       1.0          2
# 2   3      Y       1.0          2
# 3   4      D       1.0          2
# 4   5      D       1.0          2
#
#                                           added_date is_primary  \
# 0  Row(member0=Timestamp('2022-03-20 06:07:12'), ...          Y
# 1  Row(member0=Timestamp('2022-03-20 06:15:00'), ...          Y
# 2  Row(member0=Timestamp('2022-03-20 22:32:36'), ...          Y
# 3  Row(member0=Timestamp('2022-03-20 22:48:10'), ...          Y
# 4  Row(member0=Timestamp('2022-03-20 22:48:10'), ...          Y
#
#                                           renew_date card_number  charge_code  \
# 0  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN            0
# 1  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN            0
# 2  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN            0
# 3  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN            0
# 4  Row(member0=Timestamp('2024-07-23 11:04:11'), ...         NaN            0
#
#    customer_id  ... is_account_owner last_modified_by  charge_deduct_date  \
# 0          134  ...                Y              NaN                 NaN
# 1          135  ...                Y              NaN                 NaN
# 2          136  ...                Y              NaN                 NaN
# 3          137  ...                Y              NaN                 NaN
# 4          138  ...                Y              NaN                 NaN
#
#   last_modified_date  service_block_date     account_holder_name  \
# 0                NaN                 NaN     RASHIM N DHAUBANJAR
# 1                NaN                 NaN  HARI BAHADUR ALE MAGAR
# 2                NaN                 NaN               RIMA K.C.
# 3                NaN                 NaN      DAMODAR N BHANDARI
# 4                NaN                 NaN      DAMODAR N BHANDARI
#
#   old_bank_account_id account_owner_cbs_id allow_foreign_currency_txn  \
# 0                 NaN            R01911522                        NaN
# 1                 NaN            R27057898                        NaN
# 2                 NaN            R02552347                        NaN
# 3                 NaN            R01916822                        NaN
# 4                 NaN            R01916821                        NaN
#
#                updated_at
# 0 2024-08-07 07:05:19.210
# 1 2024-08-07 07:05:19.210
# 2 2024-08-07 07:05:19.210
# 3 2024-08-07 07:05:19.210
# 4 2024-08-07 07:05:19.210
#
# [5 rows x 36 columns]

# %%
df["account_owner_cbs_id"].value_counts()
# Out:
# account_owner_cbs_id
# R30102709    7
# R29927923    7
# R00801157    3
# R02127905    3
# 019665905    3
#             ..
# R01984712    1
# R01939838    1
# R01946238    1
# R01924247    1
# R02827714    1
# Name: count, Length: 1158, dtype: int64
