# %%
import pandas as pd

# %%
df = pd.read_excel("nps_transaction_detail.xlsx")
df.head()
# Out:
#                          _airbyte_ab_id     _airbyte_emitted_at  id  amount  \
# 0  c63208ee-796c-4c5d-a0b5-7886a3ef961c 2024-08-06 07:20:29.848   1     NaN
# 1  a5544ec8-8082-4201-a232-ae5d1aa9a965 2024-08-06 07:20:29.848   2     NaN
# 2  9bddec56-74a6-4d73-876e-e17439354755 2024-08-06 07:20:29.848   3     NaN
# 3  65899407-d007-4ca1-ab15-7251ea9466bb 2024-08-06 07:20:29.848   4     NaN
# 4  362a38a4-0aec-4859-a225-de501b52d3d6 2024-08-06 07:20:29.848   5     NaN
#
#    trace_id                                           txn_date   bank_code  \
# 0       NaN  Row(member0=Timestamp('2022-10-31 16:06:00'), ...    NICENPKA
# 1       NaN  Row(member0=Timestamp('2022-10-31 16:07:42'), ...    NICENPKA
# 2       NaN  Row(member0=Timestamp('2022-11-06 10:16:08'), ...  FTTESTBANK
# 3       NaN  Row(member0=Timestamp('2022-11-08 16:55:26'), ...  FTTESTBANK
# 4       NaN  Row(member0=Timestamp('2022-11-14 11:17:09'), ...  FTTESTBANK
#
#   is_mobile    to_account      from_account  ... response_code  \
# 0         Y  9.858024e+09  1900000000000131  ...           1.0
# 1         N  1.900000e+15  1900000000000131  ...           1.0
# 2         N  1.900000e+15  1900000000000131  ...           1.0
# 3         N  1.900000e+15  1900000000000131  ...           1.0
# 4         N  1.900000e+15  1900000000000131  ...           1.0
#
#    transaction_id  request_info_id  response_status  merchant_process_id  \
# 0             NaN             2060              4.0             MBT-2060
# 1             NaN             2061              4.0             MBT-2061
# 2             NaN             2098              4.0             MBT-2098
# 3             NaN             2117              4.0             MBT-2117
# 4             NaN             2154              4.0             MBT-2154
#
#           response_description merchant_transaction_id  \
# 0  Contact with error Id 49372                MBT-2060
# 1  Contact with error Id 49373                MBT-2061
# 2                        Error                MBT-2098
# 3                        Error                MBT-2117
# 4                        Error                MBT-2154
#
#   _airbyte_additional_properties  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
#                                     source_file_path              updated_at
# 0  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:26.884
# 1  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:26.884
# 2  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:26.884
# 3  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:26.884
# 4  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:26.884
#
# [5 rows x 22 columns]

# %%
df = df.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)
print(df.shape)
df.head()
# Out:
# (88, 18)
#    id  amount  trace_id                                           txn_date  \
# 0   1     NaN       NaN  Row(member0=Timestamp('2022-10-31 16:06:00'), ...
# 1   2     NaN       NaN  Row(member0=Timestamp('2022-10-31 16:07:42'), ...
# 2   3     NaN       NaN  Row(member0=Timestamp('2022-11-06 10:16:08'), ...
# 3   4     NaN       NaN  Row(member0=Timestamp('2022-11-08 16:55:26'), ...
# 4   5     NaN       NaN  Row(member0=Timestamp('2022-11-14 11:17:09'), ...
#
#     bank_code is_mobile    to_account      from_account currency_code  \
# 0    NICENPKA         Y  9.858024e+09  1900000000000131           NPR
# 1    NICENPKA         N  1.900000e+15  1900000000000131           NPR
# 2  FTTESTBANK         N  1.900000e+15  1900000000000131           NPR
# 3  FTTESTBANK         N  1.900000e+15  1900000000000131           NPR
# 4  FTTESTBANK         N  1.900000e+15  1900000000000131           NPR
#
#    mobile_number  response_code  transaction_id  request_info_id  \
# 0            NaN            1.0             NaN             2060
# 1            NaN            1.0             NaN             2061
# 2            NaN            1.0             NaN             2098
# 3            NaN            1.0             NaN             2117
# 4            NaN            1.0             NaN             2154
#
#    response_status merchant_process_id         response_description  \
# 0              4.0            MBT-2060  Contact with error Id 49372
# 1              4.0            MBT-2061  Contact with error Id 49373
# 2              4.0            MBT-2098                        Error
# 3              4.0            MBT-2117                        Error
# 4              4.0            MBT-2154                        Error
#
#   merchant_transaction_id              updated_at
# 0                MBT-2060 2024-08-07 07:05:26.884
# 1                MBT-2061 2024-08-07 07:05:26.884
# 2                MBT-2098 2024-08-07 07:05:26.884
# 3                MBT-2117 2024-08-07 07:05:26.884
# 4                MBT-2154 2024-08-07 07:05:26.884

# %%
df.to_csv("nps_transaction_detail_masked.csv", index=False)
