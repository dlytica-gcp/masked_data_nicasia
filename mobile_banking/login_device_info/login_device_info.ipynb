# %%
import pandas as pd

# %%
df=  pd.read_excel("login_device_info.xlsx")
df.head()
# Out:
#                          _airbyte_ab_id     _airbyte_emitted_at  id  os_type  \
# 0  fda43d74-e7aa-49bf-a1c9-02e84e585cda 2024-08-06 07:20:29.848   1      iOS
# 1  1ac1a6ad-803c-45ad-9b6e-65fa81f9f325 2024-08-06 07:20:29.848   2      iOS
# 2  978924b1-eaa3-48d2-a200-48999e4dfc26 2024-08-06 07:20:29.848   3      iOS
# 3  a80c9db9-df8f-4069-91d5-c80bf3a88eb7 2024-08-06 07:20:29.848   4  Android
# 4  d7df2b18-44e4-4d06-854c-502a4c40b3ea 2024-08-06 07:20:29.848   5  Android
#
#                               device_id  fcm_web_id  gcm_reg_id version_id  \
# 0  753761C2-3C6F-4903-A449-A87708584633         NaN         NaN      3.0.0
# 1                                   NaN         NaN         NaN      3.0.0
# 2                                   NaN         NaN         NaN      3.0.0
# 3                      389fbd92d8d03ebf         NaN         NaN      3.0.0
# 4  00000000-146f-3c0e-0000-000066c0f7ce         NaN         NaN      3.0.0
#
#    customer_id gcm_enabled  ... last_modified_by  customer_login_id  \
# 0          298           N  ...              NaN                298
# 1          140           N  ...              NaN                140
# 2          149           N  ...              NaN                149
# 3         1313           N  ...              NaN               1313
# 4         1130           N  ...              NaN               1130
#
#    gcm_activation_at  login_device_mode  \
# 0                NaN                  D
# 1                NaN                  D
# 2                NaN                  D
# 3                NaN                  D
# 4                NaN                  D
#
#                                   last_modified_date  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Row(member0=Timestamp('2024-01-30 16:38:53'), ...
# 4                                                NaN
#
#                                 device_extra_details  \
# 0  {"appBuildNumber":"150","iOSVersion":"17.5.1",...
# 1  {"model":"iPhone","manufacturer":"Apple Inc","...
# 2  {"appBuildNumber":"143","appVersion":"6.6.142"...
# 3  {"androidVersion":"14","appVersionCode":"755",...
# 4  {"androidVersion":"8.0.0","appVersionCode":"77...
#
#                                 device_id_updated_at  \
# 0  Row(member0=Timestamp('2024-07-17 10:12:11'), ...
# 1  Row(member0=Timestamp('2024-04-03 13:12:58'), ...
# 2  Row(member0=Timestamp('2024-03-07 10:32:34'), ...
# 3  Row(member0=Timestamp('2024-03-18 12:21:18'), ...
# 4  Row(member0=Timestamp('2024-07-22 14:35:18'), ...
#
#   _airbyte_additional_properties  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
#                                     source_file_path              updated_at
# 0  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:24.929
# 1  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:24.929
# 2  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:24.929
# 3  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:24.929
# 4  s3a://ai360nica/data/bronze/mysql/mobile_banki... 2024-08-07 07:05:24.929
#
# [5 rows x 22 columns]

# %%
df = df.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)
print(df.shape)
df.head()
# Out:
# (44, 18)
#    id  os_type                             device_id  fcm_web_id  gcm_reg_id  \
# 0   1      iOS  753761C2-3C6F-4903-A449-A87708584633         NaN         NaN
# 1   2      iOS                                   NaN         NaN         NaN
# 2   3      iOS                                   NaN         NaN         NaN
# 3   4  Android                      389fbd92d8d03ebf         NaN         NaN
# 4   5  Android  00000000-146f-3c0e-0000-000066c0f7ce         NaN         NaN
#
#   version_id  customer_id gcm_enabled device_model  email_address  \
# 0      3.0.0          298           N          NaN            NaN
# 1      3.0.0          140           N          NaN            NaN
# 2      3.0.0          149           N          NaN            NaN
# 3      3.0.0         1313           N      Android            NaN
# 4      3.0.0         1130           N      Android            NaN
#
#    last_modified_by  customer_login_id  gcm_activation_at login_device_mode  \
# 0               NaN                298                NaN                 D
# 1               NaN                140                NaN                 D
# 2               NaN                149                NaN                 D
# 3               NaN               1313                NaN                 D
# 4               NaN               1130                NaN                 D
#
#                                   last_modified_date  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Row(member0=Timestamp('2024-01-30 16:38:53'), ...
# 4                                                NaN
#
#                                 device_extra_details  \
# 0  {"appBuildNumber":"150","iOSVersion":"17.5.1",...
# 1  {"model":"iPhone","manufacturer":"Apple Inc","...
# 2  {"appBuildNumber":"143","appVersion":"6.6.142"...
# 3  {"androidVersion":"14","appVersionCode":"755",...
# 4  {"androidVersion":"8.0.0","appVersionCode":"77...
#
#                                 device_id_updated_at              updated_at
# 0  Row(member0=Timestamp('2024-07-17 10:12:11'), ... 2024-08-07 07:05:24.929
# 1  Row(member0=Timestamp('2024-04-03 13:12:58'), ... 2024-08-07 07:05:24.929
# 2  Row(member0=Timestamp('2024-03-07 10:32:34'), ... 2024-08-07 07:05:24.929
# 3  Row(member0=Timestamp('2024-03-18 12:21:18'), ... 2024-08-07 07:05:24.929
# 4  Row(member0=Timestamp('2024-07-22 14:35:18'), ... 2024-08-07 07:05:24.929

# %%
df.to_csv("login_device_info_masked.csv", index=False)
