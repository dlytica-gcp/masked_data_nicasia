# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('merchant_reallocation_details.xlsx')
df.head(99)
# Out:
#       _id                          MERCHANT_NAME   PAN_NUMBER  MERCHANT_ID  \
# 0    8568                             N. S STORE  604954956.0     245873.0
# 1    1347  MECHI KRISHI TATHA PASHUPALAN PVT.LTD  606534208.0     245889.0
# 2    1021              A.G.R. INDUSTRIES PVT LTD  605933275.0     246036.0
# 3   17613                 ALL IN ONE COLLECTION.  607238008.0     246326.0
# 4    1351                    N.P.P. FOOD SERVICE  303427586.0     246402.0
# ..    ...                                    ...          ...          ...
# 94  11160                     SHYAM KIRANA STORE  603264344.0     268824.0
# 95  12033        PANCHAKANYA DEVI KATH FURNITURE  606489980.0     269193.0
# 96  15694                   CHAMLING SUPPLIERS..  606096133.0     269203.0
# 97   6435          BHERI BABAI BAKERY KHAJA GHAR  102050570.0     269376.0
# 98  18999                    NEW BASANTA NURSERY  600935054.0     269424.0
#
#     MOBILE_NUMBER  ACQUIRER_NAME  \
# ...

# %%
df = df.drop(["source_file_path"], axis=1)

# %%
df.head()
print(len(df))
# Out:
# 4790

# %%
df.to_csv('merchant_reallocation_details_masked.csv', index=False)
