# %%
import pandas as pd

# %%
df=pd.read_excel("la_int_version_slab_table.xlsx")
df.head()
# Out:
#    ts_cnt  bank_id del_flg            lchg_time            rcre_time  \
# 0       1        1       N  2024-08-18T18:30:19  2024-08-18T18:27:53
# 1       1        1       N  2008-07-17T18:09:03  2008-07-17T18:07:36
# 2       1        1       N  2013-06-25T15:33:24  2013-06-24T18:11:32
# 3       1        1       N  2020-08-18T17:22:14  2020-08-18T17:21:23
# 4       1        1       N  2022-04-21T13:34:40  2022-04-21T13:29:53
#
#   crncy_code int_tbl_code lchg_user_id rcre_user_id  nrml_int_pcnt  ...  \
# 0        NPR        AVGLA       AS6075       SB3610           9.22  ...
# 1        NPR        L6.50     RAJESHKM      ISHWORI           6.50  ...
# 2        NPR        L1225       BAPINR     RAJESHKM          12.25  ...
# 3        NPR        L6.50       SL3843       KA3788           6.50  ...
# 4        NPR        B1278       BJ2774       RK2336           9.39  ...
#
#   penal_portion_ind compound_prnc_pcnt  int_slab_dr_cr_flg  \
# ...

# %%
df.to_csv("la_int_version_slab_table_masked.csv")
