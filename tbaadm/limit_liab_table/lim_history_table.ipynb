# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('limit_liab_table.xlsx')
df.head()
# Out:
#    liab  ts_cnt  bank_id    cust_id del_flg  free_text  \
# 0   0.0      14        1   04006533       N        NaN
# 1   0.0      47        1   30091981       Y        NaN
# 2   0.0      28        1   30091981       Y  REVOLVING
# 3   0.0      48        1   30091981       Y        NaN
# 4   0.0      18        1   30091981       Y        NaN
#
#                     lchg_time            rcre_time   sanct_lim crncy_code  \
# 0         2011-02-08T15:35:40  2010-06-22T16:48:35  15000000.0        NPR
# 1         2014-02-26T11:18:13  2013-07-15T10:59:29  36000000.0        NPR
# 2         2014-02-26T11:18:27  2013-07-03T17:02:31  40000000.0        NPR
# 3  2014-02-26T18:35:00.000000  2013-07-03T17:06:48   1826000.0        NPR
# 4         2014-02-26T18:35:04  2013-07-03T17:24:13  36000000.0        NPR
#
#    ... secd_liab_as_on_purge_date fruct_liab_as_on_purge_date  \
# 0  ...                          0                           0
# ...

# %%
df.to_csv('limit_liab_table_masked.csv', index=False)
