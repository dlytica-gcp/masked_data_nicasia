# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('service_outlet_table.xlsx')
df.head()
# Out:
#                    ADDR_1 ADDR_2  ADDR_3 SDL_ID SOL_ID  TS_CNT  BANK_ID  \
# 0            TRIPURESHWOR    NaN     NaN    ALL     01    8823        1
# 1  NEW ROAD- BISHAL BAZAR    NaN     NaN    ALL     30   30929        1
# 2                  BANEPA    NaN     NaN    ALL     07   64535        1
# 3        BHAKTAPUR BRANCH    NaN     NaN    ALL     08   44284        1
# 4                BIRTAMOD    NaN     NaN    ALL     09   30293        1
#
#   BR_CODE DEL_FLG  DP_CODE  ... INSTRMNT_ENCODE_BLOCK_NUM  \
# 0      01       N      NaN  ...                         0
# 1      30       N      NaN  ...                         0
# 2      07       N      NaN  ...                         0
# 3      08       N      NaN  ...                         0
# 4      09       N      NaN  ...                         0
#
#     LAST_INT_CALC_DATE_FOR_SB  USER_CLG_DR_LIM_EXCP_CODE  \
# 0  2024-07-26T00:00:00.000000                        GU3
# 1  2024-07-26T00:00:00.000000                        GU3
# ...

# %%
df.shape
# Out:
# (722, 126)

# %%
df.drop_duplicates(subset=['SOL_ID'], inplace=True)

# %%
print(len(df))
# Out:
# 361

# %%
df.to_csv('service_outlet_table_masked.csv', index=False)
