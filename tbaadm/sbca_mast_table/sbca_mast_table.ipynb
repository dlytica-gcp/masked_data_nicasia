# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('sbca_mast_table.xlsx')
df.head()
# Out:
#         acid  ts_cnt  bank_id            lchg_time            rcre_time  \
# 0  836531103       7        1  2024-08-14T22:50:16  2021-08-16T16:18:08
# 1  Q04054425      11        1  2024-08-18T21:21:27  2019-02-08T17:08:10
# 2   02179560       0        1  2011-05-16T16:42:09  2011-05-16T16:42:09
# 3   02182520       0        1  2011-06-14T14:20:15  2011-06-14T14:20:15
# 4   02244385       0        1  2013-04-02T15:12:39  2013-04-02T15:12:39
#
#   acct_status health_code lchg_user_id lm_link_stat product_type  ...  \
# 0           A         NaN     FINADMIN                            ...
# 1           A       NORMA     FINADMIN                            ...
# 2           A         NaN    KAUSHILAG          NaN          NaN  ...
# 3           A         NaN    KAUSHILAG          NaN          NaN  ...
# 4           A         NaN    KAUSHILAG          NaN          NaN  ...
#
#   max_alwd_advn_lim payout_on_closure acct_crfile_ref_id  dr_freq_start_date  \
# ...

# %%
print(len(df))
# Out:
# 256

# %%
df_gam = pd.read_csv("../general_acct_mast_table/acid_foracid_masked.csv")
df_gam.head()
# Out:
#          acid      acid_t         cif_id           foracid  \
# 0   Q39620558  AC10370877  DLNIND1406504  2635752944296001
# 1  Y110180600  AC41672289  DLNIND4211643  3414659520992004
# 2   O93531058  AC73584145  DLNIND4211643  O987952099252401
# 3    32559774  AC12345718  DLNLEG9334212  3241157797524004
# 4   889280082  AC47235600  DLNLEG6576494  0884459092002067
#
#             foracid_t           pan      acct_num                   acct_name
# 0  FA9627239668220084  PAN668645879  272396682200       Humacanta Bipin Thapa
# 1  FA3302344775994664  PAN697945863   23447759946          Sriti Kumari Thapa
# 2  FA5553585851915269  PAN697945863  535858519152          Sriti Kumari Thapa
# 3  FA2582732553674743  PAN353089449  827325536747  PALPA HEALTHCARE PVT. LTD.
# 4  FA7171012596574289  PAN813377590  710125965742                         NaN

# %%
result_df = pd.merge(df, df_gam, how='left', on="acid",suffixes=('_p', '_a'))
result_df.head(8)
# Out:
#         acid  ts_cnt  bank_id            lchg_time            rcre_time  \
# 0  836531103       7        1  2024-08-14T22:50:16  2021-08-16T16:18:08
# 1  Q04054425      11        1  2024-08-18T21:21:27  2019-02-08T17:08:10
# 2   02179560       0        1  2011-05-16T16:42:09  2011-05-16T16:42:09
# 3   02182520       0        1  2011-06-14T14:20:15  2011-06-14T14:20:15
# 4   02244385       0        1  2013-04-02T15:12:39  2013-04-02T15:12:39
# 5   02264398       0        1  2013-06-26T15:58:06  2013-06-26T15:58:06
# 6   02264369       0        1  2013-06-26T15:58:06  2013-06-26T15:58:06
# 7   32346317       0        1  2013-06-26T16:08:08  2013-06-26T16:08:08
#
#   acct_status health_code lchg_user_id lm_link_stat product_type  ...  \
# 0           A         NaN     FINADMIN                            ...
# 1           A       NORMA     FINADMIN                            ...
# 2           A         NaN    KAUSHILAG          NaN          NaN  ...
# ...

# %%
df["acid"] = result_df["acid_t"].values
df.head()
# Out:
#          acid  ts_cnt  bank_id            lchg_time            rcre_time  \
# 0  AC41804457       7        1  2024-08-14T22:50:16  2021-08-16T16:18:08
# 1  AC12730210      11        1  2024-08-18T21:21:27  2019-02-08T17:08:10
# 2  AC17610012       0        1  2011-05-16T16:42:09  2011-05-16T16:42:09
# 3  AC30663774       0        1  2011-06-14T14:20:15  2011-06-14T14:20:15
# 4  AC51820040       0        1  2013-04-02T15:12:39  2013-04-02T15:12:39
#
#   acct_status health_code lchg_user_id lm_link_stat product_type  ...  \
# 0           A         NaN     FINADMIN                            ...
# 1           A       NORMA     FINADMIN                            ...
# 2           A         NaN    KAUSHILAG          NaN          NaN  ...
# 3           A         NaN    KAUSHILAG          NaN          NaN  ...
# 4           A         NaN    KAUSHILAG          NaN          NaN  ...
#
#   max_alwd_advn_lim payout_on_closure acct_crfile_ref_id  dr_freq_start_date  \
# ...

# %%
df.to_csv('sbca_mast_table_masked.csv', index=False)
