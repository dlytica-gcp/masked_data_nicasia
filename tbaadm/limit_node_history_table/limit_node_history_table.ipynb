# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('limit_node_history_table.xlsx')
df.head()
# Out:
#    liab  ts_cnt  bank_id                    end_date  cont_liab  \
# 0   0.0       4        1  2009-03-24T00:00:00.000000  1970496.0
# 1   0.0       2        1  2010-06-21T00:00:00.000000        0.0
# 2   0.0       2        1  2010-06-22T00:00:00.000000        0.0
# 3   0.0       1        1  2010-10-03T00:00:00.000000  1209132.5
# 4   0.0       1        1  2010-11-18T00:00:00.000000  1209132.5
#
#              lchg_time            rcre_time  sanct_lim  fruct_liab  \
# 0  2009-03-25T18:51:26  2009-01-25T17:59:23  2060000.0         0.0
# 1  2010-06-22T16:51:49  2009-03-25T18:51:26  2060000.0         0.0
# 2  2010-06-23T12:23:26  2010-06-22T16:51:49  1210000.0         0.0
# 3  2010-10-04T16:03:38  2010-06-23T12:23:26  1210000.0         0.0
# 4  2010-11-19T13:46:06  2010-10-04T16:03:38  1210000.0         0.0
#
#                    start_date  ...  secured_liab treasury_liab  \
# 0  2009-01-25T00:00:00.000000  ...             0           NaN
# ...

# %%
print(len(df))
# Out:
# 1279

# %%
df.to_csv('limit_node_history_table_masked.csv', index=False)
