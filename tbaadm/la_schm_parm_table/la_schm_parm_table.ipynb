# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('la_schm_parm_table.xlsx')
df.head()
# Out:
#    TS_CNT  BANK_ID DEL_FLG  ACCT_TYPE DICGC_FLG EI_METHOD  \
# 0      12        1       Y        NaN         N       NaN
# 1       9        1       Y        NaN         N         R
# 2      10        1       Y        NaN         N         R
# 3      11        1       Y        NaN         N       NaN
# 4       9        1       Y        NaN         N       NaN
#
#              LCHG_TIME            RCRE_TIME SCHM_CODE CRNCY_CODE  ...  \
# 0  2008-01-01T13:43:55  2007-09-16T16:18:27     DLGEN        NPR  ...
# 1  2008-01-01T13:44:52  2007-09-17T12:15:32     TLHLN        NPR  ...
# 2  2008-01-02T19:57:42  2007-09-16T18:03:40     TLVEH        NPR  ...
# 3  2008-07-27T11:50:38  2007-09-16T17:07:04     STLGN        NPR  ...
# 4  2008-07-27T12:00:11  2007-09-16T17:27:41     LTLGN        NPR  ...
#
#    INSUFF_DEFMNT_INTVL_EXCP_CODE  MIN_FCRNCY_DISB_NOT_PERD_DAYS  \
# 0                            NaN                            NaN
# ...

# %%
df.to_csv('la_schm_parm_table_masked.csv', index=False)
