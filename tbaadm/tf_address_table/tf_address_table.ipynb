# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('tf_address_table.xlsx')
df.head()
# Out:
#                                       name  ts_cnt addr_id  bank_id del_flg  \
# 0                        JACKSON & COMPANY       1  DCOTPY        1       N
# 1  SUGAM ROJIN TERPINTINE & HERBAL PVT.LTD       1  DCOUPY        1       N
# 2                                      SCB       1  DCADBK        1       N
# 3                        JACKSON & COMPANY       1  DCOTPY        1       N
# 4                      JACKSON AND COMPANY       1  DCOTPY        1       N
#
#                    address1 address2 address3  bic_code email_id  ...  \
# 0                 NEW DELHI    INDIA      NaN       NaN      NaN  ...
# 1  LABIPUR-06 SUSNARI NEPAL      NaN      NaN       NaN      NaN  ...
# 2                     INDIA      NaN      NaN       NaN      NaN  ...
# 3                 NEW DELHI    INDIA      NaN       NaN      NaN  ...
# 4                 NEW DELHI    INDIA      NaN       NaN      NaN  ...
#
#   addr_b2kid cntry_code state_code sector_code lchg_user_id rcre_user_id  \
# ...

# %%
print(len(df))
# Out:
# 1314

# %%
df.to_csv('tf_address_table_masked.csv', index=False)
