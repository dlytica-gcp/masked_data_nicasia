# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('td_acct_master_table.xlsx')
df.head()
# Out:
#         acid sol_id  ts_cnt  bank_id  tds_amt tran_id  \
# 0   30710934     30      11        1     0.00     NaN
# 1   30741837     30       8        1  6862.50     NaN
# 2  541117291     54       1        1     0.00     NaN
# 3  991102127     99       8        1  5893.23     NaN
# 4  991117375     99       8        1  5909.38     NaN
#
#                     lchg_time  loan_acid                   rcre_time  \
# 0         2014-02-20T10:15:55        NaN         2013-06-27T01:46:53
# 1         2014-11-25T10:37:12        NaN         2013-11-25T18:45:40
# 2  2015-03-04T18:06:00.000000        NaN         2015-03-04T17:04:43
# 3         2016-01-27T22:38:02        NaN         2015-01-28T17:38:43
# 4         2016-03-03T23:44:48        NaN  2015-03-04T18:09:00.000000
#
#    agent_code  ...  anniv_flg_for_compl_cycles auto_renwl_gl_subhead_code  \
# 0         NaN  ...                         NaN                        NaN
# ...

# %%
print(len(df))
# Out:
# 3000

# %%
df_gam = pd.read_csv("../general_acct_mast_table/general_acct_mast_table_masked.csv")
df_gam.head()
# Out:
#          acid         cif_id             foracid      acct_num  \
# 0  AC10370877  DLNIND1406504  FA9627239668220084  272396682200
# 1  AC41672289  DLNIND4211643  FA3302344775994664   23447759946
# 2  AC73584145  DLNIND4211643  FA5553585851915269  535858519152
# 3  AC12345718  DLNLEG9334212  FA2582732553674743  827325536747
# 4  AC47235600  DLNLEG6576494  FA7171012596574289  710125965742
#
#                     acct_name                                 hashed_no  \
# 0       Humacanta Bipin Thapa  C1426B129652A7DB20182EAE18980F1B26D3B17E
# 1          Sriti Kumari Thapa  26B23D96EE13CDC789D531D4CF5839AD1EF73B75
# 2          Sriti Kumari Thapa  B7BDF9D665BAC86A625C32A5726764FB61251A9A
# 3  PALPA HEALTHCARE PVT. LTD.  FF377859485ED6FCE9A354D30C3A9744DE68421C
# 4                         NaN  5654F613A38B19A7130D8A5F217260B16DE305B1
#
#          phone_num            acct_short_name last_tran_id_cr last_tran_id_dr  \
# ...

# %%
result_df = pd.merge(df, df_gam, how='left', on="acid",suffixes=('_p', '_a'))
result_df.head(8)
# Out:
#         acid sol_id_p  ts_cnt_p  bank_id_p  tds_amt tran_id  \
# 0   30710934       30        11          1     0.00     NaN
# 1   30741837       30         8          1  6862.50     NaN
# 2  541117291       54         1          1     0.00     NaN
# 3  991102127       99         8          1  5893.23     NaN
# 4  991117375       99         8          1  5909.38     NaN
# 5  991142044       99         9          1     0.00     NaN
# 6  991163801       99         8          1     0.00     NaN
# 7  991289803       99        11          1     0.00     NaN
#
#                   lchg_time_p  loan_acid                 rcre_time_p  \
# 0         2014-02-20T10:15:55        NaN         2013-06-27T01:46:53
# 1         2014-11-25T10:37:12        NaN         2013-11-25T18:45:40
# 2  2015-03-04T18:06:00.000000        NaN         2015-03-04T17:04:43
# 3         2016-01-27T22:38:02        NaN         2015-01-28T17:38:43
# 4         2016-03-03T23:44:48        NaN  2015-03-04T18:09:00.000000
# ...

# %%
print(len(df))
# Out:
# 3000

# %%
df["acid"] = result_df["acid_t"].values
df.head()
# Out:
#          acid sol_id  ts_cnt  bank_id  tds_amt tran_id  \
# 0  AC85199794     30      11        1     0.00     NaN
# 1  AC56301948     30       8        1  6862.50     NaN
# 2  AC80827638     54       1        1     0.00     NaN
# 3  AC61774333     99       8        1  5893.23     NaN
# 4  AC72688784     99       8        1  5909.38     NaN
#
#                     lchg_time  loan_acid                   rcre_time  \
# 0         2014-02-20T10:15:55        NaN         2013-06-27T01:46:53
# 1         2014-11-25T10:37:12        NaN         2013-11-25T18:45:40
# 2  2015-03-04T18:06:00.000000        NaN         2015-03-04T17:04:43
# 3         2016-01-27T22:38:02        NaN         2015-01-28T17:38:43
# 4         2016-03-03T23:44:48        NaN  2015-03-04T18:09:00.000000
#
#    agent_code  ...  anniv_flg_for_compl_cycles auto_renwl_gl_subhead_code  \
# 0         NaN  ...                         NaN                        NaN
# ...

# %%
df.to_csv('td_acct_master_table_masked.csv', index=False)
