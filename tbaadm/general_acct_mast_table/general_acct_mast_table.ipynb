# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("general_acct_mast_table.xlsx")
df.head()
# Out:
#          acid  bacid     cif_id emp_id sol_id  ts_cnt  bank_id    cust_id  \
# 0   Q39620558    NaN  R02944296    NaN     Q3      69        1  RC2934809
# 1  Y110180600    NaN  O99520992    NaN     Y1       5        1  O99520992
# 2   O93531058    NaN  O99520992    NaN     O9     209        1  O99520992
# 3    32559774    NaN  R32157797    NaN     32   10720        1   32157797
# 4   889280082    NaN  R09092002    NaN     88     378        1   09092002
#
#   del_flg           foracid  ...  acct_classification_flg  \
# 0       N  2635752944296001  ...                      NaN
# 1       N  3414659520992004  ...                      NaN
# 2       N  O987952099252401  ...                      NaN
# 3       N  3241157797524004  ...                      NaN
# 4       N  0884459092002067  ...                      NaN
#
#   acct_cls_advice_printed  acct_cls_chrg_pend_verf  is_loan_agnst_cltrl_flg  \
# 0                     NaN                      NaN                        N
# ...

# %%
print(len(df))
# Out:
# 4279

# %%
df = df.drop_duplicates(subset=['acid'])
print(len(df))
# Out:
# 4087

# %%
# df = df.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)
df.head()
# Out:
#          acid  bacid     cif_id emp_id sol_id  ts_cnt  bank_id    cust_id  \
# 0   Q39620558    NaN  R02944296    NaN     Q3      69        1  RC2934809
# 1  Y110180600    NaN  O99520992    NaN     Y1       5        1  O99520992
# 2   O93531058    NaN  O99520992    NaN     O9     209        1  O99520992
# 3    32559774    NaN  R32157797    NaN     32   10720        1   32157797
# 4   889280082    NaN  R09092002    NaN     88     378        1   09092002
#
#   del_flg           foracid  ...  acct_classification_flg  \
# 0       N  2635752944296001  ...                      NaN
# 1       N  3414659520992004  ...                      NaN
# 2       N  O987952099252401  ...                      NaN
# 3       N  3241157797524004  ...                      NaN
# 4       N  0884459092002067  ...                      NaN
#
#   acct_cls_advice_printed  acct_cls_chrg_pend_verf  is_loan_agnst_cltrl_flg  \
# 0                     NaN                      NaN                        N
# ...

# %%
# generate acid 
def generate_acid(data):
    return "AC" + str(np.random.randint(10000000, 99999999))

df["acid_t"] = df["acid"].apply(generate_acid)
df.head()
# Out:
#          acid  bacid     cif_id emp_id sol_id  ts_cnt  bank_id    cust_id  \
# 0   Q39620558    NaN  R02944296    NaN     Q3      69        1  RC2934809
# 1  Y110180600    NaN  O99520992    NaN     Y1       5        1  O99520992
# 2   O93531058    NaN  O99520992    NaN     O9     209        1  O99520992
# 3    32559774    NaN  R32157797    NaN     32   10720        1   32157797
# 4   889280082    NaN  R09092002    NaN     88     378        1   09092002
#
#   del_flg           foracid  ...  acct_cls_advice_printed  \
# 0       N  2635752944296001  ...                      NaN
# 1       N  3414659520992004  ...                      NaN
# 2       N  O987952099252401  ...                      NaN
# 3       N  3241157797524004  ...                      NaN
# 4       N  0884459092002067  ...                      NaN
#
#   acct_cls_chrg_pend_verf  is_loan_agnst_cltrl_flg  int_adj_for_deduction_flg  \
# 0                     NaN                        N                        NaN
# ...

# %%
# generate_foracid
import numpy as np
import pandas as pd

def generate_foracid():
    random_digit =  str(np.random.randint(1000000000000000, 9999999999999999,dtype='int64'))
    return "FA"+random_digit

df["foracid_t"] = [generate_foracid() for _ in range(len(df))]

df["acct_num"] = df["foracid_t"].str[4:16]
df.head()
# Out:
#          acid  bacid     cif_id emp_id sol_id  ts_cnt  bank_id    cust_id  \
# 0   Q39620558    NaN  R02944296    NaN     Q3      69        1  RC2934809
# 1  Y110180600    NaN  O99520992    NaN     Y1       5        1  O99520992
# 2   O93531058    NaN  O99520992    NaN     O9     209        1  O99520992
# 3    32559774    NaN  R32157797    NaN     32   10720        1   32157797
# 4   889280082    NaN  R09092002    NaN     88     378        1   09092002
#
#   del_flg           foracid  ...  acct_cls_chrg_pend_verf  \
# 0       N  2635752944296001  ...                      NaN
# 1       N  3414659520992004  ...                      NaN
# 2       N  O987952099252401  ...                      NaN
# 3       N  3241157797524004  ...                      NaN
# 4       N  0884459092002067  ...                      NaN
#
#   is_loan_agnst_cltrl_flg  int_adj_for_deduction_flg  \
# 0                       N                        NaN
# 1                       N                        NaN
# ...

# %%
print(len(df.columns))
# Out:
# 189

# %%
selected_columns = [
    "acid",
    "acid_t",
    "cif_id",
    "foracid",
    "foracid_t",
    "acct_num",
    "acct_name",
    "hashed_no",
    "phone_num",
    "acct_short_name",
    "last_tran_id_cr",
    "last_tran_id_dr"
]
remaining_columns = [col for col in df.columns if col not in selected_columns]

# %%
df = df[selected_columns+remaining_columns]
df.head()
# Out:
#          acid      acid_t     cif_id           foracid           foracid_t  \
# 0   Q39620558  AC10370877  R02944296  2635752944296001  FA9627239668220084
# 1  Y110180600  AC41672289  O99520992  3414659520992004  FA3302344775994664
# 2   O93531058  AC73584145  O99520992  O987952099252401  FA5553585851915269
# 3    32559774  AC12345718  R32157797  3241157797524004  FA2582732553674743
# 4   889280082  AC47235600  R09092002  0884459092002067  FA7171012596574289
#
#        acct_num                                          acct_name  \
# 0  272396682200                                   DIPESH SHAH TELI
# 1  023447759946                                      KABITA BASNET
# 2  535858519152                                      KABITA BASNET
# 3  827325536747                          CIVIL CAPITAL DIV (68-69)
# 4  710125965742  NEPAL DOORSANCHAR COMPANY LTD.,REVENUE ACCOUNT...
#
#                                   hashed_no        phone_num acct_short_name  \
# ...

# %%
import hashlib

def generate_hash(data):
    if not isinstance(data, str):
        data = str(data)
    return hashlib.sha1(data.encode('utf-8')).hexdigest().upper()

df["hashed_no"] = df["foracid"].apply(generate_hash)

# %%
df["hashed_no"].head().reset_index()
# df.columns
# Out:
#    index                                 hashed_no
# 0      0  C1426B129652A7DB20182EAE18980F1B26D3B17E
# 1      1  26B23D96EE13CDC789D531D4CF5839AD1EF73B75
# 2      2  B7BDF9D665BAC86A625C32A5726764FB61251A9A
# 3      3  FF377859485ED6FCE9A354D30C3A9744DE68421C
# 4      4  5654F613A38B19A7130D8A5F217260B16DE305B1

# %%
df.head()
# Out:
#          acid      acid_t     cif_id           foracid           foracid_t  \
# 0   Q39620558  AC10370877  R02944296  2635752944296001  FA9627239668220084
# 1  Y110180600  AC41672289  O99520992  3414659520992004  FA3302344775994664
# 2   O93531058  AC73584145  O99520992  O987952099252401  FA5553585851915269
# 3    32559774  AC12345718  R32157797  3241157797524004  FA2582732553674743
# 4   889280082  AC47235600  R09092002  0884459092002067  FA7171012596574289
#
#        acct_num                                          acct_name  \
# 0  272396682200                                   DIPESH SHAH TELI
# 1  023447759946                                      KABITA BASNET
# 2  535858519152                                      KABITA BASNET
# 3  827325536747                          CIVIL CAPITAL DIV (68-69)
# 4  710125965742  NEPAL DOORSANCHAR COMPANY LTD.,REVENUE ACCOUNT...
#
#                                   hashed_no        phone_num acct_short_name  \
# ...

# %%
# df[["acid",
#     "acid_t",
#     "cif_id",
#     "foracid",
#     "foracid_t",
#     "acct_num",
#     "acct_name",
#     "hashed_no",
#     "phone_num",
#     "acct_short_name",
#     "last_tran_id_cr",
#     "last_tran_id_dr"]]

# %%
df_acc = pd.read_csv("../../crmuser/account/cif_masked.csv")
df_acc.head()
# Out:
#           cif_id     orgkey          cust_first_name cust_middle_name  \
# 0  DLNIND4568821  R01562055                    Duman          Narayan
# 1  DLNIND7235296  R01911512                  Prajina             Devi
# 2  DLNIND1406504  R02944296                Humacanta            Bipin
# 3  DLNLEG6218579  C00038863  KHOTANG FOODS PVT. LTD.              NaN
# 4  DLNIND1255130  R01651971                   Adarsh           Bhakta
#
#   cust_last_name   preferredphone                  preferredname  \
# 0        Neupane  +977-9833330190          Duman Narayan Neupane
# 1       Maharjan  +977-9892307589          Prajina Devi Maharjan
# 2          Thapa  +977-9856818453          Humacanta Bipin Thapa
# 3            NaN  +977-9862721402  MANASLU HOSPITALITY PVT. LTD.
# 4           Lama  +977-9810013657             Adarsh Bhakta Lama
#
#              preferredemail                        email gender  \
# 0     ARYALPRABAL@GMAIL.COM           duman492@gmail.com      M
# ...

# %%
print(len(df))
print(len(df_acc))
# Out:
# 4087
# 125

# %%
result_df = pd.merge(df, df_acc, how='left', left_on="cif_id",right_on="orgkey",suffixes=('_p', '_a'))
result_df.head(8)
# Out:
#          acid      acid_t   cif_id_p           foracid           foracid_t  \
# 0   Q39620558  AC10370877  R02944296  2635752944296001  FA9627239668220084
# 1  Y110180600  AC41672289  O99520992  3414659520992004  FA3302344775994664
# 2   O93531058  AC73584145  O99520992  O987952099252401  FA5553585851915269
# 3    32559774  AC12345718  R32157797  3241157797524004  FA2582732553674743
# 4   889280082  AC47235600  R09092002  0884459092002067  FA7171012596574289
# 5  V710183913  AC87964693  R00264434  317TD50264434029  FA8416326642901529
# 6   T29090477  AC86620232  J00518347  2924150518347030  FA4245394524373538
# 7   095980734  AC36353590  R01131729  0095751131729001  FA3894074676824838
#
#        acct_num                                          acct_name  \
# 0  272396682200                                   DIPESH SHAH TELI
# 1  023447759946                                      KABITA BASNET
# 2  535858519152                                      KABITA BASNET
# ...

# %%
print(len(result_df))
# Out:
# 4087

# %%
df["acct_name"] = result_df["preferredname"].values
df["acct_short_name"] = result_df["cust_first_name"].values
df["phone_num"] = result_df["preferredphone"].values
df["cif_id"] = result_df["cif_id_a"].values
df["pan"] = result_df["pan"].values

# %%
df[[
    "acid",
    "acid_t",
    "cif_id",
    "foracid",
    "foracid_t",
    "pan",
    "acct_num",
    "acct_name",
]].to_csv("acid_foracid_masked.csv", index=False)

# %%
acid_foracid = pd.read_csv("acid_foracid_masked.csv")
acid_foracid.head()
# Out:
#          acid      acid_t         cif_id           foracid  \
# 0   Q39620558  AC10370877  DLNIND1406504  2635752944296001
# 1  Y110180600  AC41672289  DLNIND4211643  3414659520992004
# 2   O93531058  AC73584145  DLNIND4211643  O987952099252401
# 3    32559774  AC12345718  DLNLEG9334212  3241157797524004
# 4   889280082  AC47235600  DLNLEG6576494  0884459092002067
#
#             foracid_t           pan      acct_num                   acct_name
# 0  FA9627239668220084  PAN668645879  272396682200       Humacanta Bipin Thapa
# 1  FA3302344775994664  PAN697945863   23447759946          Sriti Kumari Thapa
# 2  FA5553585851915269  PAN697945863  535858519152          Sriti Kumari Thapa
# 3  FA2582732553674743  PAN353089449  827325536747  PALPA HEALTHCARE PVT. LTD.
# 4  FA7171012596574289  PAN813377590  710125965742                         NaN

# %%
result_df = pd.merge(df, acid_foracid, how='left', on="acid",suffixes=('_p', '_a'))
result_df.head()
# Out:
#          acid    acid_t_p       cif_id_p         foracid_p  \
# 0   Q39620558  AC10370877  DLNIND1406504  2635752944296001
# 1  Y110180600  AC41672289  DLNIND4211643  3414659520992004
# 2   O93531058  AC73584145  DLNIND4211643  O987952099252401
# 3    32559774  AC12345718  DLNLEG9334212  3241157797524004
# 4   889280082  AC47235600  DLNLEG6576494  0884459092002067
#
#           foracid_t_p    acct_num_p                 acct_name_p  \
# 0  FA9627239668220084  272396682200       Humacanta Bipin Thapa
# 1  FA3302344775994664  023447759946          Sriti Kumari Thapa
# 2  FA5553585851915269  535858519152          Sriti Kumari Thapa
# 3  FA2582732553674743  827325536747  PALPA HEALTHCARE PVT. LTD.
# 4  FA7171012596574289  710125965742                         NaN
#
#                                   hashed_no        phone_num  \
# 0  C1426B129652A7DB20182EAE18980F1B26D3B17E  +977-9856818453
# 1  26B23D96EE13CDC789D531D4CF5839AD1EF73B75  +977-9899661272
# ...

# %%
df["acid"] = result_df["acid_t_a"].values
df["foracid"] = result_df["foracid_t_a"].values
df["cif_id"] = result_df["cif_id_a"].values

# %%
df.columns
# Out:
# Index(['acid', 'acid_t', 'cif_id', 'foracid', 'foracid_t', 'acct_num',
#        'acct_name', 'hashed_no', 'phone_num', 'acct_short_name',
#        ...
#        'acct_cls_advice_printed', 'acct_cls_chrg_pend_verf',
#        'is_loan_agnst_cltrl_flg', 'int_adj_for_deduction_flg',
#        'used_un_clr_over_dacc_amt', 'used_clean_single_tran_lim',
#        'wtax_floor_limit_scope_flg', 'used_oc_cln_single_tran_lim',
#        'updated_at', 'pan'],
#       dtype='object', length=190)

# %%
df = df.drop(['acid_t','foracid_t'], axis=1)
df.head()
# Out:
#          acid         cif_id             foracid      acct_num  \
# 0  AC10370877  DLNIND1406504  FA9627239668220084  272396682200
# 1  AC41672289  DLNIND4211643  FA3302344775994664  023447759946
# 2  AC73584145  DLNIND4211643  FA5553585851915269  535858519152
# 3  AC12345718  DLNLEG9334212  FA2582732553674743  827325536747
# 4  AC47235600  DLNLEG6576494  FA7171012596574289  710125965742
#
#                     acct_name                                 hashed_no  \
# 0       Humacanta Bipin Thapa  C1426B129652A7DB20182EAE18980F1B26D3B17E
# 1          Sriti Kumari Thapa  26B23D96EE13CDC789D531D4CF5839AD1EF73B75
# 2          Sriti Kumari Thapa  B7BDF9D665BAC86A625C32A5726764FB61251A9A
# 3  PALPA HEALTHCARE PVT. LTD.  FF377859485ED6FCE9A354D30C3A9744DE68421C
# 4                         NaN  5654F613A38B19A7130D8A5F217260B16DE305B1
#
#          phone_num            acct_short_name last_tran_id_cr last_tran_id_dr  \
# ...

# %%
df.to_csv('general_acct_mast_table_masked.csv', index=False)
