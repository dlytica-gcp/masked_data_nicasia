# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('la_tran_detail_table.xlsx')
df.head()
# Out:
#         acid  ts_cnt  bank_id del_flg flow_id                     gl_date  \
# 0  023245753       1        1       N   DISBT  2018-07-04T00:00:00.000000
# 1  023245753       2        1       N   INDEM  2018-07-16T00:00:00.000000
# 2  023245753       1        1       N   COLLC  2018-07-16T00:00:00.000000
# 3  023245753       2        1       N   INDEM  2018-10-02T00:00:00.000000
# 4  023245753       1        1       N   COLLC  2018-10-02T00:00:00.000000
#
#      tran_id  dmd_date    flow_amt  shdl_num  ... holiday_interest_amt  \
# 0    DC27779       NaN  3484000.00         1  ...                    0
# 1  S31225593       NaN    17372.27         1  ...                    0
# 2  S31225678       NaN    17372.27         1  ...                    0
# 3  S34687764       NaN    97384.96         1  ...                    0
# 4  S34698761       NaN    97384.96         1  ...                    0
#
#   interest_overdue_amt normal_principal_amt overdue_interest_amt  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 4                    0                    0                    0
#
#   accrued_penal_int_amt  principal_overdue_amt  adjust_from_sec_dep_flg  \
# 0                     0                      0                      NaN
# 1                     0                      0                      NaN
# 2                     0                      0                      NaN
# 3                     0                      0                      NaN
# 4                     0                      0                      NaN
#
#    int_refund_prepymnt_flg int_coll_on_prepayment_flg              updated_at
# 0                      NaN                        NaN 2024-08-07 06:52:55.177
# 1                      NaN                        NaN 2024-08-07 06:52:55.177
# 2                      NaN                        NaN 2024-08-07 06:52:55.177
# 3                      NaN                        NaN 2024-08-07 06:52:55.177
# 4                      NaN                        NaN 2024-08-07 06:52:55.177
#
# [5 rows x 66 columns]

# %%
print(len(df))
# Out:
# 1462

# %%
df_gam = pd.read_csv("../general_acct_mast_table/acid_foracid_masked.csv")
df_gam.head()
# Out:
#          acid      acid_t         cif_id           foracid  \
# 0   Q39620558  AC10370877  DLNIND1406504  2635752944296001
# 1  Y110180600  AC41672289  DLNIND4211643  3414659520992004
# 2   O93531058  AC73584145  DLNIND4211643  O987952099252401
# 3    32559774  AC12345718  DLNLEG9334212  3241157797524004
# 4   889280082  AC47235600  DLNLEG6576494  0884459092002067
#
#             foracid_t           pan      acct_num                   acct_name
# 0  FA9627239668220084  PAN668645879  272396682200       Humacanta Bipin Thapa
# 1  FA3302344775994664  PAN697945863   23447759946          Sriti Kumari Thapa
# 2  FA5553585851915269  PAN697945863  535858519152          Sriti Kumari Thapa
# 3  FA2582732553674743  PAN353089449  827325536747  PALPA HEALTHCARE PVT. LTD.
# 4  FA7171012596574289  PAN813377590  710125965742                         NaN

# %%
result_df = df.merge(
    df_gam,
    on='acid',
    how='left',
    suffixes=('_p', '_a')  
)

print(f"Original df length: {len(df)}")
print(f"Merged result length: {len(result_df)}")
# Out:
# Original df length: 1462
# Merged result length: 1462

# %%
result_df.head()
# Out:
#         acid  ts_cnt_p  bank_id_p del_flg_p flow_id  \
# 0  023245753         1          1         N   DISBT
# 1  023245753         2          1         N   INDEM
# 2  023245753         1          1         N   COLLC
# 3  023245753         2          1         N   INDEM
# 4  023245753         1          1         N   COLLC
#
#                       gl_date    tran_id  dmd_date    flow_amt  shdl_num  ...  \
# 0  2018-07-04T00:00:00.000000    DC27779       NaN  3484000.00         1  ...
# 1  2018-07-16T00:00:00.000000  S31225593       NaN    17372.27         1  ...
# 2  2018-07-16T00:00:00.000000  S31225678       NaN    17372.27         1  ...
# 3  2018-10-02T00:00:00.000000  S34687764       NaN    97384.96         1  ...
# 4  2018-10-02T00:00:00.000000  S34698761       NaN    97384.96         1  ...
#
#   acct_cls_advice_printed acct_cls_chrg_pend_verf is_loan_agnst_cltrl_flg  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#   int_adj_for_deduction_flg used_un_clr_over_dacc_amt  \
# 0                       NaN                         0
# 1                       NaN                         0
# 2                       NaN                         0
# 3                       NaN                         0
# 4                       NaN                         0
#
#    used_clean_single_tran_lim  wtax_floor_limit_scope_flg  \
# 0                           0                         NaN
# 1                           0                         NaN
# 2                           0                         NaN
# 3                           0                         NaN
# 4                           0                         NaN
#
#    used_oc_cln_single_tran_lim             updated_at_a       cif_id_t
# 0                            0  2024-08-07 06:44:51.722  DLNLEG3605515
# 1                            0  2024-08-07 06:44:51.722  DLNLEG3605515
# 2                            0  2024-08-07 06:44:51.722  DLNLEG3605515
# 3                            0  2024-08-07 06:44:51.722  DLNLEG3605515
# 4                            0  2024-08-07 06:44:51.722  DLNLEG3605515
#
# [5 rows x 255 columns]

# %%
df["acid"] = result_df["acid_t"].values
df.head()
# Out:
#          acid  ts_cnt  bank_id del_flg flow_id                     gl_date  \
# 0  AC99772958       1        1       N   DISBT  2018-07-04T00:00:00.000000
# 1  AC99772958       2        1       N   INDEM  2018-07-16T00:00:00.000000
# 2  AC99772958       1        1       N   COLLC  2018-07-16T00:00:00.000000
# 3  AC99772958       2        1       N   INDEM  2018-10-02T00:00:00.000000
# 4  AC99772958       1        1       N   COLLC  2018-10-02T00:00:00.000000
#
#      tran_id  dmd_date    flow_amt  shdl_num  ... holiday_interest_amt  \
# 0    DC27779       NaN  3484000.00         1  ...                    0
# 1  S31225593       NaN    17372.27         1  ...                    0
# 2  S31225678       NaN    17372.27         1  ...                    0
# 3  S34687764       NaN    97384.96         1  ...                    0
# 4  S34698761       NaN    97384.96         1  ...                    0
#
#   interest_overdue_amt normal_principal_amt overdue_interest_amt  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 4                    0                    0                    0
#
#   accrued_penal_int_amt  principal_overdue_amt  adjust_from_sec_dep_flg  \
# 0                     0                      0                      NaN
# 1                     0                      0                      NaN
# 2                     0                      0                      NaN
# 3                     0                      0                      NaN
# 4                     0                      0                      NaN
#
#    int_refund_prepymnt_flg int_coll_on_prepayment_flg              updated_at
# 0                      NaN                        NaN 2024-08-07 06:52:55.177
# 1                      NaN                        NaN 2024-08-07 06:52:55.177
# 2                      NaN                        NaN 2024-08-07 06:52:55.177
# 3                      NaN                        NaN 2024-08-07 06:52:55.177
# 4                      NaN                        NaN 2024-08-07 06:52:55.177
#
# [5 rows x 66 columns]

# %%
df.to_csv('la_tran_detail_table_masked.csv', index=False)
