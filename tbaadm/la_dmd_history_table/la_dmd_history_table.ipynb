# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('la_dmd_history_table.xlsx')
df.head()
# Out:
#         acid  ei_amt  ts_cnt  bank_id del_flg   dmd_amt  \
# 0   02924028     0.0       1        1       N  20178.74
# 1  021024618     0.0       1        1       N  23399.01
# 2  021024615     0.0       1        1       N  25283.83
# 3  231036970     0.0       1        1       N   2573.29
# 4  021024644     0.0       1        1       N  22534.28
#
#                      dmd_date  shdl_num            lchg_time  \
# 0  2014-08-14T00:00:00.000000         1  2014-08-14T12:28:45
# 1  2014-08-19T00:00:00.000000         1  2014-08-19T16:31:36
# 2  2014-08-20T00:00:00.000000         1  2014-08-20T15:28:47
# 3  2014-08-27T00:00:00.000000         2  2014-08-27T12:29:19
# 4  2014-08-27T00:00:00.000000         1  2014-08-27T17:05:30
#
#              rcre_time  ... ld_freq_type  rcre_user_id  \
# 0  2014-08-14T12:28:45  ...          NaN        CD0122
# 1  2014-08-19T16:31:36  ...          NaN        CD0122
# 2  2014-08-20T15:28:47  ...          NaN        CD0122
# 3  2014-08-27T12:29:19  ...          NaN        SAGARM
# 4  2014-08-27T17:05:30  ...          NaN        CD0122
#
#                 dmd_ovdu_date               last_adj_date  actual_adj_flg  \
# 0  2014-08-16T00:00:00.000000  2014-08-14T00:00:00.000000               N
# 1  2014-08-21T00:00:00.000000  2014-08-19T00:00:00.000000               N
# 2  2014-08-22T00:00:00.000000  2014-08-20T00:00:00.000000               N
# 3  2014-08-29T00:00:00.000000  2014-08-27T00:00:00.000000               N
# 4  2014-08-29T00:00:00.000000  2014-08-27T00:00:00.000000               N
#
#   ldt_crncy_code crystallised_amt latefee_status_flg last_waiver_adj_date  \
# 0            NPR                0                  N                  NaN
# 1            NPR                0                  N                  NaN
# 2            NPR                0                  N                  NaN
# 3            NPR                0                  N                  NaN
# 4            NPR                0                  N                  NaN
#
#                updated_at
# 0 2024-08-07 06:51:26.006
# 1 2024-08-07 06:51:26.006
# 2 2024-08-07 06:51:26.006
# 3 2024-08-07 06:51:26.006
# 4 2024-08-07 06:51:26.006
#
# [5 rows x 27 columns]

# %%
print(len(df))
# Out:
# 6804

# %%
df_gam = pd.read_csv("../general_acct_mast_table/acid_foracid_masked.csv")
df_gam.head()
# Out:
#          acid      acid_t         cif_id           foracid  \
# 0   Q39620558  AC10370877  DLNIND1406504  2635752944296001
# 1  Y110180600  AC41672289  DLNIND4211643  3414659520992004
# 2   O93531058  AC73584145  DLNIND4211643  O987952099252401
# 3    32559774  AC12345718  DLNLEG9334212  3241157797524004
# 4   889280082  AC47235600  DLNLEG6576494  0884459092002067
#
#             foracid_t           pan      acct_num                   acct_name
# 0  FA9627239668220084  PAN668645879  272396682200       Humacanta Bipin Thapa
# 1  FA3302344775994664  PAN697945863   23447759946          Sriti Kumari Thapa
# 2  FA5553585851915269  PAN697945863  535858519152          Sriti Kumari Thapa
# 3  FA2582732553674743  PAN353089449  827325536747  PALPA HEALTHCARE PVT. LTD.
# 4  FA7171012596574289  PAN813377590  710125965742                         NaN

# %%
result_df = df.merge(
    df_gam,
    on='acid',
    how='left'  
)

print(f"Original df length: {len(df)}")
print(f"Merged result length: {len(result_df)}")
# Out:
# Original df length: 6804
# Merged result length: 6804

# %%
result_df.head()
# Out:
#         acid  ei_amt  ts_cnt  bank_id del_flg   dmd_amt  \
# 0   02924028     0.0       1        1       N  20178.74
# 1  021024618     0.0       1        1       N  23399.01
# 2  021024615     0.0       1        1       N  25283.83
# 3  231036970     0.0       1        1       N   2573.29
# 4  021024644     0.0       1        1       N  22534.28
#
#                      dmd_date  shdl_num            lchg_time  \
# 0  2014-08-14T00:00:00.000000         1  2014-08-14T12:28:45
# 1  2014-08-19T00:00:00.000000         1  2014-08-19T16:31:36
# 2  2014-08-20T00:00:00.000000         1  2014-08-20T15:28:47
# 3  2014-08-27T00:00:00.000000         2  2014-08-27T12:29:19
# 4  2014-08-27T00:00:00.000000         1  2014-08-27T17:05:30
#
#              rcre_time  ... latefee_status_flg  last_waiver_adj_date  \
# 0  2014-08-14T12:28:45  ...                  N                   NaN
# 1  2014-08-19T16:31:36  ...                  N                   NaN
# 2  2014-08-20T15:28:47  ...                  N                   NaN
# 3  2014-08-27T12:29:19  ...                  N                   NaN
# 4  2014-08-27T17:05:30  ...                  N                   NaN
#
#                updated_at      acid_t         cif_id           foracid  \
# 0 2024-08-07 06:51:26.006  AC36420025  DLNLEG3286748  0214IM11029TR085
# 1 2024-08-07 06:51:26.006  AC73865839  DLNLEG3286748  0214IM11042TR095
# 2 2024-08-07 06:51:26.006  AC24889393  DLNLEG3286748  0214IM11042TR094
# 3 2024-08-07 06:51:26.006  AC33984365  DLNLEG5142567  23DL114400524008
# 4 2024-08-07 06:51:26.006  AC40993186  DLNLEG3286748  0214IM11049TR096
#
#             foracid_t           pan      acct_num acct_name
# 0  FA9908715260024887  PAN903432729   87152600248       NaN
# 1  FA2214864275267025  PAN903432729  148642752670       NaN
# 2  FA4182622921196582  PAN903432729  826229211965       NaN
# 3  FA5580233263275375  PAN491606593  802332632753       NaN
# 4  FA4857277823915247  PAN903432729  572778239152       NaN
#
# [5 rows x 34 columns]

# %%
df["acid"] = result_df["acid_t"].values
df.head()
# Out:
#          acid  ei_amt  ts_cnt  bank_id del_flg   dmd_amt  \
# 0  AC36420025     0.0       1        1       N  20178.74
# 1  AC73865839     0.0       1        1       N  23399.01
# 2  AC24889393     0.0       1        1       N  25283.83
# 3  AC33984365     0.0       1        1       N   2573.29
# 4  AC40993186     0.0       1        1       N  22534.28
#
#                      dmd_date  shdl_num            lchg_time  \
# 0  2014-08-14T00:00:00.000000         1  2014-08-14T12:28:45
# 1  2014-08-19T00:00:00.000000         1  2014-08-19T16:31:36
# 2  2014-08-20T00:00:00.000000         1  2014-08-20T15:28:47
# 3  2014-08-27T00:00:00.000000         2  2014-08-27T12:29:19
# 4  2014-08-27T00:00:00.000000         1  2014-08-27T17:05:30
#
#              rcre_time  ... ld_freq_type  rcre_user_id  \
# 0  2014-08-14T12:28:45  ...          NaN        CD0122
# 1  2014-08-19T16:31:36  ...          NaN        CD0122
# 2  2014-08-20T15:28:47  ...          NaN        CD0122
# 3  2014-08-27T12:29:19  ...          NaN        SAGARM
# 4  2014-08-27T17:05:30  ...          NaN        CD0122
#
#                 dmd_ovdu_date               last_adj_date  actual_adj_flg  \
# 0  2014-08-16T00:00:00.000000  2014-08-14T00:00:00.000000               N
# 1  2014-08-21T00:00:00.000000  2014-08-19T00:00:00.000000               N
# 2  2014-08-22T00:00:00.000000  2014-08-20T00:00:00.000000               N
# 3  2014-08-29T00:00:00.000000  2014-08-27T00:00:00.000000               N
# 4  2014-08-29T00:00:00.000000  2014-08-27T00:00:00.000000               N
#
#   ldt_crncy_code crystallised_amt latefee_status_flg last_waiver_adj_date  \
# 0            NPR                0                  N                  NaN
# 1            NPR                0                  N                  NaN
# 2            NPR                0                  N                  NaN
# 3            NPR                0                  N                  NaN
# 4            NPR                0                  N                  NaN
#
#                updated_at
# 0 2024-08-07 06:51:26.006
# 1 2024-08-07 06:51:26.006
# 2 2024-08-07 06:51:26.006
# 3 2024-08-07 06:51:26.006
# 4 2024-08-07 06:51:26.006
#
# [5 rows x 27 columns]

# %%
df.to_csv('la_dmd_history_table_masked.csv', index=False)
