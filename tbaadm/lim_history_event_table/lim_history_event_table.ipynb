# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('lim_history_event_table.xlsx')
df.head()
# Out:
#       acid  ts_cnt  bank_id            lchg_time            rcre_time  \
# 0  0113590       0        1  2008-08-27T16:19:02  2008-08-27T16:19:02
# 1  0113590       0        1  2008-09-09T18:08:55  2008-09-09T18:08:55
# 2  0113590       0        1  2008-09-09T18:08:55  2008-09-09T18:08:55
# 3  0115282       0        1  2008-09-10T14:28:40  2008-09-10T14:28:40
# 4  0115283       0        1  2008-09-10T14:29:58  2008-09-10T14:29:58
#
#    serial_num lchg_user_id rcre_user_id  event_serial_num  \
# 0           1       SOPHYP       SOPHYP                 1
# 1           1       SUBASD       SUBASD                 2
# 2           2       SUBASD       SUBASD                 1
# 3           1       SUBASD       SUBASD                 1
# 4           1       SUBASD       SUBASD                 1
#
#             lim_inactive_date  lim_inactive_rmks  related_serial_num  \
# 0  2099-12-31T00:00:00.000000                NaN                 NaN
# 1  2008-09-09T00:00:00.000000                NaN                 2.0
# 2  2099-12-31T00:00:00.000000                NaN                 NaN
# 3  2099-12-31T00:00:00.000000                NaN                 NaN
# 4  2099-12-31T00:00:00.000000                NaN                 NaN
#
#         lim_inactive_bod_date lim_inactive_sys_date              updated_at
# 0                         NaN                   NaN 2024-08-07 06:55:04.547
# 1  2008-09-09T00:00:00.000000   2008-09-09T18:08:55 2024-08-07 06:55:04.547
# 2                         NaN                   NaN 2024-08-07 06:55:04.547
# 3                         NaN                   NaN 2024-08-07 06:55:04.547
# 4                         NaN                   NaN 2024-08-07 06:55:04.547

# %%
print(len(df))
# Out:
# 2484

# %%
df_gam = pd.read_csv("../general_acct_mast_table/acid_foracid_masked.csv")
df_gam.head()
# Out:
#          acid      acid_t         cif_id           foracid  \
# 0   Q39620558  AC10370877  DLNIND1406504  2635752944296001
# 1  Y110180600  AC41672289  DLNIND4211643  3414659520992004
# 2   O93531058  AC73584145  DLNIND4211643  O987952099252401
# 3    32559774  AC12345718  DLNLEG9334212  3241157797524004
# 4   889280082  AC47235600  DLNLEG6576494  0884459092002067
#
#             foracid_t           pan      acct_num                   acct_name
# 0  FA9627239668220084  PAN668645879  272396682200       Humacanta Bipin Thapa
# 1  FA3302344775994664  PAN697945863   23447759946          Sriti Kumari Thapa
# 2  FA5553585851915269  PAN697945863  535858519152          Sriti Kumari Thapa
# 3  FA2582732553674743  PAN353089449  827325536747  PALPA HEALTHCARE PVT. LTD.
# 4  FA7171012596574289  PAN813377590  710125965742                         NaN

# %%
result_df = df.merge(
    df_gam,
    on='acid',
    how='left',
    suffixes=('_p', '_a')  
)

print(f"Original df length: {len(df)}")
print(f"Merged result length: {len(result_df)}")
# Out:
# Original df length: 2484
# Merged result length: 2484

# %%
result_df.head()
# Out:
#       acid  ts_cnt  bank_id            lchg_time            rcre_time  \
# 0  0113590       0        1  2008-08-27T16:19:02  2008-08-27T16:19:02
# 1  0113590       0        1  2008-09-09T18:08:55  2008-09-09T18:08:55
# 2  0113590       0        1  2008-09-09T18:08:55  2008-09-09T18:08:55
# 3  0115282       0        1  2008-09-10T14:28:40  2008-09-10T14:28:40
# 4  0115283       0        1  2008-09-10T14:29:58  2008-09-10T14:29:58
#
#    serial_num lchg_user_id rcre_user_id  event_serial_num  \
# 0           1       SOPHYP       SOPHYP                 1
# 1           1       SUBASD       SUBASD                 2
# 2           2       SUBASD       SUBASD                 1
# 3           1       SUBASD       SUBASD                 1
# 4           1       SUBASD       SUBASD                 1
#
#             lim_inactive_date  ...       lim_inactive_bod_date  \
# 0  2099-12-31T00:00:00.000000  ...                         NaN
# 1  2008-09-09T00:00:00.000000  ...  2008-09-09T00:00:00.000000
# 2  2099-12-31T00:00:00.000000  ...                         NaN
# 3  2099-12-31T00:00:00.000000  ...                         NaN
# 4  2099-12-31T00:00:00.000000  ...                         NaN
#
#    lim_inactive_sys_date              updated_at      acid_t         cif_id  \
# 0                    NaN 2024-08-07 06:55:04.547  AC88861241  DLNLEG6465924
# 1    2008-09-09T18:08:55 2024-08-07 06:55:04.547  AC88861241  DLNLEG6465924
# 2                    NaN 2024-08-07 06:55:04.547  AC88861241  DLNLEG6465924
# 3                    NaN 2024-08-07 06:55:04.547  AC14042152  DLNLEG6465924
# 4                    NaN 2024-08-07 06:55:04.547  AC62240947  DLNLEG6465924
#
#             foracid           foracid_t           pan      acct_num acct_name
# 0  01CA001079NPR001  FA8698709284689804  PAN952179235  987092846898       NaN
# 1  01CA001079NPR001  FA8698709284689804  PAN952179235  987092846898       NaN
# 2  01CA001079NPR001  FA8698709284689804  PAN952179235  987092846898       NaN
# 3  01EF001079NPR002  FA4693898714067951  PAN952179235  938987140679       NaN
# 4  01EF001079NPR003  FA4899046267590576  PAN952179235  990462675905       NaN
#
# [5 rows x 22 columns]

# %%
df["acid"] = result_df["acid_t"].values
df.head()
# Out:
#          acid  ts_cnt  bank_id            lchg_time            rcre_time  \
# 0  AC88861241       0        1  2008-08-27T16:19:02  2008-08-27T16:19:02
# 1  AC88861241       0        1  2008-09-09T18:08:55  2008-09-09T18:08:55
# 2  AC88861241       0        1  2008-09-09T18:08:55  2008-09-09T18:08:55
# 3  AC14042152       0        1  2008-09-10T14:28:40  2008-09-10T14:28:40
# 4  AC62240947       0        1  2008-09-10T14:29:58  2008-09-10T14:29:58
#
#    serial_num lchg_user_id rcre_user_id  event_serial_num  \
# 0           1       SOPHYP       SOPHYP                 1
# 1           1       SUBASD       SUBASD                 2
# 2           2       SUBASD       SUBASD                 1
# 3           1       SUBASD       SUBASD                 1
# 4           1       SUBASD       SUBASD                 1
#
#             lim_inactive_date  lim_inactive_rmks  related_serial_num  \
# 0  2099-12-31T00:00:00.000000                NaN                 NaN
# 1  2008-09-09T00:00:00.000000                NaN                 2.0
# 2  2099-12-31T00:00:00.000000                NaN                 NaN
# 3  2099-12-31T00:00:00.000000                NaN                 NaN
# 4  2099-12-31T00:00:00.000000                NaN                 NaN
#
#         lim_inactive_bod_date lim_inactive_sys_date              updated_at
# 0                         NaN                   NaN 2024-08-07 06:55:04.547
# 1  2008-09-09T00:00:00.000000   2008-09-09T18:08:55 2024-08-07 06:55:04.547
# 2                         NaN                   NaN 2024-08-07 06:55:04.547
# 3                         NaN                   NaN 2024-08-07 06:55:04.547
# 4                         NaN                   NaN 2024-08-07 06:55:04.547

# %%
df.to_csv('lim_history_event_table_masked.csv', index=False)
