# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('ratelist_table.xlsx')
df.head()
# Out:
#    ts_cnt  bank_id del_flg  srl_num ratecode            lchg_time  \
# 0       2        1       N        1      REV  2013-06-29T20:19:23
# 1       2        1       N        1      NCB  2013-06-29T20:19:23
# 2       2        1       N        1      SEL  2013-06-29T20:19:23
# 3      78        1       N        1      SEL  2024-04-25T10:48:39
# 4      78        1       N        1      NCB  2024-04-25T10:48:39
#
#              rcre_time  rtlist_num                 rtlist_date lchg_user_id  \
# 0  2013-06-27T23:57:58           1  2013-06-28T00:00:00.000000      BISHALS
# 1  2013-06-27T23:57:58           1  2013-06-28T00:00:00.000000      BISHALS
# 2  2013-06-27T23:57:58           1  2013-06-28T00:00:00.000000      BISHALS
# 3  2013-06-27T23:58:49           1  2024-04-25T00:00:00.000000      NIRMALB
# 4  2013-06-27T23:58:49           1  2024-04-25T00:00:00.000000      NIRMALB
#
#    ...  var_crncy_code fxd_crncy_units  slab_crncy_code var_crncy_units  \
# ...

# %%
print(len(df))
# Out:
# 5220

# %%
df.to_csv('ratelist_table_masked.csv', index=False)
