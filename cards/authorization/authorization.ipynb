# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('authorization.xlsx')  
df.head()
# Out:
#        aut_code aut_exte_code  aut_sour_inte_code aut_proc_inte_code  \
# 0  416709536187  416703664393                   2                  S
# 1  416709536383  416703665256                   2                  S
# 2  416709536532  416703665868                   2                  S
# 3  416718663760  416718663760                  39                  S
# 4  416718658971  416718658971                  39                  S
#
#    aut_dest_inte_code  aut_auth_inte_code aut_user  aut_syst_cut_off  \
# 0                  30                 NaN      NaN               NaN
# 1                  30                 NaN      NaN               NaN
# 2                  30                 NaN      NaN               NaN
# 3                  30                 NaN      NaN               NaN
# 4                  30                 NaN      NaN               NaN
#
#    aut_acqu_cut_off  aut_issu_cut_off  ... aut_increm_purg_date  \
# 0               NaN               NaN  ...                  NaN
# ...

# %%
df = df.drop(["source_file_path"], axis=1)
df.head()
# Out:
#        aut_code aut_exte_code  aut_sour_inte_code aut_proc_inte_code  \
# 0  416709536187  416703664393                   2                  S
# 1  416709536383  416703665256                   2                  S
# 2  416709536532  416703665868                   2                  S
# 3  416718663760  416718663760                  39                  S
# 4  416718658971  416718658971                  39                  S
#
#    aut_dest_inte_code  aut_auth_inte_code aut_user  aut_syst_cut_off  \
# 0                  30                 NaN      NaN               NaN
# 1                  30                 NaN      NaN               NaN
# 2                  30                 NaN      NaN               NaN
# 3                  30                 NaN      NaN               NaN
# 4                  30                 NaN      NaN               NaN
#
#    aut_acqu_cut_off  aut_issu_cut_off  ... aut_increm_flag  \
# 0               NaN               NaN  ...             NaN
# ...

# %%
df.to_csv('authorization_masked.csv', index=False)
