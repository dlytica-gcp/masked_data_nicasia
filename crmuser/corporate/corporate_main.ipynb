# %%
import pandas as pd
df_corporate= pd.read_excel("corporate.xlsx")
df_corporate = df_corporate.drop(['_airbyte_ab_id', '_airbyte_emitted_at','_airbyte_additional_properties','source_file_path'], axis=1)

df_corporate.head()
# Out:
#   zip   city  int1  int2  int3  int4  int5  int6  int7 str1  ...  \
# 0   0  KATHM   NaN   NaN   NaN   NaN   NaN   NaN   NaN    N  ...
# 1   .  SUNSA   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  ...
# 2   0  BHAKT   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  ...
# 3   .  TANAH   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  ...
# 4   .  SUNSA   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  ...
#
#    nextforeigntaxreviewdate  principle_placeoperation  \
# 0                       NaN                        NP
# 1                       NaN                        NP
# 2                       NaN                        NP
# 3                       NaN                        NP
# 4                       NaN                        NP
#
#    risk_profile_expiry_date  foreignacctaxreportingreq  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# ...

# %%
print(len(df_corporate))
# Out:
# 54

# %%
df_acc = pd.read_csv("../account/cif_masked.csv")
df_acc.head()
# Out:
#           cif_id     orgkey          cust_first_name cust_middle_name  \
# 0  DLNIND4568821  R01562055                    Duman          Narayan
# 1  DLNIND7235296  R01911512                  Prajina             Devi
# 2  DLNIND1406504  R02944296                Humacanta            Bipin
# 3  DLNLEG6218579  C00038863  KHOTANG FOODS PVT. LTD.              NaN
# 4  DLNIND1255130  R01651971                   Adarsh           Bhakta
#
#   cust_last_name   preferredphone                  preferredname  \
# 0        Neupane  +977-9833330190          Duman Narayan Neupane
# 1       Maharjan  +977-9892307589          Prajina Devi Maharjan
# 2          Thapa  +977-9856818453          Humacanta Bipin Thapa
# 3            NaN  +977-9862721402  MANASLU HOSPITALITY PVT. LTD.
# 4           Lama  +977-9810013657             Adarsh Bhakta Lama
#
#              preferredemail                        email gender  \
# 0     ARYALPRABAL@GMAIL.COM           duman492@gmail.com      M
# ...

# %%
result_df = pd.merge(df_corporate, df_acc, how='left', left_on="corp_key",right_on="orgkey", suffixes=('_add', '_acc'))
result_df.head()
# Out:
#   zip   city  int1  int2  int3  int4  int5  int6  int7 str1  ...  \
# 0   0  KATHM   NaN   NaN   NaN   NaN   NaN   NaN   NaN    N  ...
# 1   .  SUNSA   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  ...
# 2   0  BHAKT   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  ...
# 3   .  TANAH   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  ...
# 4   .  SUNSA   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN  ...
#
#                  cust_first_name  cust_middle_name  cust_last_name  \
# 0      TANAHUN DIGITAL PVT. LTD.               NaN             NaN
# 1    PYUTHAN LOGISTICS PVT. LTD.               NaN             NaN
# 2  PATHIVARA LOGISTICS PVT. LTD.               NaN             NaN
# 3                DLYTICA ACADEMY               NaN             NaN
# 4        PARSA TRADING PVT. LTD.               NaN             NaN
#
#    preferredphone_acc                             preferredname  \
# 0     +977-9836649509               PYUTHAN LOGISTICS PVT. LTD.
# ...

# %%
shuffle = pd.read_csv("../account/shuffled_data.csv")
shuffled_data = shuffle.sample(frac=1, random_state=42).reset_index(drop=True)
shuffle = shuffle.iloc[0:54]

# %%
print(len(shuffle))
# Out:
# 54

# %%
df_corporate["corp_key"] = result_df["cif_id"].values
df_corporate["short_name"]= result_df["cust_first_name"].values
df_corporate["preferredemail"]= result_df["preferredemail_acc"].values
df_corporate["phone"]= result_df["preferredphone_acc"].values
df_corporate["preferredphone"]= result_df["preferredphone_acc"].values
df_corporate["short_name"]= result_df["cust_first_name"].values
df_corporate["corporatename_native"] = result_df["preferredname"].values
df_corporate["keycontact_personname"] = shuffle["cust_first_name"].values + shuffle["cust_last_name"].values
# cust_const
# core

# %%
df_corporate.to_csv('corporate_masked.csv', index=False)

# %%
df_corporate.to_csv('corporate_masked.csv', index=False)
