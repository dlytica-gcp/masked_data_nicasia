# %%
import pandas as pd

# %%
df =pd.read_csv('cif_masked.csv')
df.head()
# Out:
#           cif_id     orgkey          cust_first_name cust_middle_name  \
# 0  DLNIND4568821  R01562055                    Duman          Narayan
# 1  DLNIND7235296  R01911512                  Prajina             Devi
# 2  DLNIND1406504  R02944296                Humacanta            Bipin
# 3  DLNLEG6218579  C00038863  KHOTANG FOODS PVT. LTD.              NaN
# 4  DLNIND1255130  R01651971                   Adarsh           Bhakta
#
#   cust_last_name   preferredphone                  preferredname  \
# 0        Neupane  +977-9833330190          Duman Narayan Neupane
# 1       Maharjan  +977-9892307589          Prajina Devi Maharjan
# 2          Thapa  +977-9856818453          Humacanta Bipin Thapa
# 3            NaN  +977-9862721402  MANASLU HOSPITALITY PVT. LTD.
# 4           Lama  +977-9810013657             Adarsh Bhakta Lama
#
#              preferredemail                        email gender  \
# 0     ARYALPRABAL@GMAIL.COM           duman492@gmail.com      M
# ...

# %%
df["preferredemail"] = df["email"]
df['preferredname'] = df['name']

# %%
df.to_csv('cif_masked.csv', index=False)

# %%
df_cum =pd.read_csv('account_masked3.csv')  # IGNORE
df_cum.head()
# Out:
#           orgkey          cust_first_name cust_middle_name cust_last_name  \
# 0  DLNIND4568821                    Duman          Narayan        Neupane
# 1  DLNIND7235296                  Prajina             Devi       Maharjan
# 2  DLNIND1406504                Humacanta            Bipin          Thapa
# 3  DLNLEG6218579  KHOTANG FOODS PVT. LTD.              NaN            NaN
# 4  DLNIND1255130                   Adarsh           Bhakta           Lama
#
#                      cust_dob   cust_type gender  education           pan  \
# 0  1989-11-25T00:00:00.000000  INDIVIDUAL      M        NaN  PAN714271279
# 1  1971-05-05T00:00:00.000000  INDIVIDUAL      F        NaN  PAN503838478
# 2  2005-05-18T00:00:00.000000  INDIVIDUAL      M        NaN  PAN668645879
# 3  2012-11-12T00:00:00.000000       LEGAL    NaN        NaN  PAN533918346
# 4  1993-02-28T00:00:00.000000  INDIVIDUAL      M        NaN  PAN331700070
#
#                          email  ...  creditbureauscorevalidity  \
# ...

# %%
df_cum["preferredemail"] = df["email"].values
df_cum["preferredname"] = df["name"].values
df_cum['gender'] = df['gender'].values

# %%
df_cum.to_csv('account_masked3.csv', index=False)
