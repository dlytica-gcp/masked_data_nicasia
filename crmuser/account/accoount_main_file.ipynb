# %%
import pandas as pd
import random
import numpy as np

# %%
df = pd.read_excel("accounts.xlsx")
df.head()
# Out:
#                          _airbyte_ab_id     _airbyte_emitted_at  cin  fax  \
# 0  273b5728-535b-4106-8c31-ce5e48eee381 2024-08-05 07:02:37.777  NaN  NaN
# 1  70ced3d3-ad57-4433-a382-6ecbcc42fd90 2024-08-05 07:02:37.777  NaN  NaN
# 2  15e20dca-a337-44b5-b202-b299895336df 2024-08-05 07:02:37.777  NaN  NaN
# 3  5cf04c55-8085-4e86-ab6f-88904ceb2c6e 2024-08-05 07:02:37.777  NaN  NaN
# 4  8fb8b8e6-aa95-4344-bdbe-a49935add064 2024-08-05 07:02:37.777  NaN  NaN
#
#            pan  ssn  url     zip   city  flg1  ...  foreignacctaxreportingreq  \
# 0          NaN  NaN  NaN  977000    NaN   NaN  ...                        NaN
# 1          NaN  NaN  NaN       0  KATHM   NaN  ...                        NaN
# 2          NaN  NaN  NaN  977000  BUDAN   NaN  ...                        NaN
# 3          NaN  NaN  NaN  977000  RAMNA   NaN  ...                        NaN
# 4  104894561.0  NaN  NaN      12  BIRAT   NaN  ...                        NaN
#
#    foreigntaxreportingstatus preferred_mobile_alert_no  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
#
#   credithistoryrequestedflag  foreigntaxreportingcountry  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#   customer_level_provisioning preferred_mobile_alert_type  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    _airbyte_additional_properties  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#                                     source_file_path              updated_at
# 0  s3a://ai360nica/data/bronze/oracle/cbs/CRMUSER... 2024-08-07 06:29:18.596
# 1  s3a://ai360nica/data/bronze/oracle/cbs/CRMUSER... 2024-08-07 06:29:18.596
# 2  s3a://ai360nica/data/bronze/oracle/cbs/CRMUSER... 2024-08-07 06:29:18.596
# 3  s3a://ai360nica/data/bronze/oracle/cbs/CRMUSER... 2024-08-07 06:29:18.596
# 4  s3a://ai360nica/data/bronze/oracle/cbs/CRMUSER... 2024-08-07 06:29:18.596
#
# [5 rows x 492 columns]

# %%
df["orgkey"].head()
# Out:
# 0    319749297
# 1    R24249553
# 2    R28893337
# 3    R66368828
# 4    R02063811
# Name: orgkey, dtype: object

# %%
df["occupation"].unique()
# Out:
# array(['NOT A', 'ENGIN', 'BUSIN', nan, 'TEACH', 'HOUSE', 'SERVI', 'STUDE',
#        'UNEMP', 'RETIR', 'BANKE', 'DOCTO', 'FARME', 'SELFE', 'TRADI'],
#       dtype=object)

# %%
def get_occupation(data):
    if data =="NOT A":
        return "NOT AVAILABLE"
    elif data =="ENGIN":
        return "ENGINEER"
    elif data =="BUSIN":
        return "BUSINESSMAN"
    elif data =="TEACH":
        return "TEACHER"
    elif data =="HOUSE":
        return "HOUSEHOLD"
    elif data =="SERVI":
        return "SERVICE"
    elif data =="UNEMP":
        return "UNEMPLOYED"
    elif data =="RETIR":
        return "RETIRED"
    elif data =="BANKE":
        return "BANKER"
    elif data =="SERVI":
        return "SERVICE"
    elif data =="DOCTO":
        return "DOCTOR"
    elif data =="FARME":
        return "FARMER"
    elif data =="TRADI":
        return "TRADING"
    elif data =="SELFE":
        return "SELFEMPLOYED"
    
    else:
        return "nan" 

df["occupation"] =  df["occupation"].apply(get_occupation)

# %%
def pan(data):
    random_digits = np.random.randint(100000000, 999999999)  
    return "PAN" + str(random_digits)

df["pan"] = df["pan"].apply(pan)

# %%
df["pan"].head()
# Out:
# 0    PAN143048430
# 1    PAN165730705
# 2    PAN729503320
# 3    PAN849149601
# 4    PAN792646871
# Name: pan, dtype: object

# %%
df = df.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)
df.head()
# Out:
#    cin  fax           pan  ssn  url     zip   city  flg1  flg2  flg3  ...  \
# 0  NaN  NaN  PAN143048430  NaN  NaN  977000    NaN   NaN   NaN   NaN  ...
# 1  NaN  NaN  PAN165730705  NaN  NaN       0  KATHM   NaN   NaN   NaN  ...
# 2  NaN  NaN  PAN729503320  NaN  NaN  977000  BUDAN   NaN   NaN   NaN  ...
# 3  NaN  NaN  PAN849149601  NaN  NaN  977000  RAMNA   NaN   NaN   NaN  ...
# 4  NaN  NaN  PAN792646871  NaN  NaN      12  BIRAT   NaN   NaN   NaN  ...
#
#   sencitizenconversionflag creditbureauscorevalidity  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      NaN                       NaN
#
#    foreignacctaxreportingreq foreigntaxreportingstatus  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
#
#   preferred_mobile_alert_no  credithistoryrequestedflag  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
#
#    foreigntaxreportingcountry  customer_level_provisioning  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    preferred_mobile_alert_type              updated_at
# 0                          NaN 2024-08-07 06:29:18.596
# 1                          NaN 2024-08-07 06:29:18.596
# 2                          NaN 2024-08-07 06:29:18.596
# 3                          NaN 2024-08-07 06:29:18.596
# 4                          NaN 2024-08-07 06:29:18.596
#
# [5 rows x 488 columns]

# %%
#cust_type generation
import numpy as np
def get_cust_type(df):
    df= df.copy()
    condition =  (df["constitution_code"] == "INDIJ") | (df["constitution_code"] == "INDIV")
    df['cust_type'] = np.where(condition,"INDIVIDUAL","LEGAL")
    return df


df = get_cust_type(df)
df[["cust_type","constitution_code"]].head(7)
# Out:
#     cust_type constitution_code
# 0  INDIVIDUAL             INDIV
# 1       LEGAL             OTHER
# 2  INDIVIDUAL             INDIV
# 3  INDIVIDUAL             INDIJ
# 4  INDIVIDUAL             INDIV
# 5  INDIVIDUAL             INDIV
# 6       LEGAL              USTS

# %%
# CIF_ID Generation
import pandas as pd
import numpy as np

def generate_cif_id(code):
    if code == "INDIVIDUAL":
        prefix = "DLNIND"
    elif code == "LEGAL":
        prefix = "DLNLEG"
    else:
        return ""  
    
    random_digits = str(np.random.randint(1000000, 9999999))
    return prefix + random_digits


df["cif_id"] = df["cust_type"].apply(generate_cif_id)
df["core_cust_id"] = df["cif_id"]
df["group_id"] = df["cif_id"]
df["introducerid"] = ""

df.head()
# Out:
#    cin  fax           pan  ssn  url     zip   city  flg1  flg2  flg3  ...  \
# 0  NaN  NaN  PAN143048430  NaN  NaN  977000    NaN   NaN   NaN   NaN  ...
# 1  NaN  NaN  PAN165730705  NaN  NaN       0  KATHM   NaN   NaN   NaN  ...
# 2  NaN  NaN  PAN729503320  NaN  NaN  977000  BUDAN   NaN   NaN   NaN  ...
# 3  NaN  NaN  PAN849149601  NaN  NaN  977000  RAMNA   NaN   NaN   NaN  ...
# 4  NaN  NaN  PAN792646871  NaN  NaN      12  BIRAT   NaN   NaN   NaN  ...
#
#   foreignacctaxreportingreq foreigntaxreportingstatus  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    preferred_mobile_alert_no credithistoryrequestedflag  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#   foreigntaxreportingcountry  customer_level_provisioning  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# 3                        NaN                          NaN
# 4                        NaN                          NaN
#
#    preferred_mobile_alert_type              updated_at         cif_id  \
# 0                          NaN 2024-08-07 06:29:18.596  DLNIND3744151
# 1                          NaN 2024-08-07 06:29:18.596  DLNLEG8507903
# 2                          NaN 2024-08-07 06:29:18.596  DLNIND1372327
# 3                          NaN 2024-08-07 06:29:18.596  DLNIND7426436
# 4                          NaN 2024-08-07 06:29:18.596  DLNIND5676264
#
#         group_id
# 0  DLNIND3744151
# 1  DLNLEG8507903
# 2  DLNIND1372327
# 3  DLNIND7426436
# 4  DLNIND5676264
#
# [5 rows x 490 columns]

# %%
df["cif_id"].nunique()
# Out:
# 125

# %%
selected_columns = [
    "cif_id",
    "orgkey",
    "cust_first_name",
    "cust_middle_name",
    "cust_last_name",
    "cust_dob",
    "cust_type",
    "gender",
    "education",
    "pan",
    "email",
    "preferredphone"
]
remaining_columns = [col for col in df.columns if col not in selected_columns]

# %%
new_df = df[selected_columns + remaining_columns]
new_df.head()
# Out:
#           cif_id     orgkey cust_first_name       cust_middle_name  \
# 0  DLNIND3744151  319749297           SHYAM                    NaN
# 1  DLNLEG8507903  R24249553             NaN                    NaN
# 2  DLNIND1372327  R28893337       PRADYUMNA                    LAL
# 3  DLNIND7426436  R66368828     CHANDESHWAR  SAHUTELI/SHAMBHUKUMAR
# 4  DLNIND5676264  R02063811        JAGADISH                 PRASAD
#
#                  cust_last_name                    cust_dob   cust_type  \
# 0                     CHAUDHARY  1988-02-17T00:00:00.000000  INDIVIDUAL
# 1  NIC BANK-LOAN PROCESSING FEE  1900-01-01T00:00:00.000000       LEGAL
# 2                     RAJBAMSHI  1961-12-06T00:00:00.000000  INDIVIDUAL
# 3                           SAH  1965-07-16T00:00:00.000000  INDIVIDUAL
# 4                       AGRAWAL  1943-04-05T00:00:00.000000  INDIVIDUAL
#
#   gender  education           pan  ... creditbureauscorevalidity  \
# 0      F        NaN  PAN143048430  ...                       NaN
# 1    NaN        NaN  PAN165730705  ...                       NaN
# 2      M        NaN  PAN729503320  ...                       NaN
# 3      M        NaN  PAN849149601  ...                       NaN
# 4      M        NaN  PAN792646871  ...                       NaN
#
#   foreignacctaxreportingreq  foreigntaxreportingstatus  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#    preferred_mobile_alert_no  credithistoryrequestedflag  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#    foreigntaxreportingcountry customer_level_provisioning  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   preferred_mobile_alert_type              updated_at       group_id
# 0                         NaN 2024-08-07 06:29:18.596  DLNIND3744151
# 1                         NaN 2024-08-07 06:29:18.596  DLNLEG8507903
# 2                         NaN 2024-08-07 06:29:18.596  DLNIND1372327
# 3                         NaN 2024-08-07 06:29:18.596  DLNIND7426436
# 4                         NaN 2024-08-07 06:29:18.596  DLNIND5676264
#
# [5 rows x 490 columns]

# %%
cust_Ind = new_df[new_df["cust_type"]=="INDIVIDUAL"]
cust_Ind.head(80)
# Out:
#             cif_id     orgkey   cust_first_name       cust_middle_name  \
# 0    DLNIND3744151  319749297             SHYAM                    NaN
# 2    DLNIND1372327  R28893337         PRADYUMNA                    LAL
# 3    DLNIND7426436  R66368828       CHANDESHWAR  SAHUTELI/SHAMBHUKUMAR
# 4    DLNIND5676264  R02063811          JAGADISH                 PRASAD
# 5    DLNIND9910969  R00061514  BIRENDRA BAHADUR                    NaN
# ..             ...        ...               ...                    ...
# 120  DLNIND2129887  R01911511              TIKA                    NaN
# 121  DLNIND9997823  R01911516           BHARATI                    NaN
# 122  DLNIND6852316  R01911519           BASANTI                    NaN
# 123  DLNIND7235296  R01911512             BUDAI                    NaN
# 124  DLNIND6192226  R01901407             SAGAR                    NaN
#
#     cust_last_name                    cust_dob   cust_type gender  education  \
# 0        CHAUDHARY  1988-02-17T00:00:00.000000  INDIVIDUAL      F        NaN
# 2        RAJBAMSHI  1961-12-06T00:00:00.000000  INDIVIDUAL      M        NaN
# 3              SAH  1965-07-16T00:00:00.000000  INDIVIDUAL      M        NaN
# 4          AGRAWAL  1943-04-05T00:00:00.000000  INDIVIDUAL      M        NaN
# 5          NEUPANE  1978-06-13T00:00:00.000000  INDIVIDUAL      M        NaN
# ..             ...                         ...         ...    ...        ...
# 120  KUMARI PADHYA  1959-01-27T00:00:00.000000  INDIVIDUAL      F        NaN
# 121  KUMARI KHATRI  1997-09-15T00:00:00.000000  INDIVIDUAL      F        NaN
# 122          DAMAI  1968-04-22T00:00:00.000000  INDIVIDUAL      F        NaN
# 123            SAH  1971-05-05T00:00:00.000000  INDIVIDUAL      M        NaN
# 124        NEUPANE  1999-08-28T00:00:00.000000  INDIVIDUAL      M        NaN
#
#               pan  ... creditbureauscorevalidity foreignacctaxreportingreq  \
# 0    PAN143048430  ...                       NaN                       NaN
# 2    PAN729503320  ...                       NaN                       NaN
# 3    PAN849149601  ...                       NaN                       NaN
# 4    PAN792646871  ...                       NaN                       NaN
# 5    PAN170015742  ...                       NaN                       NaN
# ..            ...  ...                       ...                       ...
# 120  PAN502308017  ...                       NaN                       NaN
# 121  PAN859562290  ...                       NaN                       NaN
# 122  PAN986235560  ...                       NaN                       NaN
# 123  PAN503838478  ...                       NaN                       NaN
# 124  PAN160990648  ...                       NaN                       NaN
#
#      foreigntaxreportingstatus  preferred_mobile_alert_no  \
# 0                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# 5                          NaN                        NaN
# ..                         ...                        ...
# 120                        NaN                        NaN
# 121                        NaN                        NaN
# 122                        NaN                        NaN
# 123                        NaN                        NaN
# 124                        NaN                        NaN
#
#      credithistoryrequestedflag  foreigntaxreportingcountry  \
# 0                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# 5                           NaN                         NaN
# ..                          ...                         ...
# 120                         NaN                         NaN
# 121                         NaN                         NaN
# 122                         NaN                         NaN
# 123                         NaN                         NaN
# 124                         NaN                         NaN
#
#     customer_level_provisioning preferred_mobile_alert_type  \
# 0                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# 5                           NaN                         NaN
# ..                          ...                         ...
# 120                         NaN                         NaN
# 121                         NaN                         NaN
# 122                         NaN                         NaN
# 123                         NaN                         NaN
# 124                         NaN                         NaN
#
#                  updated_at       group_id
# 0   2024-08-07 06:29:18.596  DLNIND3744151
# 2   2024-08-07 06:29:18.596  DLNIND1372327
# 3   2024-08-07 06:29:18.596  DLNIND7426436
# 4   2024-08-07 06:29:18.596  DLNIND5676264
# 5   2024-08-07 06:29:18.596  DLNIND9910969
# ..                      ...            ...
# 120 2024-08-07 06:29:18.596  DLNIND2129887
# 121 2024-08-07 06:29:18.596  DLNIND9997823
# 122 2024-08-07 06:29:18.596  DLNIND6852316
# 123 2024-08-07 06:29:18.596  DLNIND7235296
# 124 2024-08-07 06:29:18.596  DLNIND6192226
#
# [71 rows x 490 columns]

# %%
print(len(cust_Ind))
# Out:
# 71

# %%
df = pd.read_csv("shuffled_data.csv")
df = df.iloc[0:71]

# %%
print(len(df))
# Out:
# 71

# %%
cust_Ind["cust_first_name"] = df["cust_first_name"].values
cust_Ind["name"] = df["cust_first_name"].fillna("").values + " " + df["cust_middle_name"].fillna("").values + " " + df["cust_last_name"].fillna("").values
cust_Ind["preferredname"] =  df["cust_first_name"].fillna("").values + " " + df["cust_middle_name"].fillna("").values + " " + df["cust_last_name"].fillna("").values
cust_Ind["cust_middle_name"] = df["cust_middle_name"].values
cust_Ind["cust_last_name"] = df["cust_last_name"].values
cust_Ind["gender"] = df["gender"].values
cust_Ind["short_name"] = df["cust_first_name"].values
cust_Ind.head(80)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\4090070699.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cust_Ind["cust_first_name"] = df["cust_first_name"].values
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\4090070699.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cust_Ind["name"] = df["cust_first_name"].fillna("").values + " " + df["cust_middle_name"].fillna("").values + " " + df["cust_last_name"].fillna("").values
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\4090070699.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cust_Ind["preferredname"] =  df["cust_first_name"].fillna("").values + " " + df["cust_middle_name"].fillna("").values + " " + df["cust_last_name"].fillna("").values
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\4090070699.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cust_Ind["cust_middle_name"] = df["cust_middle_name"].values
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\4090070699.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cust_Ind["cust_last_name"] = df["cust_last_name"].values
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\4090070699.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cust_Ind["gender"] = df["gender"].values
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\4090070699.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cust_Ind["short_name"] = df["cust_first_name"].values
#             cif_id     orgkey cust_first_name cust_middle_name cust_last_name  \
# 0    DLNIND3744151  319749297       Buddhiraj            Bibek        Thakuri
# 2    DLNIND1372327  R28893337          Pramil          Narayan       Adhikari
# 3    DLNIND7426436  R66368828         Shirish          Shankar      Timalsina
# 4    DLNIND5676264  R02063811            Hina             Maya        Neupane
# 5    DLNIND9910969  R00061514          Poshan            Gopal       Bhandari
# ..             ...        ...             ...              ...            ...
# 120  DLNIND2129887  R01911511            Heli        Saraswati        Acharya
# 121  DLNIND9997823  R01911516          Pranij              Lal          Karki
# 122  DLNIND6852316  R01911519         Sanjita              Dev            Rai
# 123  DLNIND7235296  R01911512         Prajina             Devi       Maharjan
# 124  DLNIND6192226  R01901407          Nirvan           Bishnu       Maharjan
#
#                        cust_dob   cust_type gender  education           pan  \
# 0    1988-02-17T00:00:00.000000  INDIVIDUAL      M        NaN  PAN143048430
# 2    1961-12-06T00:00:00.000000  INDIVIDUAL      M        NaN  PAN729503320
# 3    1965-07-16T00:00:00.000000  INDIVIDUAL      M        NaN  PAN849149601
# 4    1943-04-05T00:00:00.000000  INDIVIDUAL      F        NaN  PAN792646871
# 5    1978-06-13T00:00:00.000000  INDIVIDUAL      M        NaN  PAN170015742
# ..                          ...         ...    ...        ...           ...
# 120  1959-01-27T00:00:00.000000  INDIVIDUAL      F        NaN  PAN502308017
# 121  1997-09-15T00:00:00.000000  INDIVIDUAL      M        NaN  PAN859562290
# 122  1968-04-22T00:00:00.000000  INDIVIDUAL      M        NaN  PAN986235560
# 123  1971-05-05T00:00:00.000000  INDIVIDUAL      F        NaN  PAN503838478
# 124  1999-08-28T00:00:00.000000  INDIVIDUAL      M        NaN  PAN160990648
#
#      ... creditbureauscorevalidity foreignacctaxreportingreq  \
# 0    ...                       NaN                       NaN
# 2    ...                       NaN                       NaN
# 3    ...                       NaN                       NaN
# 4    ...                       NaN                       NaN
# 5    ...                       NaN                       NaN
# ..   ...                       ...                       ...
# 120  ...                       NaN                       NaN
# 121  ...                       NaN                       NaN
# 122  ...                       NaN                       NaN
# 123  ...                       NaN                       NaN
# 124  ...                       NaN                       NaN
#
#      foreigntaxreportingstatus  preferred_mobile_alert_no  \
# 0                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# 5                          NaN                        NaN
# ..                         ...                        ...
# 120                        NaN                        NaN
# 121                        NaN                        NaN
# 122                        NaN                        NaN
# 123                        NaN                        NaN
# 124                        NaN                        NaN
#
#      credithistoryrequestedflag  foreigntaxreportingcountry  \
# 0                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# 5                           NaN                         NaN
# ..                          ...                         ...
# 120                         NaN                         NaN
# 121                         NaN                         NaN
# 122                         NaN                         NaN
# 123                         NaN                         NaN
# 124                         NaN                         NaN
#
#     customer_level_provisioning preferred_mobile_alert_type  \
# 0                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# 5                           NaN                         NaN
# ..                          ...                         ...
# 120                         NaN                         NaN
# 121                         NaN                         NaN
# 122                         NaN                         NaN
# 123                         NaN                         NaN
# 124                         NaN                         NaN
#
#                  updated_at       group_id
# 0   2024-08-07 06:29:18.596  DLNIND3744151
# 2   2024-08-07 06:29:18.596  DLNIND1372327
# 3   2024-08-07 06:29:18.596  DLNIND7426436
# 4   2024-08-07 06:29:18.596  DLNIND5676264
# 5   2024-08-07 06:29:18.596  DLNIND9910969
# ..                      ...            ...
# 120 2024-08-07 06:29:18.596  DLNIND2129887
# 121 2024-08-07 06:29:18.596  DLNIND9997823
# 122 2024-08-07 06:29:18.596  DLNIND6852316
# 123 2024-08-07 06:29:18.596  DLNIND7235296
# 124 2024-08-07 06:29:18.596  DLNIND6192226
#
# [71 rows x 490 columns]

# %%
df = pd.read_csv("company_name.csv")
df = df.iloc[0:54]
df.head()
# Out:
#                  cust_first_name cust_type
# 0      TANAHUN DIGITAL PVT. LTD.     LEGAL
# 1    PYUTHAN LOGISTICS PVT. LTD.     LEGAL
# 2  PATHIVARA LOGISTICS PVT. LTD.     LEGAL
# 3                DLYTICA ACADEMY     LEGAL
# 4        PARSA TRADING PVT. LTD.     LEGAL

# %%
print(len(df))
# Out:
# 54

# %%
cust_leg = new_df[new_df["cust_type"]=="LEGAL"]
cust_leg.head()
# Out:
#           cif_id     orgkey cust_first_name cust_middle_name  \
# 1  DLNLEG8507903  R24249553             NaN              NaN
# 6  DLNLEG1290799  C00004434             NaN              NaN
# 7  DLNLEG1805667  R08272460             NaN              NaN
# 8  DLNLEG9966100  C00004439             NaN              NaN
# 9  DLNLEG6566454  C00004426             NaN              NaN
#
#                         cust_last_name                    cust_dob cust_type  \
# 1         NIC BANK-LOAN PROCESSING FEE  1900-01-01T00:00:00.000000     LEGAL
# 6  BARPIPAL TOLE BATO UPAVAOKTA SAMITI  2019-01-22T00:00:00.000000     LEGAL
# 7                 CRYSTAL OFFSET PRESS  1900-01-01T00:00:00.000000     LEGAL
# 8               ARJUN SUNCHANDI UDHYOG  2015-09-15T00:00:00.000000     LEGAL
# 9                ROYAL FURNITURE UDYOG  2019-01-31T00:00:00.000000     LEGAL
#
#   gender  education           pan  ... creditbureauscorevalidity  \
# 1    NaN        NaN  PAN165730705  ...                       NaN
# 6    NaN        NaN  PAN679940823  ...                       NaN
# 7    NaN        NaN  PAN629114031  ...                       NaN
# 8    NaN        NaN  PAN200433423  ...                       NaN
# 9    NaN        NaN  PAN491523472  ...                       NaN
#
#   foreignacctaxreportingreq  foreigntaxreportingstatus  \
# 1                       NaN                        NaN
# 6                       NaN                        NaN
# 7                       NaN                        NaN
# 8                       NaN                        NaN
# 9                       NaN                        NaN
#
#    preferred_mobile_alert_no  credithistoryrequestedflag  \
# 1                        NaN                         NaN
# 6                        NaN                         NaN
# 7                        NaN                         NaN
# 8                        NaN                         NaN
# 9                        NaN                         NaN
#
#    foreigntaxreportingcountry customer_level_provisioning  \
# 1                         NaN                         NaN
# 6                         NaN                         NaN
# 7                         NaN                         NaN
# 8                         NaN                         NaN
# 9                         NaN                         NaN
#
#   preferred_mobile_alert_type              updated_at       group_id
# 1                         NaN 2024-08-07 06:29:18.596  DLNLEG8507903
# 6                         NaN 2024-08-07 06:29:18.596  DLNLEG1290799
# 7                         NaN 2024-08-07 06:29:18.596  DLNLEG1805667
# 8                         NaN 2024-08-07 06:29:18.596  DLNLEG9966100
# 9                         NaN 2024-08-07 06:29:18.596  DLNLEG6566454
#
# [5 rows x 490 columns]

# %%
print(len(cust_leg))
# Out:
# 54

# %%
cust_leg["cust_first_name"] = df["cust_first_name"].values
cust_leg["name"] = df["cust_first_name"].values
cust_leg["preferredname"] = df["cust_first_name"]
cust_leg["cust_middle_name"] = ""
cust_leg["cust_last_name"] = ""
cust_leg["gender"] = ""
cust_leg["short_name"] = df["cust_first_name"].values
cust_leg.head(14)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\2787443055.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cust_leg["cust_first_name"] = df["cust_first_name"].values
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\2787443055.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cust_leg["name"] = df["cust_first_name"].values
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\2787443055.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cust_leg["preferredname"] = df["cust_first_name"]
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\2787443055.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cust_leg["cust_middle_name"] = ""
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\2787443055.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cust_leg["cust_last_name"] = ""
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\2787443055.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cust_leg["gender"] = ""
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\2787443055.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cust_leg["short_name"] = df["cust_first_name"].values
#            cif_id     orgkey                           cust_first_name  \
# 1   DLNLEG8507903  R24249553                 TANAHUN DIGITAL PVT. LTD.
# 6   DLNLEG1290799  C00004434               PYUTHAN LOGISTICS PVT. LTD.
# 7   DLNLEG1805667  R08272460             PATHIVARA LOGISTICS PVT. LTD.
# 8   DLNLEG9966100  C00004439                           DLYTICA ACADEMY
# 9   DLNLEG6566454  C00004426                   PARSA TRADING PVT. LTD.
# 10  DLNLEG9678391  R22132679              MANANG HOSPITALITY PVT. LTD.
# 11  DLNLEG5919852  C00004442  RUPA SAVINGS AND CREDIT COOPERATIVE LTD.
# 12  DLNLEG2266684  R48318099             SAGARMATHA CLOTHING PVT. LTD.
# 13  DLNLEG7793973  C00004445                  SYANGJA REAL ESTATE LTD.
# 14  DLNLEG3756805  C00004446          KANCHANJUNGA LOGISTICS PVT. LTD.
# 15  DLNLEG3709876  C00004448          KAILASH PRINTING PRESS PVT. LTD.
# 16  DLNLEG5334058  C00004447                     SUNSARI VENTURES LTD.
# 17  DLNLEG1598748  800520371              SAGARMATHA TRADERS PVT. LTD.
# 18  DLNLEG7265178  800520784            SINDHUPALCHOWK MEDIA PVT. LTD.
#
#    cust_middle_name cust_last_name                    cust_dob cust_type  \
# 1                                   1900-01-01T00:00:00.000000     LEGAL
# 6                                   2019-01-22T00:00:00.000000     LEGAL
# 7                                   1900-01-01T00:00:00.000000     LEGAL
# 8                                   2015-09-15T00:00:00.000000     LEGAL
# 9                                   2019-01-31T00:00:00.000000     LEGAL
# 10                                  1900-01-01T00:00:00.000000     LEGAL
# 11                                  2017-02-07T00:00:00.000000     LEGAL
# 12                                  1900-01-01T00:00:00.000000     LEGAL
# 13                                  2019-02-04T00:00:00.000000     LEGAL
# 14                                  2018-06-11T00:00:00.000000     LEGAL
# 15                                  2009-10-22T00:00:00.000000     LEGAL
# 16                                  2019-01-29T00:00:00.000000     LEGAL
# 17                                  1900-01-01T00:00:00.000000     LEGAL
# 18                                  1900-01-01T00:00:00.000000     LEGAL
#
#    gender  education           pan  ... creditbureauscorevalidity  \
# 1                NaN  PAN165730705  ...                       NaN
# 6                NaN  PAN679940823  ...                       NaN
# 7                NaN  PAN629114031  ...                       NaN
# 8                NaN  PAN200433423  ...                       NaN
# 9                NaN  PAN491523472  ...                       NaN
# 10               NaN  PAN432548863  ...                       NaN
# 11               NaN  PAN723809886  ...                       NaN
# 12               NaN  PAN940651973  ...                       NaN
# 13               NaN  PAN758602904  ...                       NaN
# 14               NaN  PAN668536553  ...                       NaN
# 15               NaN  PAN880276201  ...                       NaN
# 16               NaN  PAN222576654  ...                       NaN
# 17               NaN  PAN606494169  ...                       NaN
# 18               NaN  PAN188513875  ...                       NaN
#
#    foreignacctaxreportingreq  foreigntaxreportingstatus  \
# 1                        NaN                        NaN
# 6                        NaN                        NaN
# 7                        NaN                        NaN
# 8                        NaN                        NaN
# 9                        NaN                        NaN
# 10                       NaN                        NaN
# 11                       NaN                        NaN
# 12                       NaN                        NaN
# 13                       NaN                        NaN
# 14                       NaN                        NaN
# 15                       NaN                        NaN
# 16                       NaN                        NaN
# 17                       NaN                        NaN
# 18                       NaN                        NaN
#
#     preferred_mobile_alert_no  credithistoryrequestedflag  \
# 1                         NaN                         NaN
# 6                         NaN                         NaN
# 7                         NaN                         NaN
# 8                         NaN                         NaN
# 9                         NaN                         NaN
# 10                        NaN                         NaN
# 11                        NaN                         NaN
# 12                        NaN                         NaN
# 13                        NaN                         NaN
# 14                        NaN                         NaN
# 15                        NaN                         NaN
# 16                        NaN                         NaN
# 17                        NaN                         NaN
# 18                        NaN                         NaN
#
#     foreigntaxreportingcountry customer_level_provisioning  \
# 1                          NaN                         NaN
# 6                          NaN                         NaN
# 7                          NaN                         NaN
# 8                          NaN                         NaN
# 9                          NaN                         NaN
# 10                         NaN                         NaN
# 11                         NaN                         NaN
# 12                         NaN                         NaN
# 13                         NaN                         NaN
# 14                         NaN                         NaN
# 15                         NaN                         NaN
# 16                         NaN                         NaN
# 17                         NaN                         NaN
# 18                         NaN                         NaN
#
#    preferred_mobile_alert_type              updated_at       group_id
# 1                          NaN 2024-08-07 06:29:18.596  DLNLEG8507903
# 6                          NaN 2024-08-07 06:29:18.596  DLNLEG1290799
# 7                          NaN 2024-08-07 06:29:18.596  DLNLEG1805667
# 8                          NaN 2024-08-07 06:29:18.596  DLNLEG9966100
# 9                          NaN 2024-08-07 06:29:18.596  DLNLEG6566454
# 10                         NaN 2024-08-07 06:29:18.596  DLNLEG9678391
# 11                         NaN 2024-08-07 06:29:18.596  DLNLEG5919852
# 12                         NaN 2024-08-07 06:29:18.596  DLNLEG2266684
# 13                         NaN 2024-08-07 06:29:18.596  DLNLEG7793973
# 14                         NaN 2024-08-07 06:29:18.596  DLNLEG3756805
# 15                         NaN 2024-08-07 06:29:18.596  DLNLEG3709876
# 16                         NaN 2024-08-07 06:29:18.596  DLNLEG5334058
# 17                         NaN 2024-08-07 06:29:18.596  DLNLEG1598748
# 18                         NaN 2024-08-07 06:29:18.596  DLNLEG7265178
#
# [14 rows x 490 columns]

# %%
result = pd.concat([cust_Ind,cust_leg])
shuffled = result.sample(frac=1, random_state=42).reset_index(drop=True)

shuffled.head(50)
# Out:
#            cif_id     orgkey                           cust_first_name  \
# 0   DLNIND2622447  R01516157                                    Suprim
# 1   DLNIND6943934  R01007045                                  Prithivi
# 2   DLNIND4263447  R09396490                                    Nawraj
# 3   DLNLEG9678391  R22132679              MANANG HOSPITALITY PVT. LTD.
# 4   DLNIND4269492  R00580783                                 Shrikumar
# 5   DLNLEG9681773  C00004457               TAMOR ELECTRONICS PVT. LTD.
# 6   DLNIND9286944  019898447                                    Hansha
# 7   DLNLEG6576494  R09092002                       NEPAL AIRLINES LTD.
# 8   DLNLEG2990042  C00004460             SARLAHI ENGINEERING PVT. LTD.
# 9   DLNIND9910969  R00061514                                    Poshan
# 10  DLNIND3257367  R02275983                                    Aavaas
# 11  DLNLEG5738561  R19041342                 BARDIA BUILDERS PVT. LTD.
# 12  DLNIND3732980  R29977110                                    Sakhil
# 13  DLNLEG6218579  C00038863                   KHOTANG FOODS PVT. LTD.
# 14  DLNIND2035752  R01566002                                 Anushikha
# 15  DLNLEG5919852  C00004442  RUPA SAVINGS AND CREDIT COOPERATIVE LTD.
# 16  DLNIND8778682  R52291857                                     Srija
# 17  DLNLEG5828268  R90504419       MAHENDRANAGAR CONSULTANCY PVT. LTD.
# 18  DLNIND2830344  R33297804                                      Apsa
# 19  DLNLEG5063780  R42240201              SHREE KRISHNA FOUNDATION NGO
# 20  DLNIND7537080  R00090623                                   Bashuki
# 21  DLNLEG2266684  R48318099             SAGARMATHA CLOTHING PVT. LTD.
# 22  DLNIND3744151  319749297                                 Buddhiraj
# 23  DLNIND1568693  R02169468                                   Srijeet
# 24  DLNIND8690282  R00625845                                    Ronika
# 25  DLNIND9997823  R01911516                                    Pranij
# 26  DLNIND7227326  R16155515                                   Sunanda
# 27  DLNIND6686056  R01731860                                    Hemraj
# 28  DLNIND4568821  R01562055                                     Duman
# 29  DLNLEG5142567  R23114400     BHIMSEN AGRICULTURAL COOPERATIVE LTD.
# 30  DLNLEG9749078  C00004456            NEPAL HERITAGE TOURS PVT. LTD.
# 31  DLNLEG1805667  R08272460             PATHIVARA LOGISTICS PVT. LTD.
# 32  DLNIND5601256  R01901406                                     Rajoj
# 33  DLNIND8257521  R01131729                                      Juna
# 34  DLNLEG8098419  R09403211                PALPA HEALTHCARE PVT. LTD.
# 35  DLNIND8738953  R36283925                                     Sahil
# 36  DLNIND5576304  R01082803                                      Lucy
# 37  DLNLEG3709876  C00004448          KAILASH PRINTING PRESS PVT. LTD.
# 38  DLNLEG8246037  C00004452                DLYTICA HOSPITAL PVT. LTD.
# 39  DLNIND9611726  R00960980                                    Dipika
# 40  DLNLEG7366525  R52273477                BARDIYA SECURITY PVT. LTD.
# 41  DLNIND4269310  R01266590                                   Bandana
# 42  DLNIND7445925  R00587212                                      Abid
# 43  DLNIND4157875  R02906784                               Hrisheekesh
# 44  DLNIND3186116  R01901393                                    Posraj
# 45  DLNIND9450331  R01014498                                   Avineak
# 46  DLNLEG9444528  C00000865                 JAJARKOT DAIRY CO-OP LTD.
# 47  DLNIND8726228  R00816195                                       Suk
# 48  DLNIND2129887  R01911511                                      Heli
# 49  DLNLEG5924902  R46253427                SUNSARI MANUFACTURING LTD.
#
#    cust_middle_name cust_last_name                    cust_dob   cust_type  \
# 0            Bishnu       Shrestha  1966-05-06T00:00:00.000000  INDIVIDUAL
# 1           Narayan       Adhikari  1966-04-13T00:00:00.000000  INDIVIDUAL
# 2            Bishal         Khadka  2013-01-09T00:00:00.000000  INDIVIDUAL
# 3                                   1900-01-01T00:00:00.000000       LEGAL
# 4               Ram          Yadav  2000-01-01T00:00:00.000000  INDIVIDUAL
# 5                                   2019-02-07T00:00:00.000000       LEGAL
# 6           Krishna       Adhikari  1991-06-03T00:00:00.000000  INDIVIDUAL
# 7                                   1900-01-01T00:00:00.000000       LEGAL
# 8                                   2019-02-05T00:00:00.000000       LEGAL
# 9             Gopal       Bhandari  1978-06-13T00:00:00.000000  INDIVIDUAL
# 10              Ram       Adhikari  2020-08-07T00:00:00.000000  INDIVIDUAL
# 11                                  2010-02-17T00:00:00.000000       LEGAL
# 12          Krishna           Lama  1951-01-31T00:00:00.000000  INDIVIDUAL
# 13                                  2012-11-12T00:00:00.000000       LEGAL
# 14        Saraswati       Shrestha  1997-01-28T00:00:00.000000  INDIVIDUAL
# 15                                  2017-02-07T00:00:00.000000       LEGAL
# 16          Krishna           Lama  1968-04-13T00:00:00.000000  INDIVIDUAL
# 17                                  1900-01-01T00:00:00.000000       LEGAL
# 18             Devi       Adhikari  1983-06-09T00:00:00.000000  INDIVIDUAL
# 19                                  1994-05-27T00:00:00.000000       LEGAL
# 20             Maan        Neupane  1990-01-18T00:00:00.000000  INDIVIDUAL
# 21                                  1900-01-01T00:00:00.000000       LEGAL
# 22            Bibek        Thakuri  1988-02-17T00:00:00.000000  INDIVIDUAL
# 23           Prasad         Tamang  1973-12-04T00:00:00.000000  INDIVIDUAL
# 24             Devi            Rai  1995-02-20T00:00:00.000000  INDIVIDUAL
# 25              Lal          Karki  1997-09-15T00:00:00.000000  INDIVIDUAL
# 26           Bishnu            Rai  1970-11-30T00:00:00.000000  INDIVIDUAL
# 27            Bibek          Karki  1979-03-03T00:00:00.000000  INDIVIDUAL
# 28          Narayan        Neupane  1989-11-25T00:00:00.000000  INDIVIDUAL
# 29                                  1900-01-01T00:00:00.000000       LEGAL
# 30                                  2019-02-07T00:00:00.000000       LEGAL
# 31                                  1900-01-01T00:00:00.000000       LEGAL
# 32             Hari           Rana  2002-04-15T00:00:00.000000  INDIVIDUAL
# 33        Saraswati        Neupane  1996-10-02T00:00:00.000000  INDIVIDUAL
# 34                                  2015-09-06T00:00:00.000000       LEGAL
# 35          Bahadur          Yadav  1986-08-11T00:00:00.000000  INDIVIDUAL
# 36            Laxmi          Regmi  1982-03-02T00:00:00.000000  INDIVIDUAL
# 37                                  2009-10-22T00:00:00.000000       LEGAL
# 38                                  2018-05-17T00:00:00.000000       LEGAL
# 39        Saraswati       Adhikari  2001-04-14T00:00:00.000000  INDIVIDUAL
# 40                                  1986-08-17T00:00:00.000000       LEGAL
# 41              Lal        Acharya  1997-08-30T00:00:00.000000  INDIVIDUAL
# 42            Gopal         Khadka  2000-01-01T00:00:00.000000  INDIVIDUAL
# 43              Dev         Khadka  1959-09-29T00:00:00.000000  INDIVIDUAL
# 44           Bhakta          Dahal  1978-10-01T00:00:00.000000  INDIVIDUAL
# 45           Bishal         Pandey  1959-10-16T00:00:00.000000  INDIVIDUAL
# 46                                  2011-02-07T00:00:00.000000       LEGAL
# 47           Bishal         Sharma  2019-03-29T00:00:00.000000  INDIVIDUAL
# 48        Saraswati        Acharya  1959-01-27T00:00:00.000000  INDIVIDUAL
# 49                                  1900-01-01T00:00:00.000000       LEGAL
#
#    gender  education           pan  ... creditbureauscorevalidity  \
# 0       M        NaN  PAN288484684  ...                       NaN
# 1       M        NaN  PAN733986970  ...                       NaN
# 2       M        NaN  PAN602858021  ...                       NaN
# 3                NaN  PAN432548863  ...                       NaN
# 4       M        NaN  PAN861110758  ...                       NaN
# 5                NaN  PAN600210736  ...                       NaN
# 6       M        NaN  PAN140168943  ...                       NaN
# 7                NaN  PAN813377590  ...                       NaN
# 8                NaN  PAN608705773  ...                       NaN
# 9       M        NaN  PAN170015742  ...                       NaN
# 10      M        NaN  PAN727567807  ...                       NaN
# 11               NaN  PAN183074119  ...                       NaN
# 12      M        NaN  PAN683139342  ...                       NaN
# 13               NaN  PAN533918346  ...                       NaN
# 14      F        NaN  PAN630828841  ...                       NaN
# 15               NaN  PAN723809886  ...                       NaN
# 16      M        NaN  PAN773963914  ...                       NaN
# 17               NaN  PAN649400480  ...                       NaN
# 18      F        NaN  PAN755710007  ...                       NaN
# 19               NaN  PAN642854936  ...                       NaN
# 20      M        NaN  PAN479408245  ...                       NaN
# 21               NaN  PAN940651973  ...                       NaN
# 22      M        NaN  PAN143048430  ...                       NaN
# 23      M        NaN  PAN651060348  ...                       NaN
# 24      F        NaN  PAN234402002  ...                       NaN
# 25      M        NaN  PAN859562290  ...                       NaN
# 26      M        NaN  PAN613246502  ...                       NaN
# 27      M        NaN  PAN871531890  ...                       NaN
# 28      M        NaN  PAN714271279  ...                       NaN
# 29               NaN  PAN491606593  ...                       NaN
# 30               NaN  PAN269568742  ...                       NaN
# 31               NaN  PAN629114031  ...                       NaN
# 32      M        NaN  PAN185594326  ...                       NaN
# 33      F        NaN  PAN873721196  ...                       NaN
# 34               NaN  PAN954062163  ...                       NaN
# 35      M        NaN  PAN401676066  ...                       NaN
# 36      F        NaN  PAN747150056  ...                       NaN
# 37               NaN  PAN880276201  ...                       NaN
# 38               NaN  PAN888268690  ...                       NaN
# 39      F        NaN  PAN153589712  ...                       NaN
# 40               NaN  PAN549095519  ...                       NaN
# 41      M        NaN  PAN473804509  ...                       NaN
# 42      M        NaN  PAN409564003  ...                       NaN
# 43      M        NaN  PAN847554163  ...                       NaN
# 44      M        NaN  PAN108679158  ...                       NaN
# 45      M        NaN  PAN642077006  ...                       NaN
# 46               NaN  PAN558406246  ...                       NaN
# 47      M        NaN  PAN960707979  ...                       NaN
# 48      F        NaN  PAN502308017  ...                       NaN
# 49               NaN  PAN596302582  ...                       NaN
#
#    foreignacctaxreportingreq  foreigntaxreportingstatus  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
# 5                        NaN                        NaN
# 6                        NaN                        NaN
# 7                        NaN                        NaN
# 8                        NaN                        NaN
# 9                        NaN                        NaN
# 10                       NaN                        NaN
# 11                       NaN                        NaN
# 12                       NaN                        NaN
# 13                       NaN                        NaN
# 14                       NaN                        NaN
# 15                       NaN                        NaN
# 16                       NaN                        NaN
# 17                       NaN                        NaN
# 18                       NaN                        NaN
# 19                       NaN                        NaN
# 20                       NaN                        NaN
# 21                       NaN                        NaN
# 22                       NaN                        NaN
# 23                       NaN                        NaN
# 24                       NaN                        NaN
# 25                       NaN                        NaN
# 26                       NaN                        NaN
# 27                       NaN                        NaN
# 28                       NaN                        NaN
# 29                       NaN                        NaN
# 30                       NaN                        NaN
# 31                       NaN                        NaN
# 32                       NaN                        NaN
# 33                       NaN                        NaN
# 34                       NaN                        NaN
# 35                       NaN                        NaN
# 36                       NaN                        NaN
# 37                       NaN                        NaN
# 38                       NaN                        NaN
# 39                       NaN                        NaN
# 40                       NaN                        NaN
# 41                       NaN                        NaN
# 42                       NaN                        NaN
# 43                       NaN                        NaN
# 44                       NaN                        NaN
# 45                       NaN                        NaN
# 46                       NaN                        NaN
# 47                       NaN                        NaN
# 48                       NaN                        NaN
# 49                       NaN                        NaN
#
#     preferred_mobile_alert_no  credithistoryrequestedflag  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
# 5                         NaN                         NaN
# 6                         NaN                         NaN
# 7                         NaN                         NaN
# 8                         NaN                         NaN
# 9                         NaN                         NaN
# 10                        NaN                         NaN
# 11                        NaN                         NaN
# 12                        NaN                         NaN
# 13                        NaN                         NaN
# 14                        NaN                         NaN
# 15                        NaN                         NaN
# 16                        NaN                         NaN
# 17                        NaN                         NaN
# 18                        NaN                         NaN
# 19                        NaN                         NaN
# 20                        NaN                         NaN
# 21                        NaN                         NaN
# 22                        NaN                         NaN
# 23                        NaN                         NaN
# 24                        NaN                         NaN
# 25                        NaN                         NaN
# 26                        NaN                         NaN
# 27                        NaN                         NaN
# 28                        NaN                         NaN
# 29                        NaN                         NaN
# 30                        NaN                         NaN
# 31                        NaN                         NaN
# 32                        NaN                         NaN
# 33                        NaN                         NaN
# 34                        NaN                         NaN
# 35                        NaN                         NaN
# 36                        NaN                         NaN
# 37                        NaN                         NaN
# 38                        NaN                         NaN
# 39                        NaN                         NaN
# 40                        NaN                         NaN
# 41                        NaN                         NaN
# 42                        NaN                         NaN
# 43                        NaN                         NaN
# 44                        NaN                         NaN
# 45                        NaN                         NaN
# 46                        NaN                         NaN
# 47                        NaN                         NaN
# 48                        NaN                         NaN
# 49                        NaN                         NaN
#
#     foreigntaxreportingcountry customer_level_provisioning  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# 5                          NaN                         NaN
# 6                          NaN                         NaN
# 7                          NaN                         NaN
# 8                          NaN                         NaN
# 9                          NaN                         NaN
# 10                         NaN                         NaN
# 11                         NaN                         NaN
# 12                         NaN                         NaN
# 13                         NaN                         NaN
# 14                         NaN                         NaN
# 15                         NaN                         NaN
# 16                         NaN                         NaN
# 17                         NaN                         NaN
# 18                         NaN                         NaN
# 19                         NaN                         NaN
# 20                         NaN                         NaN
# 21                         NaN                         NaN
# 22                         NaN                         NaN
# 23                         NaN                         NaN
# 24                         NaN                         NaN
# 25                         NaN                         NaN
# 26                         NaN                         NaN
# 27                         NaN                         NaN
# 28                         NaN                         NaN
# 29                         NaN                         NaN
# 30                         NaN                         NaN
# 31                         NaN                         NaN
# 32                         NaN                         NaN
# 33                         NaN                         NaN
# 34                         NaN                         NaN
# 35                         NaN                         NaN
# 36                         NaN                         NaN
# 37                         NaN                         NaN
# 38                         NaN                         NaN
# 39                         NaN                         NaN
# 40                         NaN                         NaN
# 41                         NaN                         NaN
# 42                         NaN                         NaN
# 43                         NaN                         NaN
# 44                         NaN                         NaN
# 45                         NaN                         NaN
# 46                         NaN                         NaN
# 47                         NaN                         NaN
# 48                         NaN                         NaN
# 49                         NaN                         NaN
#
#    preferred_mobile_alert_type              updated_at       group_id
# 0                          NaN 2024-08-07 06:29:18.596  DLNIND2622447
# 1                          NaN 2024-08-07 06:29:18.596  DLNIND6943934
# 2                          NaN 2024-08-07 06:29:18.596  DLNIND4263447
# 3                          NaN 2024-08-07 06:29:18.596  DLNLEG9678391
# 4                          NaN 2024-08-07 06:29:18.596  DLNIND4269492
# 5                          NaN 2024-08-07 06:29:18.596  DLNLEG9681773
# 6                          NaN 2024-08-07 06:29:18.596  DLNIND9286944
# 7                          NaN 2024-08-07 06:29:18.596  DLNLEG6576494
# 8                          NaN 2024-08-07 06:29:18.596  DLNLEG2990042
# 9                          NaN 2024-08-07 06:29:18.596  DLNIND9910969
# 10                         NaN 2024-08-07 06:29:18.596  DLNIND3257367
# 11                         NaN 2024-08-07 06:29:18.596  DLNLEG5738561
# 12                         NaN 2024-08-07 06:29:18.596  DLNIND3732980
# 13                         NaN 2024-08-07 06:29:18.596  DLNLEG6218579
# 14                         NaN 2024-08-07 06:29:18.596  DLNIND2035752
# 15                         NaN 2024-08-07 06:29:18.596  DLNLEG5919852
# 16                         NaN 2024-08-07 06:29:18.596  DLNIND8778682
# 17                         NaN 2024-08-07 06:29:18.596  DLNLEG5828268
# 18                         NaN 2024-08-07 06:29:18.596  DLNIND2830344
# 19                         NaN 2024-08-07 06:29:18.596  DLNLEG5063780
# 20                         NaN 2024-08-07 06:29:18.596  DLNIND7537080
# 21                         NaN 2024-08-07 06:29:18.596  DLNLEG2266684
# 22                         NaN 2024-08-07 06:29:18.596  DLNIND3744151
# 23                         NaN 2024-08-07 06:29:18.596  DLNIND1568693
# 24                         NaN 2024-08-07 06:29:18.596  DLNIND8690282
# 25                         NaN 2024-08-07 06:29:18.596  DLNIND9997823
# 26                         NaN 2024-08-07 06:29:18.596  DLNIND7227326
# 27                         NaN 2024-08-07 06:29:18.596  DLNIND6686056
# 28                         NaN 2024-08-07 06:29:18.596  DLNIND4568821
# 29                         NaN 2024-08-07 06:29:18.596  DLNLEG5142567
# 30                         NaN 2024-08-07 06:29:18.596  DLNLEG9749078
# 31                         NaN 2024-08-07 06:29:18.596  DLNLEG1805667
# 32                         NaN 2024-08-07 06:29:18.596  DLNIND5601256
# 33                         NaN 2024-08-07 06:29:18.596  DLNIND8257521
# 34                         NaN 2024-08-07 06:29:18.596  DLNLEG8098419
# 35                         NaN 2024-08-07 06:29:18.596  DLNIND8738953
# 36                         NaN 2024-08-07 06:29:18.596  DLNIND5576304
# 37                         NaN 2024-08-07 06:29:18.596  DLNLEG3709876
# 38                         NaN 2024-08-07 06:29:18.596  DLNLEG8246037
# 39                         NaN 2024-08-07 06:29:18.596  DLNIND9611726
# 40                         NaN 2024-08-07 06:29:18.596  DLNLEG7366525
# 41                         NaN 2024-08-07 06:29:18.596  DLNIND4269310
# 42                         NaN 2024-08-07 06:29:18.596  DLNIND7445925
# 43                         NaN 2024-08-07 06:29:18.596  DLNIND4157875
# 44                         NaN 2024-08-07 06:29:18.596  DLNIND3186116
# 45                         NaN 2024-08-07 06:29:18.596  DLNIND9450331
# 46                         NaN 2024-08-07 06:29:18.596  DLNLEG9444528
# 47                         NaN 2024-08-07 06:29:18.596  DLNIND8726228
# 48                         NaN 2024-08-07 06:29:18.596  DLNIND2129887
# 49                         NaN 2024-08-07 06:29:18.596  DLNLEG5924902
#
# [50 rows x 490 columns]

# %%
import numpy as np

def generate_email(data):
    # Extract first name (handle NaN and company names)
    first_name = str(data["cust_first_name"]) if not pd.isna(data["cust_first_name"]) else "unknown"
    
    # Remove "PVT. LTD." or "LTD." and clean the name
    name = (
        first_name.replace("PVT. LTD.", "")
                 .replace("LTD.", "")
                 .strip() 
                 .lower()  
                 .replace(" ", "")
    )
    
    num = str(np.random.randint(100, 999))
    
    if data["cust_type"] == "INDIVIDUAL":
        email = f"{name}{num}@gmail.com"
    else:
        email = f"{name}{num}@outlook.com"
    
    return email

# Apply the function to the DataFrame
shuffled["email"] = shuffled[["cust_first_name", "cust_type"]].apply(generate_email, axis=1)

# Display first 15 generated emails
shuffled["email"].head(15)
# Out:
# 0                   suprim368@gmail.com
# 1                 prithivi535@gmail.com
# 2                   nawraj135@gmail.com
# 3      mananghospitality262@outlook.com
# 4                shrikumar923@gmail.com
# 5       tamorelectronics865@outlook.com
# 6                   hansha676@gmail.com
# 7          nepalairlines939@outlook.com
# 8     sarlahiengineering869@outlook.com
# 9                   poshan218@gmail.com
# 10                  aavaas614@gmail.com
# 11        bardiabuilders660@outlook.com
# 12                  sakhil952@gmail.com
# 13          khotangfoods840@outlook.com
# 14               anushikha296@gmail.com
# Name: email, dtype: object

# %%
def generate_phone_number(data):
   return  "+977-98"+str(np.random.randint(10000000,99999999))

shuffled["preferredphone"] = shuffled["preferredphone"].apply(generate_phone_number)
shuffled["preferredphone"].head(10)
# Out:
# 0    +977-9854509648
# 1    +977-9851839113
# 2    +977-9869221896
# 3    +977-9885898458
# 4    +977-9856942193
# 5    +977-9812775674
# 6    +977-9855894680
# 7    +977-9856247781
# 8    +977-9829817173
# 9    +977-9879603979
# Name: preferredphone, dtype: object

# %%
Ind_cust = shuffled[shuffled["cust_type"] == "INDIVIDUAL"]
print(len(Ind_cust))
# Out:
# 71

# %%
first_5 = Ind_cust.iloc[:5]        
remaining = Ind_cust.iloc[5:]

# %%
first_5.head()
# Out:
#           cif_id     orgkey cust_first_name cust_middle_name cust_last_name  \
# 0  DLNIND2622447  R01516157          Suprim           Bishnu       Shrestha
# 1  DLNIND6943934  R01007045        Prithivi          Narayan       Adhikari
# 2  DLNIND4263447  R09396490          Nawraj           Bishal         Khadka
# 4  DLNIND4269492  R00580783       Shrikumar              Ram          Yadav
# 6  DLNIND9286944  019898447          Hansha          Krishna       Adhikari
#
#                      cust_dob   cust_type gender  education           pan  \
# 0  1966-05-06T00:00:00.000000  INDIVIDUAL      M        NaN  PAN288484684
# 1  1966-04-13T00:00:00.000000  INDIVIDUAL      M        NaN  PAN733986970
# 2  2013-01-09T00:00:00.000000  INDIVIDUAL      M        NaN  PAN602858021
# 4  2000-01-01T00:00:00.000000  INDIVIDUAL      M        NaN  PAN861110758
# 6  1991-06-03T00:00:00.000000  INDIVIDUAL      M        NaN  PAN140168943
#
#    ... creditbureauscorevalidity foreignacctaxreportingreq  \
# 0  ...                       NaN                       NaN
# 1  ...                       NaN                       NaN
# 2  ...                       NaN                       NaN
# 4  ...                       NaN                       NaN
# 6  ...                       NaN                       NaN
#
#    foreigntaxreportingstatus  preferred_mobile_alert_no  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 4                        NaN                        NaN
# 6                        NaN                        NaN
#
#    credithistoryrequestedflag  foreigntaxreportingcountry  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 4                         NaN                         NaN
# 6                         NaN                         NaN
#
#   customer_level_provisioning preferred_mobile_alert_type  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 4                         NaN                         NaN
# 6                         NaN                         NaN
#
#                updated_at       group_id
# 0 2024-08-07 06:29:18.596  DLNIND2622447
# 1 2024-08-07 06:29:18.596  DLNIND6943934
# 2 2024-08-07 06:29:18.596  DLNIND4263447
# 4 2024-08-07 06:29:18.596  DLNIND4269492
# 6 2024-08-07 06:29:18.596  DLNIND9286944
#
# [5 rows x 490 columns]

# %%
import pandas as pd
import numpy as np

# Create sample data
data = {
    'cust_first_name': ['Prashanta', 'Kabita', 'sandal', 'sirish', 'Veshraj'],
    'cust_middle_name': ['Babu', '', '', '', ''],
    'cust_last_name': ['Thapa', 'Bhattarai', 'Tandukar', 'poudel', 'Mainali'],
    'preferredphone': ['9810288411', '9866180896', '9861396794', '9861632577', '9861674997'],
    'email': ['Prashant.babu@dlytica.com', 'kabita.bhattarai@dlytica.com', 'sandil.tandukar@dlytica.com', 'sirish.poudel@dlytica.com', 'Veshraj.Mainali@dlytica.com'],
    'preferredemail': ['john.smith@example.com', 'emily.johnson@example.com', 'michael.williams@example.com', 'sarah.brown@example.com', 'david.jones@example.com'],
    'gender':['M', 'F', 'M', 'M', 'M'],
}

# Create DataFrame
df = pd.DataFrame(data)

df.head()
# Out:
#   cust_first_name cust_middle_name cust_last_name preferredphone  \
# 0       Prashanta             Babu          Thapa     9810288411
# 1          Kabita                       Bhattarai     9866180896
# 2          sandal                        Tandukar     9861396794
# 3          sirish                          poudel     9861632577
# 4         Veshraj                         Mainali     9861674997
#
#                           email                preferredemail gender
# 0     Prashant.babu@dlytica.com        john.smith@example.com      M
# 1  kabita.bhattarai@dlytica.com     emily.johnson@example.com      F
# 2   sandil.tandukar@dlytica.com  michael.williams@example.com      M
# 3     sirish.poudel@dlytica.com       sarah.brown@example.com      M
# 4   Veshraj.Mainali@dlytica.com       david.jones@example.com      M

# %%
first_5["cust_first_name"] = df["cust_first_name"].values
first_5["cust_middle_name"] = df["cust_middle_name"].values
first_5["cust_last_name"] = df["cust_last_name"].values
first_5["preferredphone"] = df["preferredphone"].values
first_5["email"] = df["email"].values
first_5["gender"] = df["gender"].values
first_5["preferredemail"] = df["email"].values
first_5["name"] = df["cust_first_name"].values + " " + df["cust_middle_name"].values + " " + df["cust_last_name"].values
first_5["preferredname"] = df["cust_first_name"].values + " " + df["cust_middle_name"].values + " " + df["cust_last_name"].values
first_5.head()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\1744550957.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_5["cust_first_name"] = df["cust_first_name"].values
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\1744550957.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_5["cust_middle_name"] = df["cust_middle_name"].values
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\1744550957.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_5["cust_last_name"] = df["cust_last_name"].values
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\1744550957.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_5["preferredphone"] = df["preferredphone"].values
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\1744550957.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_5["email"] = df["email"].values
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\1744550957.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_5["gender"] = df["gender"].values
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\1744550957.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_5["preferredemail"] = df["email"].values
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\1744550957.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_5["name"] = df["cust_first_name"].values + " " + df["cust_middle_name"].values + " " + df["cust_last_name"].values
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6976\1744550957.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_5["preferredname"] = df["cust_first_name"].values + " " + df["cust_middle_name"].values + " " + df["cust_last_name"].values
#           cif_id     orgkey cust_first_name cust_middle_name cust_last_name  \
# 0  DLNIND2622447  R01516157       Prashanta             Babu          Thapa
# 1  DLNIND6943934  R01007045          Kabita                       Bhattarai
# 2  DLNIND4263447  R09396490          sandal                        Tandukar
# 4  DLNIND4269492  R00580783          sirish                          poudel
# 6  DLNIND9286944  019898447         Veshraj                         Mainali
#
#                      cust_dob   cust_type gender  education           pan  \
# 0  1966-05-06T00:00:00.000000  INDIVIDUAL      M        NaN  PAN288484684
# 1  1966-04-13T00:00:00.000000  INDIVIDUAL      F        NaN  PAN733986970
# 2  2013-01-09T00:00:00.000000  INDIVIDUAL      M        NaN  PAN602858021
# 4  2000-01-01T00:00:00.000000  INDIVIDUAL      M        NaN  PAN861110758
# 6  1991-06-03T00:00:00.000000  INDIVIDUAL      M        NaN  PAN140168943
#
#    ... creditbureauscorevalidity foreignacctaxreportingreq  \
# 0  ...                       NaN                       NaN
# 1  ...                       NaN                       NaN
# 2  ...                       NaN                       NaN
# 4  ...                       NaN                       NaN
# 6  ...                       NaN                       NaN
#
#    foreigntaxreportingstatus  preferred_mobile_alert_no  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 4                        NaN                        NaN
# 6                        NaN                        NaN
#
#    credithistoryrequestedflag  foreigntaxreportingcountry  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 4                         NaN                         NaN
# 6                         NaN                         NaN
#
#   customer_level_provisioning preferred_mobile_alert_type  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 4                         NaN                         NaN
# 6                         NaN                         NaN
#
#                updated_at       group_id
# 0 2024-08-07 06:29:18.596  DLNIND2622447
# 1 2024-08-07 06:29:18.596  DLNIND6943934
# 2 2024-08-07 06:29:18.596  DLNIND4263447
# 4 2024-08-07 06:29:18.596  DLNIND4269492
# 6 2024-08-07 06:29:18.596  DLNIND9286944
#
# [5 rows x 490 columns]

# %%
leg_cust = shuffled[shuffled["cust_type"] == "LEGAL"]
print(len(Ind_cust))
# Out:
# 71

# %%
result = pd.concat([first_5,remaining,leg_cust])
shuffled = result.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
shuffled.head()
# Out:
#           cif_id     orgkey          cust_first_name cust_middle_name  \
# 0  DLNIND4568821  R01562055                    Duman          Narayan
# 1  DLNIND7235296  R01911512                  Prajina             Devi
# 2  DLNIND1406504  R02944296                Humacanta            Bipin
# 3  DLNLEG6218579  C00038863  KHOTANG FOODS PVT. LTD.
# 4  DLNIND1255130  R01651971                   Adarsh           Bhakta
#
#   cust_last_name                    cust_dob   cust_type gender  education  \
# 0        Neupane  1989-11-25T00:00:00.000000  INDIVIDUAL      M        NaN
# 1       Maharjan  1971-05-05T00:00:00.000000  INDIVIDUAL      F        NaN
# 2          Thapa  2005-05-18T00:00:00.000000  INDIVIDUAL      M        NaN
# 3                 2012-11-12T00:00:00.000000       LEGAL               NaN
# 4           Lama  1993-02-28T00:00:00.000000  INDIVIDUAL      M        NaN
#
#             pan  ... creditbureauscorevalidity foreignacctaxreportingreq  \
# 0  PAN714271279  ...                       NaN                       NaN
# 1  PAN503838478  ...                       NaN                       NaN
# 2  PAN668645879  ...                       NaN                       NaN
# 3  PAN533918346  ...                       NaN                       NaN
# 4  PAN331700070  ...                       NaN                       NaN
#
#    foreigntaxreportingstatus  preferred_mobile_alert_no  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    credithistoryrequestedflag  foreigntaxreportingcountry  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   customer_level_provisioning preferred_mobile_alert_type  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#                updated_at       group_id
# 0 2024-08-07 06:29:18.596  DLNIND4568821
# 1 2024-08-07 06:29:18.596  DLNIND7235296
# 2 2024-08-07 06:29:18.596  DLNIND1406504
# 3 2024-08-07 06:29:18.596  DLNLEG6218579
# 4 2024-08-07 06:29:18.596  DLNIND1255130
#
# [5 rows x 490 columns]

# %%
shuffled.to_csv('../../&&&&&&&&&&&&&&account_masked.csv', index=False)

# %%
df = pd.read_csv("cif_masked.csv")

# %%
get_masked = pd.read_csv("_masked.csv")

# %%
get_masked[["cif_id",
            "orgkey",
            "cust_first_name",
            "cust_middle_name",
            "cust_last_name",
            "preferredphone",
            "preferredname",
            "preferredemail",
            "email",
            "gender",
            "name",
            "pan",]].to_csv('cif_masked.csv', index=False)

# %%
df = pd.read_csv("cif_masked.csv")

# %%
df.head()
# Out:
#           cif_id     orgkey          cust_first_name cust_middle_name  \
# 0  DLNIND4568821  R01562055                    Duman          Narayan
# 1  DLNIND7235296  R01911512                  Prajina             Devi
# 2  DLNIND1406504  R02944296                Humacanta            Bipin
# 3  DLNLEG6218579  C00038863  KHOTANG FOODS PVT. LTD.              NaN
# 4  DLNIND1255130  R01651971                   Adarsh           Bhakta
#
#   cust_last_name   preferredphone                  preferredname  \
# 0        Neupane  +977-9833330190          Duman Narayan Neupane
# 1       Maharjan  +977-9892307589          Prajina Devi Maharjan
# 2          Thapa  +977-9856818453          Humacanta Bipin Thapa
# 3            NaN  +977-9862721402  MANASLU HOSPITALITY PVT. LTD.
# 4           Lama  +977-9810013657             Adarsh Bhakta Lama
#
#              preferredemail                        email gender  \
# 0     ARYALPRABAL@GMAIL.COM           duman492@gmail.com      M
# 1        na@nicasiabank.com         prajina427@gmail.com      F
# 2  dipeshshah4000@gmail.com       humacanta862@gmail.com      M
# 3                       NaN  khotangfoods840@outlook.com    NaN
# 4      BINODRAYEE@GMAIL.COM          adarsh904@gmail.com      M
#
#                       name           pan
# 0    Duman Narayan Neupane  PAN714271279
# 1    Prajina Devi Maharjan  PAN503838478
# 2    Humacanta Bipin Thapa  PAN668645879
# 3  KHOTANG FOODS PVT. LTD.  PAN533918346
# 4       Adarsh Bhakta Lama  PAN331700070

# %%
result_df = shuffled.merge(
    df,
    on='orgkey',
    how='left',
    suffixes=('_p', '_a')
)

print(f"Original df length: {len(df)}")
print(f"Merged result length: {len(result_df)}")
# Out:
# Original df length: 125
# Merged result length: 125

# %%
result_df[["orgkey","cif_id_a"]].head()
# Out:
#       orgkey       cif_id_a
# 0  R01562055  DLNIND4568821
# 1  R01911512  DLNIND7235296
# 2  R02944296  DLNIND1406504
# 3  C00038863  DLNLEG6218579
# 4  R01651971  DLNIND1255130

# %%
shuffled["cif_id"] = result_df["cif_id_a"].values
shuffled["pan"] = result_df["pan_a"].values
shuffled["cust_first_name"] = result_df["cust_first_name_a"].values
shuffled["cust_middle_name"] = result_df["cust_middle_name_a"].values
shuffled["cust_last_name"] = result_df["cust_last_name_a"].values
shuffled["preferredphone"] = result_df["preferredphone_a"].values
shuffled["email"] = result_df["email_a"].values
shuffled["gender"] = result_df["gender_a"].values
shuffled["preferredemail"] = result_df["email_a"].values
shuffled["name"] = result_df["name_a"].values
shuffled["preferredname"] = result_df["preferredname_a"].values
shuffled["preferredemail"] = result_df["email_a"].values

# %%
shuffled.head()
# Out:
#           cif_id     orgkey          cust_first_name cust_middle_name  \
# 0  DLNIND4568821  R01562055                    Duman          Narayan
# 1  DLNIND7235296  R01911512                  Prajina             Devi
# 2  DLNIND1406504  R02944296                Humacanta            Bipin
# 3  DLNLEG6218579  C00038863  KHOTANG FOODS PVT. LTD.              NaN
# 4  DLNIND1255130  R01651971                   Adarsh           Bhakta
#
#   cust_last_name                    cust_dob   cust_type gender  education  \
# 0        Neupane  1989-11-25T00:00:00.000000  INDIVIDUAL      M        NaN
# 1       Maharjan  1971-05-05T00:00:00.000000  INDIVIDUAL      F        NaN
# 2          Thapa  2005-05-18T00:00:00.000000  INDIVIDUAL      M        NaN
# 3            NaN  2012-11-12T00:00:00.000000       LEGAL    NaN        NaN
# 4           Lama  1993-02-28T00:00:00.000000  INDIVIDUAL      M        NaN
#
#             pan  ... creditbureauscorevalidity foreignacctaxreportingreq  \
# 0  PAN714271279  ...                       NaN                       NaN
# 1  PAN503838478  ...                       NaN                       NaN
# 2  PAN668645879  ...                       NaN                       NaN
# 3  PAN533918346  ...                       NaN                       NaN
# 4  PAN331700070  ...                       NaN                       NaN
#
#    foreigntaxreportingstatus  preferred_mobile_alert_no  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    credithistoryrequestedflag  foreigntaxreportingcountry  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   customer_level_provisioning preferred_mobile_alert_type  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#                updated_at       group_id
# 0 2024-08-07 06:29:18.596  DLNIND4568821
# 1 2024-08-07 06:29:18.596  DLNIND7235296
# 2 2024-08-07 06:29:18.596  DLNIND1406504
# 3 2024-08-07 06:29:18.596  DLNLEG6218579
# 4 2024-08-07 06:29:18.596  DLNIND1255130
#
# [5 rows x 490 columns]

# %%
shuffled = shuffled.drop("orgkey", axis=1)

# %%
shuffled.to_csv('account_masked.csv', index=False)
