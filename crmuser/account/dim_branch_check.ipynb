# %%
import pandas as pd

# %%
df_cust = pd.read_csv('account_masked3.csv')
df_bra = pd.read_csv('dim_branch.csv')

# %%
df_cust.head()
# Out:
#           orgkey          cust_first_name cust_middle_name cust_last_name  \
# 0  DLNIND4568821                    Duman          Narayan        Neupane
# 1  DLNIND7235296                  Prajina             Devi       Maharjan
# 2  DLNIND1406504                Humacanta            Bipin          Thapa
# 3  DLNLEG6218579  KHOTANG FOODS PVT. LTD.              NaN            NaN
# 4  DLNIND1255130                   Adarsh           Bhakta           Lama
#
#                      cust_dob   cust_type gender  education           pan  \
# 0  1989-11-25T00:00:00.000000  INDIVIDUAL      M        NaN  PAN714271279
# 1  1971-05-05T00:00:00.000000  INDIVIDUAL      F        NaN  PAN503838478
# 2  2005-05-18T00:00:00.000000  INDIVIDUAL      M        NaN  PAN668645879
# 3  2012-11-12T00:00:00.000000       LEGAL    NaN        NaN  PAN533918346
# 4  1993-02-28T00:00:00.000000  INDIVIDUAL      M        NaN  PAN331700070
#
#                          email  ...  creditbureauscorevalidity  \
# ...

# %%
print(df_bra.shape)
print(df_cust.shape)
# Out:
# (361, 14)
# (125, 489)

# %%
df_bra.head()
# Out:
#   branch_sol_id            branch_open_date city_code            address1  \
# 0            07  2008-09-08T00:00:00.000000     BANEP              BANEPA
# 1            11  2009-01-19T00:00:00.000000     KATHM  CHHETRAPATI BRANCH
# 2            13  2009-05-03T00:00:00.000000     KATHM         MAHARAJGUJN
# 3            14  2009-05-03T00:00:00.000000     BHARA         NARAYANGARH
# 4            04  2008-06-01T00:00:00.000000     ITAHA             ITAHARI
#
#     address2 branch_code  branch_description state_code lchg_user_id  \
# 0        NaN          07       BANEPA BRANCH      BAGMA     FINADMIN
# 1        NaN          11  CHHETRAPATI BRANCH      BAGMA     FINADMIN
# 2  KATHMANDU          13  MAHARAJGUNJ BRANCH      BAGMA     FINADMIN
# 3        NaN          14  NARAYANGARH BRANCH      NARAY     FINADMIN
# 4        NaN          04      ITAHARI BRANCH      KOSHI     FINADMIN
#
#                    lchg_time province_name sub_provincial          hub_name  \
# ...

# %%
df_data = df_cust.merge(df_bra, how='left', left_on='primary_sol_id', right_on='branch_sol_id', suffixes=('_cus', '_bra'))

# %%
df_data.head()
# Out:
#           orgkey          cust_first_name cust_middle_name cust_last_name  \
# 0  DLNIND4568821                    Duman          Narayan        Neupane
# 1  DLNIND7235296                  Prajina             Devi       Maharjan
# 2  DLNIND1406504                Humacanta            Bipin          Thapa
# 3  DLNLEG6218579  KHOTANG FOODS PVT. LTD.              NaN            NaN
# 4  DLNIND1255130                   Adarsh           Bhakta           Lama
#
#                      cust_dob   cust_type gender  education           pan  \
# 0  1989-11-25T00:00:00.000000  INDIVIDUAL      M        NaN  PAN714271279
# 1  1971-05-05T00:00:00.000000  INDIVIDUAL      F        NaN  PAN503838478
# 2  2005-05-18T00:00:00.000000  INDIVIDUAL      M        NaN  PAN668645879
# 3  2012-11-12T00:00:00.000000       LEGAL    NaN        NaN  PAN533918346
# 4  1993-02-28T00:00:00.000000  INDIVIDUAL      M        NaN  PAN331700070
#
#                          email  ...  address2  branch_code  \
# ...

# %%
df_data[['primary_sol_id', 'branch_sol_id', 'branch_description']].head(40)
# Out:
#    primary_sol_id branch_sol_id              branch_description
# 0              21            21                KAUSALTAR BRANCH
# 1              42            42                MALANGAWA BRANCH
# 2              Q3            Q3                 LINKROAD BRANCH
# 3              D2            D2                 TARAHARA BRANCH
# 4              26            26                   GWARKO BRANCH
# 5              68            68                         HETAUDA
# 6              52            52                   SIRAHA BRANCH
# 7              F1            F1                KOTHIHAWA BRANCH
# 8              I4            I4                   GAJURI BRANCH
# 9               1           NaN                             NaN
# 10             S9            S9                 BHANDARA BRANCH
# 11             V7            V7                 PHARPING BRANCH
# 12             F8            F8             JITPUR 4 NUM BRANCH
# 13             A8            A8                   DUHABI BRANCH
# ...

# %%
df_result  = df_data[df_data['primary_sol_id']!= df_data['branch_sol_id']]
df_result['primary_sol_id'].unique()
# Out:
# array(['1', '2', '9', '8', '4', '5'], dtype=object)

# %%
df_result.to_csv('dim_branch_check.csv', index=False)

# %%
print(len(df_data['primary_sol_id'].head()))
# Out:
# 5

# %%
df_res = df_data.where(df_data['branch_description'].isnull())
df_res.head(10)
# Out:
#           orgkey cust_first_name cust_middle_name cust_last_name  \
# 0            NaN             NaN              NaN            NaN
# 1            NaN             NaN              NaN            NaN
# 2            NaN             NaN              NaN            NaN
# 3            NaN             NaN              NaN            NaN
# 4            NaN             NaN              NaN            NaN
# 5            NaN             NaN              NaN            NaN
# 6            NaN             NaN              NaN            NaN
# 7            NaN             NaN              NaN            NaN
# 8            NaN             NaN              NaN            NaN
# 9  DLNIND9286944         Veshraj              NaN        Mainali
#
#                      cust_dob   cust_type gender  education           pan  \
# 0                         NaN         NaN    NaN        NaN           NaN
# 1                         NaN         NaN    NaN        NaN           NaN
# ...

# %%
df_res.shape
# Out:
# (125, 503)

# %%
df_cust[df["cif_id "]].head()
# Out:
#           orgkey          cust_first_name cust_middle_name cust_last_name  \
# 0  DLNIND4568821                    Duman          Narayan        Neupane
# 1  DLNIND7235296                  Prajina             Devi       Maharjan
# 2  DLNIND1406504                Humacanta            Bipin          Thapa
# 3  DLNLEG6218579  KHOTANG FOODS PVT. LTD.              NaN            NaN
# 4  DLNIND1255130                   Adarsh           Bhakta           Lama
#
#                      cust_dob   cust_type gender  education           pan  \
# 0  1989-11-25T00:00:00.000000  INDIVIDUAL      M        NaN  PAN714271279
# 1  1971-05-05T00:00:00.000000  INDIVIDUAL      F        NaN  PAN503838478
# 2  2005-05-18T00:00:00.000000  INDIVIDUAL      M        NaN  PAN668645879
# 3  2012-11-12T00:00:00.000000       LEGAL    NaN        NaN  PAN533918346
# 4  1993-02-28T00:00:00.000000  INDIVIDUAL      M        NaN  PAN331700070
#
#                          email  ...  creditbureauscorevalidity  \
# ...
