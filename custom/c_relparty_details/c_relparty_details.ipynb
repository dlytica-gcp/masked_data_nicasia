# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('c_relparty_details.xlsx')
df.head()
# Out:
#                          _airbyte_ab_id     _airbyte_emitted_at  dob  pan  \
# 0  67079ecc-64ff-479f-86a4-703676d85f4d 2024-08-05 09:11:03.365  NaN  NaN
# 1  1ffadd2f-d69b-442e-8d56-4c713fbb9869 2024-08-05 09:11:03.365  NaN  NaN
# 2  f81abc5c-62f6-44c2-afb0-3cb41f9d5680 2024-08-05 09:11:03.365  NaN  NaN
# 3  893f1669-1093-4995-b264-52c2ce8d5195 2024-08-05 09:11:03.365  NaN  NaN
# 4  1747356b-e287-482a-b20f-f19c1a884f5b 2024-08-05 09:11:03.365  NaN  NaN
#
#   email text0 text1 text2  text3 text4  ... perthosueno cerissuedate  \
# 0   NaN   NaN   NaN   NaN    NaN   NaN  ...         NaN          NaN
# 1   NaN   NaN   NaN   NaN    NaN   NaN  ...         NaN          NaN
# 2   NaN   NaN   NaN   NaN    NaN   NaN  ...         NaN          NaN
# 3   NaN   NaN   NaN   NaN    NaN   NaN  ...         NaN          NaN
# 4   NaN   NaN   NaN   NaN    NaN   NaN  ...         NaN          NaN
#
#   lchg_user_id rcre_user_id  cerissuedatead entity_cre_flg mailinghouseno  \
# ...

# %%
df = df.drop(['_airbyte_ab_id', '_airbyte_emitted_at',"source_file_path","_airbyte_additional_properties"], axis=1)
df["foracid"].head()
# Out:
# 0    K344000086552403
# 1    K344000086552403
# 2    K344000086552403
# 3    K344000086552403
# 4    K344000086552403
# Name: foracid, dtype: object

# %%
df_gam = pd.read_csv("../../tbaadm/general_acct_mast_table/acid_foracid_masked.csv")
df_gam.head()
# Out:
#          acid      acid_t         cif_id           foracid  \
# 0   Q39620558  AC10370877  DLNIND1406504  2635752944296001
# 1  Y110180600  AC41672289  DLNIND4211643  3414659520992004
# 2   O93531058  AC73584145  DLNIND4211643  O987952099252401
# 3    32559774  AC12345718  DLNLEG9334212  3241157797524004
# 4   889280082  AC47235600  DLNLEG6576494  0884459092002067
#
#             foracid_t           pan      acct_num                   acct_name
# 0  FA9627239668220084  PAN668645879  272396682200       Humacanta Bipin Thapa
# 1  FA3302344775994664  PAN697945863   23447759946          Sriti Kumari Thapa
# 2  FA5553585851915269  PAN697945863  535858519152          Sriti Kumari Thapa
# 3  FA2582732553674743  PAN353089449  827325536747  PALPA HEALTHCARE PVT. LTD.
# 4  FA7171012596574289  PAN813377590  710125965742                         NaN

# %%
result_df = df.merge(
    df_gam,
    on='foracid',
    how='left'  
)

print(f"Original df length: {len(df)}")
print(f"Merged result length: {len(result_df)}")
# Out:
# Original df length: 429
# Merged result length: 429

# %%
df["foracid"] = result_df["foracid_t"].values

# %%
df["foracid"].head()
# Out:
# 0    FA3598099171962374
# 1    FA3598099171962374
# 2    FA3598099171962374
# 3    FA3598099171962374
# 4    FA3598099171962374
# Name: foracid, dtype: object

# %%
df_acc = pd.read_csv("../../crmuser/account/account_masked.csv")
# df_kyc = pd.read_csv("../../custom/kyc_details/kyc_details_masked.csv")

df_acc["occupation"].head(40)
# Out:
# 0           SERVICE
# 1            FARMER
# 2               NaN
# 3               NaN
# 4          ENGINEER
# 5     NOT AVAILABLE
# 6               NaN
# 7               NaN
# 8     NOT AVAILABLE
# 9            BANKER
# 10     SELFEMPLOYED
# 11              NaN
# 12       UNEMPLOYED
# 13              NaN
# 14              NaN
# 15              NaN
# 16          SERVICE
# 17    NOT AVAILABLE
# 18              NaN
# 19    NOT AVAILABLE
# 20          SERVICE
# 21    NOT AVAILABLE
# 22          RETIRED
# 23        HOUSEHOLD
# 24          TEACHER
# 25           BANKER
# 26    NOT AVAILABLE
# 27           BANKER
# 28      BUSINESSMAN
# 29    NOT AVAILABLE
# 30    NOT AVAILABLE
# 31              NaN
# 32        HOUSEHOLD
# 33           FARMER
# 34              NaN
# 35        HOUSEHOLD
# 36          SERVICE
# 37    NOT AVAILABLE
# 38              NaN
# 39           FARMER
# Name: occupation, dtype: object

# %%
df_acc["pan"].head()
# Out:
# 0    PAN714271279
# 1    PAN503838478
# 2    PAN668645879
# 3    PAN533918346
# 4    PAN331700070
# Name: pan, dtype: object

# %%
result_df = pd.merge(result_df, df_acc, how='left', on="cif_id")
result_df.head()
# Out:
#    dob  pan_x email_x text0 text1 text2  text3 text4  \
# 0  NaN    NaN     NaN   NaN   NaN   NaN    NaN   NaN
# 1  NaN    NaN     NaN   NaN   NaN   NaN    NaN   NaN
# 2  NaN    NaN     NaN   NaN   NaN   NaN    NaN   NaN
# 3  NaN    NaN     NaN   NaN   NaN   NaN    NaN   NaN
# 4  NaN    NaN     NaN   NaN   NaN   NaN    NaN   NaN
#
#                            text5 gender_x  ... creditbureauscorevalidity  \
# 0  REFER AC NO :K341000086552402        M  ...                       NaN
# 1  REFER AC NO :K341000086552402        M  ...                       NaN
# 2  REFER AC NO :K341000086552402        F  ...                       NaN
# 3  REFER AC NO :K341000086552402        F  ...                       NaN
# 4  REFER AC NO :K341000086552402        M  ...                       NaN
#
#   foreignacctaxreportingreq  foreigntaxreportingstatus  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# ...

# %%
result_df["cif_id"].head(40)
# Out:
# 0     DLNLEG9444528
# 1     DLNLEG9444528
# 2     DLNLEG9444528
# 3     DLNLEG9444528
# 4     DLNLEG9444528
# 5     DLNLEG9444528
# 6     DLNLEG9444528
# 7     DLNLEG9444528
# 8     DLNLEG9444528
# 9     DLNLEG9444528
# 10    DLNLEG9444528
# 11    DLNLEG6576494
# 12    DLNLEG6576494
# 13    DLNLEG1805667
# 14    DLNLEG1805667
# 15    DLNLEG1805667
# 16    DLNLEG1805667
# 17    DLNLEG1805667
# 18    DLNLEG3756805
# 19    DLNLEG5919852
# 20    DLNLEG5919852
# 21    DLNLEG9966100
# 22    DLNLEG9101051
# 23    DLNLEG9681773
# 24    DLNLEG9681773
# 25    DLNLEG9681773
# 26    DLNLEG4016980
# 27    DLNLEG8246037
# 28    DLNLEG9370940
# 29    DLNLEG9370940
# 30    DLNLEG5334058
# 31    DLNLEG5334058
# 32    DLNLEG5334058
# 33    DLNLEG6566454
# 34    DLNLEG3709876
# 35    DLNLEG9749078
# 36    DLNLEG9749078
# 37    DLNLEG9749078
# 38    DLNLEG7793973
# 39    DLNLEG7793973
# Name: cif_id, dtype: object

# %%
result_df["email_y"].head(50)
# Out:
# 0                  jajarkotdairyco-op855@outlook.com
# 1                  jajarkotdairyco-op855@outlook.com
# 2                  jajarkotdairyco-op855@outlook.com
# 3                  jajarkotdairyco-op855@outlook.com
# 4                  jajarkotdairyco-op855@outlook.com
# 5                  jajarkotdairyco-op855@outlook.com
# 6                  jajarkotdairyco-op855@outlook.com
# 7                  jajarkotdairyco-op855@outlook.com
# 8                  jajarkotdairyco-op855@outlook.com
# 9                  jajarkotdairyco-op855@outlook.com
# 10                 jajarkotdairyco-op855@outlook.com
# 11                      nepalairlines939@outlook.com
# 12                      nepalairlines939@outlook.com
# 13                 pathivaralogistics755@outlook.com
# 14                 pathivaralogistics755@outlook.com
# 15                 pathivaralogistics755@outlook.com
# 16                 pathivaralogistics755@outlook.com
# 17                 pathivaralogistics755@outlook.com
# ...

# %%
df["email"] = result_df["email_y"].values
df["pan"] = result_df["pan_y"].values
df["dob"] = result_df["cust_dob"].values
# df["gfname"] = result_df["grd_name"].values
# df["fathername"] = result_df["father_name"].values
df["preferredname "] = result_df["fullname"].values
df["mobnum"] = result_df["preferredphone"].values
df["occupation"] = result_df["occupation_y"].values
# df["spousename"] = result_df["spouse_name"].values

# %%
df[["email", "pan", "dob", "preferredname ", "mobnum", "occupation"]].head()
# Out:
#                                email           pan  \
# 0  jajarkotdairyco-op855@outlook.com  PAN558406246
# 1  jajarkotdairyco-op855@outlook.com  PAN558406246
# 2  jajarkotdairyco-op855@outlook.com  PAN558406246
# 3  jajarkotdairyco-op855@outlook.com  PAN558406246
# 4  jajarkotdairyco-op855@outlook.com  PAN558406246
#
#                           dob  \
# 0  2011-02-07T00:00:00.000000
# 1  2011-02-07T00:00:00.000000
# 2  2011-02-07T00:00:00.000000
# 3  2011-02-07T00:00:00.000000
# 4  2011-02-07T00:00:00.000000
#
#                                       preferredname            mobnum  \
# 0                                                NaN  +977-9823170390
# 1  HARI PRASAD KADARIYA                          ...  +977-9823170390
# 2  TARA BASNET                                   ...  +977-9823170390
# 3  SASHIKALA MUKHIYA SUNUWAR                     ...  +977-9823170390
# 4  PRAKASH BHATTARAI                             ...  +977-9823170390
#
#   occupation
# 0        NaN
# ...

# %%
df_kyc = pd.read_csv("../../custom/kyc_details/kyc_details_masked.csv")
df_kyc["cif_id"].head()
# Out:
# 0    DLNIND6943934
# 1    DLNIND9084977
# 2    DLNIND5013653
# 3    DLNIND1568693
# 4    DLNIND3263104
# Name: cif_id, dtype: object

# %%
result_df["cif_id"].head(40)
# Out:
# 0     DLNLEG9444528
# 1     DLNLEG9444528
# 2     DLNLEG9444528
# 3     DLNLEG9444528
# 4     DLNLEG9444528
# 5     DLNLEG9444528
# 6     DLNLEG9444528
# 7     DLNLEG9444528
# 8     DLNLEG9444528
# 9     DLNLEG9444528
# 10    DLNLEG9444528
# 11    DLNLEG6576494
# 12    DLNLEG6576494
# 13    DLNLEG1805667
# 14    DLNLEG1805667
# 15    DLNLEG1805667
# 16    DLNLEG1805667
# 17    DLNLEG1805667
# 18    DLNLEG3756805
# 19    DLNLEG5919852
# 20    DLNLEG5919852
# 21    DLNLEG9966100
# 22    DLNLEG9101051
# 23    DLNLEG9681773
# 24    DLNLEG9681773
# 25    DLNLEG9681773
# 26    DLNLEG4016980
# 27    DLNLEG8246037
# 28    DLNLEG9370940
# 29    DLNLEG9370940
# 30    DLNLEG5334058
# 31    DLNLEG5334058
# 32    DLNLEG5334058
# 33    DLNLEG6566454
# 34    DLNLEG3709876
# 35    DLNLEG9749078
# 36    DLNLEG9749078
# 37    DLNLEG9749078
# 38    DLNLEG7793973
# 39    DLNLEG7793973
# Name: cif_id, dtype: object

# %%
# result_df = pd.merge(result_df, df_kyc, how='left', left_on="cif_id",right_on="cif_id",suffixes=('_p', '_a'))
result_df = pd.merge(result_df, df_kyc, how='left', on="cif_id",suffixes=('_p', '_a'))

result_df.head()
# Out:
#    dob  pan_x email_x text0 text1 text2  text3 text4  \
# 0  NaN    NaN     NaN   NaN   NaN   NaN    NaN   NaN
# 1  NaN    NaN     NaN   NaN   NaN   NaN    NaN   NaN
# 2  NaN    NaN     NaN   NaN   NaN   NaN    NaN   NaN
# 3  NaN    NaN     NaN   NaN   NaN   NaN    NaN   NaN
# 4  NaN    NaN     NaN   NaN   NaN   NaN    NaN   NaN
#
#                            text5 gender_x  ... kyc_last_review  \
# 0  REFER AC NO :K341000086552402        M  ...             NaN
# 1  REFER AC NO :K341000086552402        M  ...             NaN
# 2  REFER AC NO :K341000086552402        F  ...             NaN
# 3  REFER AC NO :K341000086552402        F  ...             NaN
# 4  REFER AC NO :K341000086552402        M  ...             NaN
#
#   referal_foracid  ecdd_last_review es_annu_tran_amt es_annu_tran_num  \
# 0             NaN               NaN              NaN              NaN
# 1             NaN               NaN              NaN              NaN
# ...

# %%
df["gfname"] = result_df["grd_name"].values
df["fathername"] = result_df["father_name"].values
df["spousename"] = result_df["spouse_name"].values

# %%
df[["gfname","fathername", "spousename"]].head()
# Out:
#   gfname fathername spousename
# 0    NaN        NaN        NaN
# 1    NaN        NaN        NaN
# 2    NaN        NaN        NaN
# 3    NaN        NaN        NaN
# 4    NaN        NaN        NaN

# %%
df.to_csv('c_relparty_details_masked.csv', index=False)
